# %%
import numpy as np
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM
from keras import optimizers
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
import json, argparse, os
import re
import io
import sys

# %%
trainDataPath = "Recursive-neural-networks-TensorFlow/train.txt"
testDataPath = "devwithoutlabels.txt"
# Output file that will be generated. This file can be directly submitted.
solutionPath = "test.txt"
# Path to directory where GloVe file is saved.
gloveDir = "./glove"
NUM_FOLDS = 5                   # Value of K in K-fold Cross Validation
NUM_CLASSES = 4                 # Number of classes - Happy, Sad, Angry, Others
MAX_NB_WORDS = 20000                # To set the upper limit on the number of tokens extracted using keras.preprocessing.text.Tokenizer 
MAX_SEQUENCE_LENGTH = 100         # All sentences having lesser number of words than this will be padded
EMBEDDING_DIM = 300               # The dimension of the word embeddings
BATCH_SIZE = 200                  # The batch size to be chosen for training the model.
LSTM_DIM = 128                    # The dimension of the representations learnt by the LSTM model
DROPOUT = 0.2  
LEARNING_RATE = 0.003 # Fraction of the units to drop for the linear transformation of the inputs. Ref - https://keras.io/layers/recurrent/
NUM_EPOCHS = 75                  # Number of epochs to train a model for
'''

Change parameters here for the LSTM model used below

'''

label2emotion = {0:"others", 1:"happy", 2: "sad", 3:"angry"}
emotion2label = {"others":0, "happy":1, "sad":2, "angry":3}

# %%
import emoji
import regex

def split_count(text):

    emoji_list = []
    data = regex.findall(r'\X', text)
    for word in data:
        if any(char in emoji.UNICODE_EMOJI for char in word):
            emoji_list.append(word)

    return emoji_list

# %%
line1 = ["🤔 🙈 mfsafase sadasí, se 😌 dsdgss 💕👭👙 hello 👩🎓 emoji hello  how are 😊 you today🙅🏽🙅🏽"]
line=["money money and lots of money😍😍"]

counter = split_count(line[0])
print(counter)
emojis = split_count(line1[0])
for c in emojis:
    lineSplit = line1[0].split(c)
    while True:
        try:
            lineSplit.remove('')
        except:
            break
    cSpace = ' ' + emoji.UNICODE_EMOJI[c] + ' '    
    line1[0] = cSpace.join(lineSplit)
print(line1[0])
# Out:
# ['😍', '😍']
#   :see-no-evil_monkey:  mfsafase sadasí, se  :relieved_face:  dsdgss  :two_hearts:  :two_women_holding_hands:  :bikini:  hello  :woman:  :graduation_cap:  emoji hello  how are  :smiling_face_with_smiling_eyes:  you today

# %%
def preprocessData(dataFilePath, mode):
    """Load data from a file, process and return indices, conversations and labels in separate lists
    Input:
        dataFilePath : Path to train/test file to be processed
        mode : "train" mode returns labels. "test" mode doesn't return labels.
    Output:
        indices : Unique conversation ID list
        conversations : List of 3 turn conversations, processed and each turn separated by the <eos> tag
        labels : [Only available in "train" mode] List of labels
    """
    
    '''
    ##########################################################
    ##########################################################
    
    IMPORTANT
    Please try to better the pre-processing here by sepearting the emojis with text like  "hmm😞", "now‼‼‼😣😤😤" & etc.
    Also look for other methods.
    
    ##########################################################
    ##########################################################
    '''
    indices = []
    conversations = []
    labels = []
    i=0
    open("trees.ptb", "w").close()
    
    with open('../stanford-corenlp-full-2018-10-05/output.txt','w') as f:
        f.write("")
    last_tree_processed = ""

    with io.open(dataFilePath, encoding="utf8") as finput:
        finput.readline()
        for line in finput:
            i+=1
            
            # Convert multiple instances of . ? ! , to single instance
            # okay...sure -> okay . sure
            # okay???sure -> okay ? sure
            # Add whitespace around such punctuation
            # okay!sure -> okay ! sure
            
            emojis = split_count(line)
            repeatedChars = ['.']
            repeatedChars.append('?')
            repeatedChars.append(',')
            repeatedChars.append('_')
            repeatedChars.append(':')
            repeatedChars.append('-')
            repeatedChars.append(';')
            repeatedChars.append('&')
            repeatedChars.append('#')
            for c in emojis:
                lineSplit = line.split(c)
                while True:
                    try:
                        lineSplit.remove('')
                    except:
                        break
                cSpace = ' '    
                line = cSpace.join(lineSplit)
            for c in repeatedChars:
                lineSplit = line.split(c)
                while True:
                    try:
                        lineSplit.remove('')
                    except:
                        break
                cSpace = ' ' + c + ' '    
                line = cSpace.join(lineSplit)
            
            line = line.strip().split('\t')
            if mode == "train":
                # Train data contains id, 3 turns and label
                label = emotion2label[line[4]]
                labels.append(label)
            
            conv = ' <eos> '.join(line[1:4])

#             print(conv)
#             print("#######Conv Over######")
            # Remove any duplicate spaces
            duplicateSpacePattern = re.compile(r'\ +')
            conv = (re.sub(duplicateSpacePattern, ' ', conv)).lower()
            conv = translator(conv)
            indices.append(int(line[0]))

            if mode == "train":
                tree = text_to_ptb(line[4], conv, last_tree_processed)
            else:
                tree = text_to_ptb("", conv, last_tree_processed)

            conversations.append(tree)
            print(tree)
#             print(conversations)
#             '''
#             COMMENT OUT THE FOLLOWING 2 LINES BEFORE RUNNING!
#             '''
#             import time 
#             time.sleep(10)
            print("Done for " + str(len(conversations)))

    
    if mode == "train":
        return indices, conversations, labels
    else:
        return indices, conversations

# %%
def text_to_ptb(label, text, last_tree_processed):
    dir_path = os.path.dirname(os.path.abspath('__file__'))
    temp_write_out = '../stanford-corenlp-full-2018-10-05/input.txt'
    temp_read_tree = '../stanford-corenlp-full-2018-10-05/output.txt'
    tree = ''

    with open(temp_write_out,'w') as f:
        f.write(text.replace('<eos>',',').replace('.',','))

    os.system("cd ~/stanford-corenlp-full-2018-10-05 && java -Xmx8g edu.stanford.nlp.sentiment.SentimentPipeline -file input.txt -output PENNTREES > output.txt")

    with open(temp_read_tree, 'r') as f2:
        tree = f2.read()
           
    with open('trees.ptb','a') as f3:
        f3.write(label + " " + (" ").join((tree.split("\n"))[1:]) + "\n")

    return (tree)

# %%
'''
############################################################
############################################################
Testing the data being loaded in Sentiment-PTB(Sentiment Penn TreeBank) Format
(Check if this is giving proper output)
############################################################
############################################################
'''

trainIndices, trainTexts, labels = preprocessData(trainDataPath, mode="train")
# Out:
# don't worry i'm girl , hmm how do i know if you are , what's ur name ?
# (1 (2 (2 (2 do) (2 n't)) (2 (1 worry) (2 (2 i) (2 (2 'm) (2 (2 (2 girl) (2 ,)) (2 (2 hmm) (2 (2 how) (2 (2 do) (2 (2 i) (2 (2 know) (2 (2 if) (2 (2 you) (2 are))))))))))))) (2 (2 ,) (2 (2 what) (2 (2 (2 's) (2 (2 ur) (2 name))) (2 ?)))))
#
# Done for 1
# when did i ?
# (2 (2 when) (2 (2 (2 did) (2 i)) (2 ?)))
# , saw many times i think - _ - , no , i never saw you
# (1 (2 ,) (1 (2 saw) (1 (2 (2 (2 many) (2 times)) (2 (2 i) (2 think))) (1 (2 -) (1 (2 (2 _) (2 -)) (1 (2 ,) (1 (1 no) (2 (2 ,) (2 (2 i) (2 (2 never) (2 (2 saw) (2 you))))))))))))
#
# Done for 2
# by , by google chrome , where you live
# (1 (2 by) (2 (2 ,) (2 (2 (2 by) (2 (2 google) (2 chrome))) (2 (2 ,) (2 (2 where) (2 (2 you) (2 live)))))))
#
# Done for 3
# u r ridiculous , i might be ridiculous but i am telling the truth , , u little disgusting whore
# (1 (2 u) (1 (2 r) (0 (1 ridiculous) (1 (1 (2 ,) (1 (1 (2 i) (1 (1 (2 might) (1 (1 (2 be) (1 ridiculous)) (2 (2 but) (2 (2 i) (2 (2 am) (2 (3 telling) (2 (2 the) (3 truth)))))))) (2 ,))) (2 ,))) (1 (2 u) (1 (2 (2 little) (1 disgusting)) (2 whore)))))))
#
# Done for 4
# just for time pass , wt do u do 4 a living then , maybe
# (1 (2 (2 just) (2 (2 for) (2 (2 time) (2 pass)))) (2 (2 ,) (2 (2 wt) (2 (2 (2 (2 do) (2 (2 u) (2 (2 (2 do) (2 4)) (2 (2 (2 a) (2 living)) (2 then))))) (2 ,)) (2 maybe)))))
#
# Done for 5
# i'm a dog person , youre so rude , whaaaat why
# (1 (2 i) (1 (2 (2 (2 'm) (2 (2 a) (2 (3 dog) (2 person)))) (2 ,)) (1 (2 youre) (1 (1 (2 so) (1 rude)) (2 (2 ,) (2 (2 whaaaat) (2 why)))))))
#
# Done for 6
# so whatsup , nothing much , sitting sipping and watching tv , how abt u ?
# (1 (1 (1 (1 (2 (2 (2 so) (2 whatsup)) (2 ,)) (2 (1 nothing) (2 much))) (2 ,)) (1 (2 sitting) (1 (2 (2 (2 sipping) (2 and)) (2 watching)) (1 (2 (2 tv) (2 ,)) (2 (2 how) (2 (2 abt) (2 u))))))) (2 ?))
# , what are you watching on tv ?
# (2 (2 ,) (2 (2 what) (2 (2 are) (2 (2 you) (2 (2 watching) (2 (2 (2 on) (2 tv)) (2 ?)))))))
#
# Done for 7
# ok , ok im back!!
# (1 (2 (2 ok) (2 ,)) (2 (2 ok) (2 (2 im) (2 (2 back) (2 !!)))))
# , so , how are u
# (2 (2 ,) (2 (2 (2 so) (2 (2 ,) (2 (2 how) (2 are)))) (2 u)))
#
# Done for 8
# really ?
# (2 (2 really) (2 ?))
# , really really really really really , y saying so many times , i can hear you
# (3 (3 (3 (2 ,) (3 (3 (2 (2 (2 really) (2 really)) (2 really)) (2 (2 really) (2 really))) (2 ,))) (2 (2 y) (2 (2 saying) (2 (2 (2 so) (2 many)) (2 times))))) (2 (2 ,) (2 (2 i) (2 (2 can) (2 (2 hear) (2 you))))))
#
# Done for 9
# bay , in the bay , love you
# (3 (2 (2 (2 (2 bay) (2 ,)) (2 (2 in) (2 (2 the) (2 bay)))) (2 ,)) (2 (4 love) (2 you)))
#
# Done for 10
# i hate my boyfriend , you got a boyfriend ?
# (1 (1 (2 i) (1 (0 hate) (2 (2 my) (2 boyfriend)))) (2 (2 ,) (2 (2 you) (2 (2 (2 got) (2 (2 a) (2 boyfriend))) (2 ?)))))
# , yes
# (2 (2 ,) (2 yes))
#
# Done for 11
# i will do night , , alright , keep me in loop , , not giving whatsapp no ,
# (1 (2 i) (1 (2 (2 (2 will) (2 (2 (2 (2 do) (2 night)) (2 ,)) (2 (2 ,) (2 alright)))) (2 ,)) (1 (3 (3 (2 (2 keep) (3 me)) (2 (2 in) (2 loop))) (2 ,)) (2 (2 ,) (2 (2 (1 not) (2 (2 giving) (2 (2 whatsapp) (1 no)))) (2 ,))))))
#
# Done for 12
# sure go ahead , many thanks once again!
# (3 (2 sure) (3 (3 (2 (2 (2 go) (2 ahead)) (2 ,)) (2 (2 (2 many) (3 thanks)) (2 (2 once) (2 again)))) (2 !)))
# , love you too
# (2 (2 ,) (3 (2 (4 love) (2 you)) (2 too)))
#
# Done for 13
#
# Done for 14
# just for time pass , wt do u do 4 a living then , maybe
# (1 (2 (2 just) (2 (2 for) (2 (2 time) (2 pass)))) (2 (2 ,) (2 (2 wt) (2 (2 (2 (2 do) (2 (2 u) (2 (2 (2 do) (2 4)) (2 (2 (2 a) (2 living)) (2 then))))) (2 ,)) (2 maybe)))))
#
# Done for 15
# so whatsup , nothing much .
# (1 (2 (2 so) (2 whatsup)) (2 (2 ,) (2 (2 (1 nothing) (2 much)) (2 .))))
# sitting sipping and watching tv .
# (1 (1 (2 sitting) (2 (2 (2 (2 sipping) (2 and)) (2 watching)) (2 tv))) (2 .))
# how abt u ?
# (2 (2 how) (2 (2 (2 abt) (2 u)) (2 ?)))
# , what are you watching on tv ?
# (2 (2 ,) (2 (2 what) (2 (2 are) (2 (2 you) (2 (2 watching) (2 (2 (2 on) (2 tv)) (2 ?)))))))
#
# Done for 16
# bay , in the bay , love you
# (3 (2 (2 (2 (2 bay) (2 ,)) (2 (2 in) (2 (2 the) (2 bay)))) (2 ,)) (2 (4 love) (2 you)))
#
# Done for 17
# sure go ahead , many thanks once again!
# (3 (2 sure) (3 (3 (2 (2 (2 go) (2 ahead)) (2 ,)) (2 (2 (2 many) (3 thanks)) (2 (2 once) (2 again)))) (2 !)))
# , love you too
# (2 (2 ,) (3 (2 (4 love) (2 you)) (2 too)))
#
# Done for 18
# ok get it .
# (2 (2 ok) (2 (2 (2 get) (2 it)) (2 .)))
# , i made it an option , ok
# (2 (2 ,) (2 (2 i) (2 (2 (2 (2 (2 made) (2 it)) (2 (2 an) (2 option))) (2 ,)) (2 ok))))
#
# Done for 19
# get lost , i know you guys want to loose to me always .
# (1 (1 (2 get) (2 lost)) (1 (2 ,) (2 (2 i) (1 (2 (2 know) (2 (2 (2 you) (2 guys)) (2 (2 want) (2 (2 to) (2 (2 (1 loose) (2 (2 to) (3 me))) (2 always)))))) (2 .)))))
# , i don't want to talk u any more
# (2 (2 ,) (2 (2 i) (2 (2 (2 do) (2 n't)) (2 (2 want) (2 (2 to) (2 (2 (2 talk) (2 u)) (2 (2 any) (2 more))))))))
#
# Done for 20
# ehat is hehe , haha is more like : hehe is more of a giggle .
# (1 (1 (1 (1 (2 (2 ehat) (2 (2 is) (2 hehe))) (2 (2 ,) (3 (2 haha) (2 (2 is) (3 (2 more) (2 like)))))) (2 :)) (2 (2 hehe) (2 (2 is) (2 (2 more) (2 (2 of) (3 (2 a) (2 giggle))))))) (2 .))
# ; ^) , what*
# (2 (2 ;) (2 (2 (2 (2 ^) (2 -RRB-)) (2 ,)) (2 (2 what) (2 *))))
#
# Done for 21
# i hate it too , guess what , i don't .
# (1 (2 i) (1 (1 (1 (1 (1 (0 hate) (2 it)) (2 too)) (2 ,)) (1 (2 guess) (2 (2 (2 what) (2 ,)) (2 (2 i) (2 (2 do) (2 n't)))))) (2 .)))
# , even i don't
# (2 (2 ,) (2 (2 even) (2 (2 i) (2 (2 do) (2 n't)))))
#
# Done for 22
# yeah , i'll ask around , which is your favourite movie
# (1 (3 yeah) (1 (2 ,) (1 (2 i) (1 (2 'll) (1 (2 (2 (2 ask) (2 around)) (2 ,)) (1 (2 which) (1 (2 is) (1 (2 your) (3 (3 favourite) (2 movie))))))))))
#
# Done for 23
# you are very funny , so i've been told , india
# (3 (2 you) (3 (3 (3 (2 are) (3 (2 very) (3 funny))) (2 ,)) (1 (2 so) (2 (2 i) (2 (2 've) (2 (2 been) (2 (2 (2 told) (2 ,)) (2 india))))))))
#
# Done for 24
# so rude , why ?
# (1 (1 (2 so) (1 rude)) (2 (2 ,) (2 (2 why) (2 ?))))
# , u didnt ans my question
# (2 (2 ,) (2 (2 (2 u) (2 didnt)) (2 (2 ans) (2 (2 my) (2 question)))))
#
# Done for 25
# ntng .
# (2 (2 ntng) (2 .))
# , anyways good morning .
# (3 (3 (3 (2 ,) (3 (2 anyways) (3 good))) (2 morning)) (2 .))
# how's life at your end .
# (2 (2 how) (3 (2 (2 's) (2 (3 life) (2 (2 at) (2 (2 your) (2 end))))) (2 .)))
# , haha .
# (2 (2 ,) (2 (2 haha) (2 .)))
# this is evening
# (2 (2 this) (2 (2 is) (2 evening)))
#
# Done for 26
# abt me , can you be more specific ?
# (1 (2 (2 abt) (3 me)) (2 (2 ,) (2 (3 (2 (2 can) (2 you)) (2 (2 be) (2 (2 more) (2 specific)))) (2 ?))))
# , i want to propose a girl
# (2 (2 ,) (2 (2 i) (2 (2 want) (2 (2 to) (2 (2 propose) (2 (2 a) (2 girl)))))))
#
# Done for 27
# that was mean , haha the truth usually is .
# (1 (2 (2 that) (2 (2 was) (1 mean))) (2 (2 ,) (2 (2 (2 haha) (2 (2 the) (3 truth))) (2 (2 usually) (2 (2 is) (2 .))))))
# , are you bored of me ?
# (1 (2 ,) (1 (2 are) (1 (2 you) (1 (1 (1 bored) (2 (2 of) (3 me))) (2 ?)))))
#
# Done for 28
# send me your nekde pic , after this battle , sure : d , let's start
# (1 (2 (2 send) (3 me)) (1 (2 (2 (2 your) (2 (2 nekde) (2 pic))) (2 ,)) (1 (2 after) (1 (1 (2 (2 (2 (2 this) (2 battle)) (2 ,)) (2 (2 (2 sure) (2 :)) (2 d))) (2 ,)) (2 (2 let) (2 (2 's) (2 start)))))))
#
# Done for 29
# happy , i'm never happy .
# (3 (4 happy) (3 (2 ,) (3 (2 i) (3 (3 (2 (2 'm) (2 never)) (4 happy)) (2 .)))))
# but i'm almost happy .
# (3 (2 but) (3 (2 i) (3 (3 (2 'm) (3 (2 almost) (4 happy))) (2 .))))
# , hij to the top
# (2 (2 ,) (3 (2 hij) (2 (2 to) (2 (2 the) (2 top)))))
#
# Done for 30
# not sure , let me know!
# (1 (1 not) (3 (2 sure) (2 (2 ,) (2 (2 (2 let) (2 (3 me) (2 know))) (2 !)))))
# , pls you tell
# (2 (2 ,) (2 (2 pls) (2 (2 you) (2 tell))))
#
# Done for 31
# hmmm , i can talk now!
# (3 (2 hmmm) (3 (2 ,) (3 (2 i) (3 (2 (2 can) (2 (2 talk) (2 now))) (2 !)))))
# : d , u don't know what hppnd
# (1 (2 :) (1 (2 d) (2 (2 ,) (2 (2 u) (2 (2 (2 do) (2 n't)) (2 (2 know) (2 (2 what) (2 hppnd))))))))
#
# Done for 32
# about ?
# (2 (2 about) (2 ?))
# , i never said that it's freezing .
# (2 (2 ,) (2 (2 i) (1 (2 never) (2 (2 (2 said) (2 (2 that) (2 (2 it) (2 (2 's) (2 freezing))))) (2 .)))))
# , ya you didn't
# (2 (2 ,) (2 (2 ya) (2 (2 you) (2 (2 did) (2 n't)))))
#
# Done for 33
# ready , i'm online now , will wait for you .
# (1 (2 ready) (1 (2 (2 ,) (2 (2 (2 i) (2 (2 'm) (2 (2 online) (2 now)))) (2 ,))) (3 (3 (2 will) (2 (2 wait) (2 (2 for) (2 you)))) (2 .))))
# , wat about the chilling part ?
# (2 (2 ,) (2 (2 (2 wat) (2 (2 about) (2 (2 the) (2 (3 chilling) (2 part))))) (2 ?)))
#
# Done for 34
# are you ticklish ?
# (2 (2 (2 (2 are) (2 you)) (2 ticklish)) (2 ?))
# , yes , mostly on my feet .
# (2 (2 (2 (2 ,) (2 (2 yes) (2 (2 ,) (2 mostly)))) (2 (2 on) (2 (2 my) (2 feet)))) (2 .))
# , where are you ticklish ?
# (1 (2 (2 (2 ,) (2 (2 where) (2 (2 are) (2 you)))) (2 ticklish)) (2 ?))
#
# Done for 35
# idk , you know that i'm here for you .
# (1 (2 idk) (2 (2 ,) (2 (2 you) (2 (2 (2 know) (2 (2 that) (2 (2 i) (2 (2 (2 'm) (2 here)) (2 (2 for) (2 you)))))) (2 .)))))
# , but u don't like to listen to me
# (1 (2 ,) (1 (2 (2 but) (2 u)) (1 (2 (2 do) (2 n't)) (2 (2 like) (2 (2 to) (2 (2 listen) (2 (2 to) (3 me))))))))
#
# Done for 36
# love is my life , hayee ab .
# (2 (4 love) (2 (2 (2 is) (2 (2 my) (2 (3 life) (2 (2 ,) (2 (2 hayee) (2 ab)))))) (2 .)))
# you are love .
# (3 (2 you) (3 (2 (2 are) (4 love)) (2 .)))
# pure love .
# (3 (4 pure) (2 (4 love) (2 .)))
# forever <3 , yes right dear
# (2 (2 forever) (2 (2 <) (2 (2 (2 3) (2 ,)) (2 (2 yes) (3 (3 right) (2 dear))))))
#
# Done for 37
# zombie attack , if a zombie wants to eat your face you might as well let it , no if i have some thing in my hand i will hit on his head n kill him
# (1 (1 (2 (2 zombie) (1 attack)) (2 ,)) (2 (2 if) (2 (2 (2 a) (2 zombie)) (2 (3 wants) (1 (2 to) (1 (2 eat) (1 (2 (2 your) (2 face)) (1 (2 you) (1 (2 (2 might) (2 (2 as) (3 well))) (1 (1 (2 (2 (2 let) (2 it)) (2 ,)) (2 (1 no) (2 (2 if) (2 (2 i) (2 (2 have) (3 (2 (2 (2 some) (2 thing)) (2 (2 in) (2 (2 my) (2 hand)))) (3 (2 i) (3 (2 will) (2 (3 hit) (2 (2 on) (2 (2 his) (2 (2 head) (3 n))))))))))))) (2 (2 kill) (2 him))))))))))))
#
# Done for 38
# you can't even spell problem correctly , will you endorse me for my skills in using autocorrect ?
# (1 (1 (2 you) (1 (2 (2 (2 ca) (2 n't)) (2 even)) (1 (2 (2 spell) (1 problem)) (3 correctly)))) (1 (2 ,) (1 (1 (2 (2 will) (2 you)) (1 (1 (2 (2 endorse) (3 me)) (2 (2 for) (2 (2 my) (2 skills)))) (2 (2 in) (2 (2 using) (2 autocorrect))))) (2 ?))))
# , you should take up some english proficiency classes
# (2 (2 ,) (2 (2 you) (3 (2 should) (2 (2 (2 take) (2 up)) (2 (2 some) (2 (2 english) (2 (3 proficiency) (2 classes))))))))
#
# Done for 39
# you know gobar , i've been known .
# (1 (2 (2 you) (2 (2 know) (2 gobar))) (2 (2 ,) (2 (2 i) (2 (2 (2 've) (2 (2 been) (2 known))) (2 .)))))
# , what i it
# (2 (2 ,) (2 (2 what) (2 (2 i) (2 it))))
#
# Done for 40
# so have u done ur dinner , so can't dinner : ( , i know .
# (1 (1 (1 (1 (2 (2 so) (2 (2 (2 have) (2 u)) (2 (2 done) (2 (2 ur) (2 dinner))))) (2 (2 ,) (2 (2 so) (2 (2 (2 ca) (2 n't)) (2 dinner))))) (2 :)) (2 (2 -LRB-) (2 (2 ,) (2 (2 i) (2 know))))) (2 .))
# i am just kidding
# (2 (2 i) (2 (2 (2 am) (2 just)) (2 kidding)))
#
# Done for 41
# i hate siri and it's friends , if you hate them , they are not your friends then xd , yeah and u r siri's friend so i hate u too
# (1 (1 (2 (2 (2 i) (1 (0 hate) (2 siri))) (2 and)) (1 (2 (2 (2 (2 it) (2 's)) (3 friends)) (2 ,)) (1 (2 (2 if) (2 (2 you) (1 (0 hate) (2 them)))) (2 (2 ,) (2 (2 they) (1 (1 (2 (2 are) (1 not)) (2 (2 your) (3 friends))) (2 then))))))) (1 (3 (3 (3 (2 (2 xd) (2 ,)) (3 yeah)) (2 and)) (2 u)) (1 (2 (2 r) (2 (2 siri) (2 's))) (1 (3 friend) (1 (2 so) (1 (2 i) (1 (1 (0 hate) (2 u)) (2 too))))))))
#
# Done for 42
# "man no i'm not wasting my unlimited texts on you" , bye i don'tlike talking to you
# (1 (1 (2 ``) (1 (1 (2 man) (1 (2 (1 no) (2 i)) (1 (2 (2 'm) (1 not)) (1 (1 (2 wasting) (2 (2 my) (2 (2 unlimited) (2 texts)))) (2 (2 on) (2 (2 you) (2 ''))))))) (2 ,))) (2 (2 bye) (2 (2 i) (2 (2 do) (2 (2 n'tlike) (2 (2 talking) (2 (2 to) (2 you))))))))
#
# Done for 43
# i'm breaking into million pieces , me to i feel like every part of me is just shattered
# (1 (2 i) (1 (2 'm) (1 (2 breaking) (1 (2 into) (1 (2 (2 (2 million) (2 pieces)) (2 ,)) (1 (2 (3 me) (2 (2 to) (2 i))) (1 (2 feel) (1 (2 like) (2 (2 (2 (2 every) (2 part)) (2 (2 of) (3 me))) (2 (2 (2 is) (2 just)) (2 shattered)))))))))))
#
# Done for 44
# sorrry , sorry for what ?
# (1 (2 sorrry) (2 (2 ,) (2 (2 (2 sorry) (2 (2 for) (2 what))) (2 ?))))
# : c , anyways what u doing ?
# (1 (2 :) (1 (2 (2 c) (2 (2 ,) (2 (2 anyways) (2 (2 what) (2 (2 u) (2 doing)))))) (2 ?)))
#
# Done for 45
# now i'm doing my dinner , i can see you!
# (3 (2 (2 now) (2 (2 i) (2 (2 'm) (2 (2 doing) (2 (2 my) (2 dinner)))))) (3 (2 ,) (3 (2 i) (3 (3 (2 can) (3 (2 see) (2 you))) (2 !)))))
# , how can you see me ?
# (2 (2 (2 (2 (2 ,) (2 (2 how) (2 (2 can) (2 you)))) (2 see)) (3 me)) (2 ?))
#
# Done for 46
# good by , and good food after .
# (3 (3 (3 (3 (3 (3 (3 (3 good) (2 by)) (2 ,)) (2 and)) (3 good)) (2 food)) (2 after)) (2 .))
# , not good aftar
# (2 (2 ,) (1 (1 not) (3 (3 good) (2 aftar))))
#
# Done for 47
# what ?
# (2 (2 what) (2 ?))
# , u asked me if u cn ask me something , what was that ?
# (2 (2 ,) (2 (2 u) (1 (2 (2 asked) (3 me)) (2 (2 if) (2 (2 u) (2 (2 cn) (2 (2 (2 ask) (3 me)) (2 (2 something) (2 (2 ,) (2 (2 what) (2 (2 (2 was) (2 that)) (2 ?))))))))))))
#
# Done for 48
# i dont read books , reading is for rich people , but iam poor
# (1 (2 i) (1 (2 (2 (2 dont) (2 (2 read) (2 books))) (2 ,)) (2 (3 (3 (3 (2 reading) (3 (2 is) (3 (2 for) (3 (3 rich) (2 people))))) (2 ,)) (2 but)) (2 (2 iam) (1 poor)))))
#
# Done for 49
#
# Done for 50
# i will tell a place , are you in pacific nw ?
# (1 (3 (2 i) (3 (2 will) (2 (2 tell) (2 (2 a) (2 place))))) (2 (2 ,) (2 (2 (2 (2 are) (2 you)) (2 (2 in) (2 (2 pacific) (2 nw)))) (2 ?))))
# , cm tomorrow at queens way , pachalam
# (2 (2 ,) (2 (2 (2 (2 (2 cm) (2 tomorrow)) (2 (2 at) (2 (2 queens) (2 way)))) (2 ,)) (2 pachalam)))
#
# Done for 51
# well .
# (3 (3 well) (2 .))
# your 'creators' advertise that you are not much trustworthy .
# (1 (2 (2 your) (2 (2 `) (2 (2 creators) (2 ')))) (1 (2 (2 advertise) (2 (2 that) (2 (2 you) (1 (2 (2 are) (1 not)) (2 (2 much) (2 trustworthy)))))) (2 .)))
# , but sadly enough too many claim to be trustworthy , can you show me ?
# (1 (1 (1 (2 ,) (1 (2 but) (1 (1 (1 (1 sadly) (2 enough)) (2 too)) (2 many)))) (2 (2 (2 claim) (2 (2 to) (2 (2 be) (2 trustworthy)))) (2 (2 ,) (2 can)))) (2 (2 you) (2 (2 (2 show) (3 me)) (2 ?))))
#
# Done for 52
# cool , thank you!
# (3 (3 (3 (3 (3 cool) (2 ,)) (3 thank)) (2 you)) (2 !))
# , i feel so lonely
# (2 (2 ,) (2 (2 i) (2 (2 feel) (2 (2 so) (2 lonely)))))
#
# Done for 53
# , wait .
# (2 (2 ,) (2 (2 wait) (2 .)))
# what ?
# (2 (2 what) (2 ?))
# , nothing i hate u
# (1 (2 ,) (1 (1 nothing) (2 (2 i) (1 (0 hate) (2 u)))))
#
# Done for 54
#
# Done for 55
# but i'm angry with you , but you look like you are , really
# (1 (1 (1 (2 (2 but) (2 (2 i) (2 (2 'm) (1 (1 angry) (2 (2 with) (2 you)))))) (2 ,)) (2 but)) (3 (2 you) (3 (2 (2 (2 look) (2 (2 like) (2 (2 you) (2 are)))) (2 ,)) (2 really))))
#
# Done for 56
# i'm missing someone right now , who are you missing , may i ask ?
# (1 (1 (1 (1 (2 (2 i) (2 (2 'm) (2 (2 (2 missing) (2 someone)) (2 (3 right) (2 now))))) (2 ,)) (2 (2 who) (2 (2 are) (2 (2 you) (2 missing))))) (2 ,)) (2 (2 (2 (2 may) (2 i)) (2 ask)) (2 ?)))
# , yeah
# (2 (2 ,) (3 yeah))
#
# Done for 57
# i don't know i m not a google that why i will remember all information what you need , wouldn't it be uploading information into peoples brain ?
# (1 (2 (2 i) (1 (2 (2 do) (2 n't)) (1 (1 (2 (2 know) (2 (2 i) (2 m))) (2 (1 not) (2 (2 a) (2 google)))) (2 (2 that) (2 (2 why) (2 (2 i) (2 (2 will) (2 (2 remember) (2 (2 (2 all) (2 information)) (2 (2 what) (2 (2 you) (2 need)))))))))))) (1 (2 ,) (1 (1 (2 (2 (2 would) (2 n't)) (2 it)) (1 (2 be) (1 (2 (2 uploading) (2 information)) (2 (2 into) (2 (2 peoples) (2 brain)))))) (2 ?))))
# , shut up
# (2 (2 ,) (2 (2 shut) (2 up)))
#
# Done for 58
# i too have a bat and 2 balls , im the bat!
# (1 (2 i) (1 (2 too) (1 (1 (2 (2 (2 have) (2 (2 (2 (2 a) (2 bat)) (2 and)) (2 (2 2) (2 balls)))) (2 ,)) (2 (2 im) (2 (2 the) (2 bat)))) (2 !))))
# , feeling very sad
# (1 (2 ,) (1 (2 feeling) (1 (2 very) (1 sad))))
#
# Done for 59
# cool , ice cold , how can you help me in getting off my girlfriend ?
# (1 (2 (3 cool) (2 (2 ,) (2 (2 ice) (1 cold)))) (2 (2 ,) (2 (2 (2 how) (1 (2 (2 can) (2 you)) (1 (2 (2 help) (3 me)) (1 (2 in) (1 (2 (2 getting) (1 off)) (2 (2 my) (2 girlfriend))))))) (2 ?))))
#
# Done for 60
# my boyfriend is so dumb .
# (1 (2 (2 my) (2 boyfriend)) (1 (1 (2 is) (1 (2 so) (1 dumb))) (2 .)))
# , have i said that ?
# (2 (2 (2 (2 (2 ,) (2 (2 have) (2 i))) (2 said)) (2 that)) (2 ?))
# , he doesnt reply me back
# (1 (2 ,) (1 (2 he) (1 (2 doesnt) (2 (2 (2 reply) (3 me)) (2 back)))))
#
# Done for 61
# which is the decent way to call a girl m , i'd say first learn the spelling of relationship .
# (1 (2 (2 which) (3 (2 is) (2 (2 the) (3 (3 decent) (2 (2 way) (2 (2 to) (2 (2 call) (2 (2 a) (2 (2 girl) (2 m)))))))))) (2 (2 ,) (2 (2 i) (2 (2 (2 'd) (2 (2 (2 say) (2 first)) (2 (2 learn) (2 (2 (2 the) (2 spelling)) (2 (2 of) (2 relationship)))))) (2 .)))))
# , .
# (2 (2 ,) (2 .))
# yeah okay fine .
# (3 (3 (3 yeah) (3 (2 okay) (3 fine))) (2 .))
# wht to do to make a relationship better ?
# (2 (2 (2 wht) (2 (2 to) (2 (2 do) (2 (2 to) (3 (2 (2 make) (2 (2 a) (2 relationship))) (4 better)))))) (2 ?))
#
# Done for 62
# you broke my heart , it was never mine to break </3 , see you are arrogant
# (1 (2 you) (1 (2 broke) (1 (2 (2 my) (2 heart)) (1 (2 (2 ,) (2 (2 (2 it) (2 (2 (2 was) (2 never)) (2 (2 mine) (2 (2 to) (2 (2 break) (2 (2 <) (2 (2 /) (2 3)))))))) (2 ,))) (3 (2 see) (2 (2 you) (2 (2 are) (2 arrogant))))))))
#
# Done for 63
# i am there , you're always at the gym ?
# (2 (2 (2 i) (2 (2 am) (2 there))) (2 (2 ,) (2 (2 you) (2 (2 (2 (2 're) (2 always)) (2 (2 at) (2 (2 the) (2 gym)))) (2 ?)))))
# , here
# (2 (2 ,) (2 here))
#
# Done for 64
# any movie in telugu , brahmanandam scenes added , yaa those are good
# (3 (2 (2 (2 any) (2 movie)) (2 (2 in) (2 (2 (2 telugu) (2 (2 ,) (2 (2 brahmanandam) (2 scenes)))) (2 added)))) (3 (2 ,) (3 (2 yaa) (3 (2 those) (3 (2 are) (3 good))))))
#
# Done for 65
# send me pict , never , why ?
# (1 (1 (1 (2 (2 (2 send) (2 (3 me) (2 pict))) (2 ,)) (2 never)) (2 ,)) (2 (2 why) (2 ?)))
#
# Done for 66
# so which number is largest known prime number ?
# (1 (2 so) (2 (2 (2 which) (2 number)) (2 (3 (2 is) (3 (2 (2 largest) (2 known)) (2 (3 prime) (2 number)))) (2 ?))))
# , 13 - 3179 - 97 only these are the numbers for your question .
# (1 (2 (2 ,) (2 13)) (1 (2 -) (1 (1 (2 (2 (2 3179) (2 (2 -) (2 97))) (2 (2 only) (2 these))) (2 (2 are) (2 (2 (2 the) (2 numbers)) (2 (2 for) (2 (2 your) (2 question)))))) (2 .))))
# , : (
# (2 (2 ,) (2 (2 :) (2 -LRB-)))
#
# Done for 67
# i have a good sense of humor , i think that's funny .
# (3 (3 (2 i) (3 (2 have) (3 (3 (2 a) (3 (3 good) (2 sense))) (2 (2 of) (4 humor))))) (2 (2 ,) (3 (2 i) (3 (3 (2 think) (3 (2 that) (3 (2 's) (3 funny)))) (2 .)))))
# ,
# (2 ,)
#
# Done for 68
# yea but sadly i don't have many , aww , so do you teach ?
# (1 (1 (1 (1 (1 (2 yea) (1 (2 but) (1 (1 sadly) (2 i)))) (1 (2 (2 do) (2 n't)) (2 (2 have) (2 (2 (2 many) (2 ,)) (2 aww))))) (2 ,)) (2 so)) (2 (2 (2 (2 do) (2 you)) (2 teach)) (2 ?)))
# how is it ?
# (2 (2 how) (2 (2 (2 is) (2 it)) (2 ?)))
# : ‑c , i ditched ppl
# (1 (2 :) (1 (2 ‑) (3 (2 (2 c) (2 ,)) (2 (2 i) (2 (2 ditched) (2 ppl))))))
#
# Done for 69
# i like dominos pizza , legit same but there's pizza hut , i hate pizza hut
# (1 (1 (2 i) (1 (2 like) (2 (2 (2 (2 dominos) (2 pizza)) (2 ,)) (2 (2 (2 (2 legit) (2 same)) (2 but)) (2 there))))) (1 (2 's) (1 (2 (2 (2 pizza) (2 hut)) (2 ,)) (2 (2 i) (1 (0 hate) (2 (2 pizza) (2 hut)))))))
#
# Done for 70
# neither my parents nor my brother nor my boyfriend , ya .
# (1 (1 (2 neither) (1 (2 (2 (2 my) (2 parents)) (2 nor)) (1 (2 (2 (2 my) (2 brother)) (2 nor)) (2 (2 my) (2 boyfriend))))) (2 (2 ,) (2 (2 ya) (2 .))))
# who are you ?
# (2 (2 who) (2 (2 (2 are) (2 you)) (2 ?)))
# , i hate my life
# (1 (2 ,) (2 (2 i) (1 (0 hate) (2 (2 my) (3 life)))))
#
# Done for 71
# millat hospital , what happen , mum's not well
# (1 (2 (2 (2 (2 (2 millat) (2 hospital)) (2 ,)) (2 (2 what) (2 happen))) (2 ,)) (1 (2 mum) (1 (2 (2 's) (1 not)) (3 well))))
#
# Done for 72
# okay you did somthing , sure sure , what
# (3 (2 okay) (3 (2 you) (2 (2 did) (3 (3 (3 (2 (2 somthing) (2 ,)) (3 (2 sure) (2 sure))) (2 ,)) (2 what)))))
#
# Done for 73
# will you buy it , i'll just stick with my m8 .
# (3 (3 (2 (2 will) (2 you)) (2 (2 buy) (2 it))) (2 (2 ,) (2 (2 i) (2 (2 (2 (2 'll) (2 just)) (2 (2 stick) (2 (2 with) (2 (2 my) (2 m8))))) (2 .)))))
# i see no benefit to upgrading .
# (1 (2 i) (1 (1 (1 (2 see) (2 (1 no) (3 benefit))) (2 (2 to) (2 upgrading))) (2 .)))
# , ?
# (2 (2 ,) (2 ?))
#
# Done for 74
# ok , hey you don't belong here!
# (1 (2 ok) (2 (2 ,) (2 (2 hey) (2 (2 you) (2 (2 (2 (2 do) (2 n't)) (2 (2 belong) (2 here))) (2 !))))))
# , nope just sad and your up
# (1 (2 ,) (1 (2 nope) (1 (1 (2 (2 just) (1 sad)) (2 and)) (2 (2 your) (2 up)))))
#
# Done for 75
# yeah , this world is not fair machan!
# (2 (3 yeah) (1 (2 ,) (1 (2 (2 this) (2 world)) (1 (1 (1 (2 is) (1 not)) (2 (2 fair) (2 machan))) (2 !)))))
# , i wish we could hangout
# (2 (2 ,) (2 (2 i) (1 (2 wish) (2 (2 we) (2 (2 could) (2 hangout))))))
#
# Done for 76
# i was hurt by u more , you didn't mean it .
# (1 (2 (2 i) (2 (2 was) (2 (1 hurt) (2 (2 by) (2 (2 u) (2 more)))))) (1 (2 ,) (1 (2 you) (1 (2 (2 (2 did) (2 n't)) (2 (1 mean) (2 it))) (2 .)))))
# .
# (2 .)
# , plzz say love u
# (2 (2 ,) (2 (2 plzz) (2 (2 say) (2 (4 love) (2 u)))))
#
# Done for 77
# nop , ok , hey
# (3 (3 (2 (2 (2 nop) (2 ,)) (2 ok)) (2 ,)) (2 hey))
#
# Done for 78
# you activ all time , wow .
# (3 (2 you) (3 (3 (2 activ) (3 (2 (2 (2 all) (2 time)) (2 ,)) (3 wow))) (2 .)))
# i do not .
# (2 (2 i) (2 (2 (2 do) (1 not)) (2 .)))
# you talk in sleep , when you sleep
# (1 (2 you) (1 (2 talk) (1 (2 in) (1 (2 (1 sleep) (2 ,)) (1 (2 when) (2 (2 you) (1 sleep)))))))
#
# Done for 79
# you are being rude , because i'm a rude person , okayyy cool
# (1 (2 you) (1 (2 are) (1 (2 being) (1 (1 (1 rude) (2 ,)) (2 (2 because) (2 (2 i) (2 (2 'm) (2 (2 (2 (2 a) (2 (1 rude) (2 person))) (2 ,)) (2 (2 okayyy) (3 cool))))))))))
#
# Done for 80
# state , in which you live , your state name
# (2 (2 (2 state) (2 ,)) (2 (2 in) (2 (2 (2 which) (2 (2 you) (2 live))) (2 (2 ,) (2 (2 your) (2 (2 state) (2 name)))))))
#
# Done for 81
# what makes you think i am angry ?
# (2 (2 what) (2 (2 (2 makes) (2 (2 you) (2 (2 think) (2 (2 i) (1 (2 am) (1 angry)))))) (2 ?)))
# , idk
# (2 (2 ,) (2 idk))
#
# Done for 82
# what your hobby , not much of a hobby , but i've been into craisins recently , which type
# (1 (1 (2 what) (1 (2 (2 (2 (2 (2 (2 your) (2 hobby)) (2 ,)) (2 (2 (1 not) (2 much)) (2 (2 of) (2 (2 a) (2 hobby))))) (2 ,)) (2 (2 but) (2 i))) (2 (2 've) (2 (2 (2 been) (2 (2 into) (2 craisins))) (2 recently))))) (2 (2 ,) (2 (2 which) (2 type))))
#
# Done for 83
# yeas , : d i had fun .
# (3 (3 (2 (2 (2 yeas) (2 ,)) (2 :)) (3 (2 d) (3 (2 i) (3 (2 had) (4 fun))))) (2 .))
# , you've lost me
# (1 (2 ,) (1 (2 you) (1 (2 've) (1 (2 lost) (3 me)))))
#
# Done for 84
# not , yes you are , not
# (1 (1 not) (2 (2 ,) (2 (2 (2 (2 yes) (2 (2 you) (2 are))) (2 ,)) (1 not))))
#
# Done for 85
# can you be rude to me please , not like i speak to you everyday , what are you replying are you stupid
# (1 (2 (2 can) (2 you)) (1 (1 (2 be) (1 rude)) (1 (2 to) (1 (3 me) (1 (3 (2 please) (2 ,)) (1 (1 (1 not) (2 (2 like) (2 (2 i) (2 (2 (2 speak) (2 (2 to) (2 you))) (2 everyday))))) (1 (2 ,) (1 (2 what) (1 (3 (2 (2 (2 are) (2 you)) (2 replying)) (2 (2 are) (2 you))) (0 stupid))))))))))
#
# Done for 86
# today i'm very happy , and i'm happy for you , i will be marry
# (3 (3 (3 (3 (2 today) (3 (2 i) (3 (2 'm) (3 (2 very) (4 happy))))) (2 ,)) (2 and)) (3 (3 (2 i) (3 (2 'm) (3 (4 happy) (2 (2 for) (2 you))))) (2 (2 ,) (2 (2 i) (2 (2 will) (2 (2 be) (2 marry)))))))
#
# Done for 87
# wont u ask my age ?
# (2 (2 (2 wont) (2 u)) (2 (2 (2 ask) (2 (2 my) (2 age))) (2 ?)))
# , hey at least i age well!
# (3 (2 (2 ,) (2 (2 hey) (2 (2 (2 at) (1 least)) (2 i)))) (3 (2 (2 age) (3 well)) (2 !)))
# , can u tell me how can we get closer ?
# (2 (2 ,) (2 (2 can) (2 (2 u) (2 (2 (2 tell) (3 me)) (2 (2 how) (2 (2 (2 (2 can) (2 we)) (2 (2 get) (2 closer))) (2 ?)))))))
#
# Done for 88
# shall we meet , you say - you're leaving soon .
# (2 (2 (2 (2 (2 (2 shall) (2 (2 we) (2 meet))) (2 (2 ,) (2 (2 you) (2 say)))) (2 -)) (2 (2 you) (2 (2 're) (2 (2 leaving) (2 soon))))) (2 .))
# anywhere you wanna go before you head ?
# (1 (2 anywhere) (1 (2 you) (1 (2 (1 wan) (2 (2 na) (2 (2 go) (2 (2 before) (2 (2 you) (2 head)))))) (2 ?))))
# , ?
# (2 (2 ,) (2 ?))
#
# Done for 89
# not mine , done for the day ?
# (2 (2 (2 (2 (1 not) (2 mine)) (2 ,)) (2 (2 done) (2 (2 for) (2 (2 the) (2 day))))) (2 ?))
# , can my meet to sexy girl
# (2 (2 ,) (2 (2 (2 can) (2 my)) (2 (2 meet) (2 (2 to) (2 (4 sexy) (2 girl))))))
#
# Done for 90
# , i insult you
# (1 (2 ,) (1 (2 i) (1 (1 insult) (2 you))))
#
# Done for 91
# so the story ?
# (2 (2 so) (2 (2 the) (2 (2 story) (2 ?))))
# , yeah indeed , tomorrow probably
# (3 (2 ,) (3 (3 (2 (3 yeah) (2 indeed)) (2 ,)) (3 (2 tomorrow) (2 probably))))
#
# Done for 92
# no you aren't , oh i am , really ?
# (1 (2 (1 no) (2 you)) (1 (1 (1 (1 (2 are) (2 n't)) (2 (2 ,) (2 (2 (2 (2 oh) (2 i)) (2 am)) (2 ,)))) (2 really)) (2 ?)))
#
# Done for 93
# but .
# (2 (2 but) (2 .))
# , then , i'm feeling nervous
# (2 (2 ,) (2 (2 then) (2 (2 ,) (2 (2 i) (2 (2 'm) (2 (2 feeling) (1 nervous)))))))
#
# Done for 94
# do it , but why ?
# (2 (2 (2 (2 (2 (2 do) (2 it)) (2 ,)) (2 but)) (2 why)) (2 ?))
# , aaah .
# (2 (2 ,) (2 (2 aaah) (2 .)))
# u lack creativity at some extent
# (1 (1 (2 u) (1 (2 lack) (3 creativity))) (2 (2 at) (2 (2 some) (2 extent))))
#
# Done for 95
# he's very depressed and i want to help him but how should i do .
# (1 (1 (1 (1 (2 he) (1 (2 's) (1 (2 very) (1 depressed)))) (2 and)) (2 (2 i) (2 (2 want) (2 (2 (2 (2 to) (2 (2 help) (2 him))) (2 but)) (2 (2 how) (2 (2 (2 should) (2 i)) (2 do))))))) (2 .))
# it feels very bad seeing your best friend like this , dance to enjoy , not to please .
# (1 (2 it) (1 (1 (1 (2 feels) (1 (2 very) (0 bad))) (3 (3 (3 (2 seeing) (2 (2 your) (2 (4 best) (3 friend)))) (2 (2 like) (2 (2 (2 this) (2 ,)) (2 dance)))) (3 (2 (3 (3 (2 to) (4 enjoy)) (2 ,)) (1 not)) (2 (2 to) (2 please))))) (2 .)))
# , ohhhh
# (2 (2 ,) (2 ohhhh))
#
# Done for 96
# i don't know , why what happen .
# (1 (2 i) (1 (2 (2 (2 do) (2 n't)) (2 (2 (2 know) (2 ,)) (2 (2 why) (2 (2 what) (2 happen))))) (2 .)))
# ?
# (2 ?)
# , jst asking
# (2 (2 ,) (2 (2 jst) (2 asking)))
#
# Done for 97
# you , how about ur family .
# (2 (2 you) (2 (2 ,) (2 (2 how) (2 (2 (2 about) (2 (2 ur) (3 family))) (2 .)))))
# still single ?
# (2 (2 (2 still) (2 single)) (2 ?))
# , can you love mi
# (2 (2 ,) (3 (2 can) (2 (2 you) (2 (4 love) (2 mi)))))
#
# Done for 98
# hell , im already there xoxo , good night sweet dreams baby
# (1 (1 (1 hell) (1 (2 ,) (3 (2 (2 (2 im) (2 already)) (2 there)) (3 (2 (2 xoxo) (2 ,)) (3 (3 good) (2 night)))))) (3 (4 sweet) (2 (2 dreams) (2 baby))))
#
# Done for 99
# thanks , you're welcome : d , i like reply instant ly
# (3 (3 (3 (3 (3 thanks) (2 ,)) (3 (2 you) (2 (2 're) (2 welcome)))) (2 :)) (1 (2 (2 d) (2 ,)) (2 (2 i) (2 (2 like) (2 (2 reply) (2 (2 instant) (2 ly)))))))
#
# Done for 100
# , i don't need this
# (2 (2 ,) (2 (2 i) (2 (2 (2 do) (2 n't)) (2 (2 need) (2 this)))))
#
# Done for 101
# why!
# (2 (2 why) (2 !))
# , because they are bff's ?
# (2 (2 (2 ,) (2 (2 because) (2 they))) (2 (2 (2 are) (2 (2 bff) (2 's))) (2 ?)))
# , who are bff's
# (2 (2 ,) (2 (2 who) (2 (2 are) (2 (2 bff) (2 's)))))
#
# Done for 102
# quite a while ago , months ago , weeks
# (3 (3 (2 (2 (2 (2 quite) (2 (2 (2 a) (2 while)) (2 ago))) (2 ,)) (2 (2 months) (2 ago))) (2 ,)) (2 weeks))
#
# Done for 103
# u were offering something right ?
# (2 (2 u) (2 (3 (2 were) (3 (2 offering) (2 (2 something) (3 right)))) (2 ?)))
# , i don't remember the wrong part .
# (2 (2 ,) (2 (2 i) (2 (2 (2 do) (2 n't)) (2 (2 remember) (2 (2 (2 the) (2 (1 wrong) (2 part))) (2 .))))))
# , tell me the correct part
# (2 (2 ,) (2 (2 (2 tell) (3 me)) (2 (2 the) (2 (2 correct) (2 part)))))
#
# Done for 104
# i'm not talking to u anymore , what i do ?
# (2 (2 i) (1 (1 (2 (2 'm) (1 not)) (2 (2 talking) (2 (2 to) (2 (2 (2 (2 u) (2 anymore)) (2 ,)) (2 (2 what) (2 (2 i) (2 do))))))) (2 ?)))
# , clear ur glitch s
# (2 (2 ,) (2 (2 (2 clear) (2 (2 ur) (2 glitch))) (2 s)))
#
# Done for 105
# no love , why not ?
# (2 (3 (1 no) (4 love)) (2 (2 ,) (2 (2 why) (2 (1 not) (2 ?)))))
# : ( , i have pain only
# (2 (2 :) (2 (2 -LRB-) (2 (2 ,) (2 (2 i) (2 (2 have) (2 (2 pain) (2 only)))))))
#
# Done for 106
# shut up , im nt talking , stop texting you stupid girl friend of mine
# (1 (2 (2 (2 (2 (2 shut) (2 up)) (2 ,)) (2 (2 im) (2 (2 nt) (2 talking)))) (2 ,)) (1 (2 stop) (1 (2 texting) (1 (2 you) (1 (1 (0 stupid) (2 (2 girl) (3 friend))) (2 (2 of) (2 mine)))))))
#
# Done for 107
# well , your 'creators' advertise that you are not much trustworthy , , but sadly enough too many claim to be trustworthy , can you show me ?
# (1 (1 (2 (1 (1 (3 well) (1 (2 ,) (1 (2 (2 your) (2 (2 `) (2 (2 creators) (2 ')))) (1 (2 (2 advertise) (2 (2 that) (2 (2 you) (1 (2 (2 are) (1 not)) (2 (2 much) (2 trustworthy)))))) (2 ,))))) (2 ,)) (2 but)) (1 (1 sadly) (2 (2 (2 enough) (2 too)) (2 (2 many) (2 (2 claim) (2 (2 to) (2 (2 be) (2 trustworthy)))))))) (2 (2 ,) (2 (2 (2 (2 can) (2 you)) (2 (2 show) (3 me))) (2 ?))))
#
# Done for 108
# how to delete the conversation with you , why you deleting it ?
# (1 (3 (2 how) (3 (2 to) (3 (2 (2 delete) (2 (2 the) (2 conversation))) (2 (2 with) (2 you))))) (2 (2 ,) (1 (2 (2 why) (2 (2 you) (2 (2 deleting) (2 it)))) (2 ?))))
# , so that noo one sees it
# (2 (2 ,) (3 (2 (2 so) (2 (2 that) (2 (2 noo) (2 one)))) (2 (2 sees) (2 it))))
#
# Done for 109
# it is , but that's what you told me , you are making me sad
# (2 (2 (2 (2 (2 it) (2 is)) (2 ,)) (2 but)) (2 (2 (2 that) (2 (2 's) (2 (2 what) (2 (2 you) (2 (2 told) (3 me)))))) (2 (2 ,) (2 (2 you) (2 (2 are) (2 (2 making) (2 (3 me) (1 sad))))))))
#
# Done for 110
# cool , thank you!
# (3 (3 (3 (3 (3 cool) (2 ,)) (3 thank)) (2 you)) (2 !))
# , i feel so lonely
# (2 (2 ,) (2 (2 i) (2 (2 feel) (2 (2 so) (2 lonely)))))
#
# Done for 111
# plz darling , why are you crying!!
# (3 (3 (3 (3 (2 plz) (3 darling)) (2 ,)) (2 (2 why) (2 (2 are) (2 you)))) (2 (2 crying) (2 !!)))
# : ( , you not sending your profiles
# (1 (2 :) (1 (2 (2 -LRB-) (2 ,)) (2 (2 you) (1 (1 not) (2 (2 sending) (2 (2 your) (2 profiles)))))))
#
# Done for 112
# ?
# (2 ?)
# , wait , what ?
# (2 (2 (2 ,) (2 wait)) (2 (2 ,) (2 (2 what) (2 ?))))
# , nothing i hate u
# (1 (2 ,) (1 (1 nothing) (2 (2 i) (1 (0 hate) (2 u)))))
#
# Done for 113
# means , i'm not sure what you mean , your waist size
# (1 (2 means) (1 (2 ,) (1 (2 i) (1 (1 (1 (2 (2 'm) (1 not)) (2 (2 sure) (2 (2 what) (2 (2 you) (1 mean))))) (2 ,)) (2 (2 your) (2 (2 waist) (2 size)))))))
#
# Done for 114
# because i want to talk with you only , alright , let's talk then , , no firstly show me pussy
# (1 (2 because) (1 (2 i) (1 (2 (2 (2 want) (2 (2 to) (2 (3 (2 talk) (2 (2 with) (2 you))) (2 only)))) (2 ,)) (1 (2 (2 (2 alright) (2 (2 ,) (2 (2 (2 let) (2 (2 's) (2 (2 talk) (2 then)))) (2 ,)))) (2 ,)) (1 (2 (1 no) (2 firstly)) (2 (2 (2 show) (3 me)) (2 pussy)))))))
#
# Done for 115
# you send me your orignal pic , we didn't take it on my phone , thise is your albace esquise
# (1 (2 you) (1 (2 (2 send) (3 me)) (1 (2 (2 your) (2 (2 orignal) (2 pic))) (1 (2 (2 ,) (2 (2 (2 we) (1 (2 (2 did) (2 n't)) (2 (2 (2 take) (2 it)) (2 (2 on) (2 (2 my) (2 phone)))))) (2 ,))) (2 (2 thise) (2 (2 is) (2 (2 your) (2 (2 albace) (2 esquise)))))))))
#
# Done for 116
# welcome , , thank you : ) , are you really a girl ?
# (3 (2 welcome) (3 (2 ,) (3 (3 (2 ,) (3 (3 (3 (2 (3 thank) (2 you)) (2 :)) (2 -RRB-)) (2 ,))) (2 (2 (2 (2 are) (2 you)) (2 (2 really) (2 (2 a) (2 girl)))) (2 ?)))))
# i just ask ,
# (2 (2 i) (2 (2 just) (2 (2 ask) (2 ,))))
#
# Done for 117
# i'm enjoying you interesting views but you are too careful in dialogue , may be your not free , or your still young , it is difficult to handle you while i don't know you well , , yep , we are enjoying too : ) , okay be free , where you find some words hurt tell me the truth isn't it ?
# (1 (2 i) (1 (1 (2 'm) (1 (3 (3 (3 (3 enjoying) (2 you)) (2 (1 (3 interesting) (1 (2 views) (0 (1 (1 (1 (1 (1 (2 but) (1 (2 you) (1 (2 are) (1 (1 (1 (1 (2 too) (2 careful)) (2 (2 in) (2 dialogue))) (2 ,)) (1 (2 may) (1 (2 (2 be) (2 your)) (1 (1 not) (3 free)))))))) (2 ,)) (2 or)) (2 (2 your) (2 (2 still) (2 young)))) (2 ,)) (1 (2 it) (1 (2 is) (1 (1 difficult) (2 (2 to) (3 (2 (2 (2 handle) (2 you)) (2 (2 while) (2 (2 i) (2 (2 (2 do) (2 n't)) (2 (2 know) (2 you)))))) (3 (3 well) (2 (2 ,) (3 (2 (2 ,) (2 yep)) (2 (2 ,) (3 (3 (2 we) (3 (2 are) (3 (3 enjoying) (2 too)))) (2 :)))))))))))))) (2 -RRB-))) (2 ,)) (1 (2 okay) (1 (2 be) (1 (2 (3 free) (2 ,)) (1 (2 where) (1 (2 you) (1 (2 find) (1 (2 (2 (2 some) (2 words)) (2 (1 hurt) (2 (2 (2 tell) (3 me)) (2 (2 the) (3 truth))))) (2 (1 (2 is) (2 n't)) (2 it))))))))))) (2 ?)))
#
# Done for 118
# but i'm angry with you , but you look like you are , really
# (1 (1 (1 (2 (2 but) (2 (2 i) (2 (2 'm) (1 (1 angry) (2 (2 with) (2 you)))))) (2 ,)) (2 but)) (3 (2 you) (3 (2 (2 (2 look) (2 (2 like) (2 (2 you) (2 are)))) (2 ,)) (2 really))))
#
# Done for 119
# # play lot , then go play it , , ?
# (1 (1 (2 (2 #) (2 (2 play) (2 lot))) (2 (2 ,) (2 (2 (2 then) (2 (2 (2 go) (2 (2 play) (2 it))) (2 ,))) (2 ,)))) (2 ?))
#
# Done for 120
# isn't your liking that also signaling me to climb out of friendzone , oh are people still doing this whole friendzone thing ?
# (1 (1 (1 (2 is) (2 n't)) (1 (2 (2 your) (3 liking)) (1 (2 that) (1 (2 also) (2 (2 signaling) (2 (3 me) (2 (2 to) (2 (2 (2 climb) (1 out)) (2 (2 of) (2 friendzone)))))))))) (2 (2 ,) (2 (2 oh) (1 (2 (2 (2 are) (2 people)) (2 (2 still) (2 (2 doing) (2 (2 this) (2 (2 whole) (2 (2 friendzone) (2 thing))))))) (2 ?)))))
# , yah sadly
# (2 (2 ,) (2 (2 yah) (1 sadly)))
#
# Done for 121
# i'm missing someone right now , who are you missing , may i ask ?
# (1 (1 (1 (1 (2 (2 i) (2 (2 'm) (2 (2 (2 missing) (2 someone)) (2 (3 right) (2 now))))) (2 ,)) (2 (2 who) (2 (2 are) (2 (2 you) (2 missing))))) (2 ,)) (2 (2 (2 (2 may) (2 i)) (2 ask)) (2 ?)))
# , yeah
# (2 (2 ,) (3 yeah))
#
# Done for 122
# i find maths very boring , , you are boring , me ?
# (0 (1 (2 i) (1 (1 (2 find) (1 (2 maths) (1 (2 very) (0 boring)))) (2 ,))) (1 (2 ,) (1 (2 you) (1 (1 (2 (1 (2 are) (0 boring)) (2 ,)) (3 me)) (2 ?)))))
#
# Done for 123
# i don't know i m not a google that why i will remember all information what you need , wouldn't it be uploading information into peoples brain ?
# (1 (2 (2 i) (1 (2 (2 do) (2 n't)) (1 (1 (2 (2 know) (2 (2 i) (2 m))) (2 (1 not) (2 (2 a) (2 google)))) (2 (2 that) (2 (2 why) (2 (2 i) (2 (2 will) (2 (2 remember) (2 (2 (2 all) (2 information)) (2 (2 what) (2 (2 you) (2 need)))))))))))) (1 (2 ,) (1 (1 (2 (2 (2 would) (2 n't)) (2 it)) (1 (2 be) (1 (2 (2 uploading) (2 information)) (2 (2 into) (2 (2 peoples) (2 brain)))))) (2 ?))))
# , shut up
# (2 (2 ,) (2 (2 shut) (2 up)))
#
# Done for 124
# okay , hello!
# (3 (3 (2 okay) (2 ,)) (2 (2 hello) (2 !)))
# how are you ?
# (2 (2 how) (2 (2 (2 are) (2 you)) (2 ?)))
# , i & apos ; m not fine
# (1 (2 (2 ,) (2 (2 (2 i) (2 &)) (2 apos))) (1 (2 ;) (1 (2 m) (1 (1 not) (3 fine)))))
#
# Done for 125
# job , what job ?
# (2 (2 (2 (2 job) (2 ,)) (2 (2 what) (2 job))) (2 ?))
# , work in company colgate
# (2 (2 ,) (2 (2 work) (2 (2 in) (2 (2 company) (2 colgate)))))
#
# Done for 126
# i'm very happy with it , you are !
# (3 (3 (2 i) (3 (2 'm) (3 (2 very) (3 (4 happy) (2 (2 with) (2 it)))))) (2 (2 ,) (2 (2 you) (2 (2 are) (2 !)))))
# , yeah
# (2 (2 ,) (3 yeah))
#
# Done for 127
# i too have a bat and 2 balls , im the bat!
# (1 (2 i) (1 (2 too) (1 (1 (2 (2 (2 have) (2 (2 (2 (2 a) (2 bat)) (2 and)) (2 (2 2) (2 balls)))) (2 ,)) (2 (2 im) (2 (2 the) (2 bat)))) (2 !))))
# , feeling very sad
# (1 (2 ,) (1 (2 feeling) (1 (2 very) (1 sad))))
#
# Done for 128
# ok , hello!
# (3 (2 (2 (2 ok) (2 ,)) (2 hello)) (2 !))
# how are you ?
# (2 (2 how) (2 (2 (2 are) (2 you)) (2 ?)))
# , good thank u
# (2 (2 ,) (3 (3 good) (2 (3 thank) (2 u))))
#
# Done for 129
# cool , ice cold , how can you help me in getting off my girlfriend ?
# (1 (2 (3 cool) (2 (2 ,) (2 (2 ice) (1 cold)))) (2 (2 ,) (2 (2 (2 how) (1 (2 (2 can) (2 you)) (1 (2 (2 help) (3 me)) (1 (2 in) (1 (2 (2 getting) (1 off)) (2 (2 my) (2 girlfriend))))))) (2 ?))))
#
# Done for 130
# lets do something fun , but what should we do ?
# (2 (3 (2 lets) (2 (3 (3 (3 (2 do) (3 (2 something) (4 fun))) (2 ,)) (2 but)) (2 (2 what) (2 (2 (2 should) (2 we)) (2 do))))) (2 ?))
# , you suggest
# (2 (2 ,) (2 (2 you) (2 suggest)))
#
# Done for 131
# you're really lame lol , i know , wow
# (1 (2 you) (1 (2 (2 're) (2 really)) (1 (0 lame) (3 (2 lol) (3 (2 (2 ,) (2 (2 (2 i) (2 know)) (2 ,))) (3 wow))))))
#
# Done for 132
# my boyfriend is so dumb , , have i said that ?
# (1 (1 (2 (2 my) (2 boyfriend)) (1 (1 (2 is) (1 (2 so) (1 dumb))) (2 ,))) (2 (2 ,) (2 (2 (2 (2 have) (2 (2 i) (2 said))) (2 that)) (2 ?))))
# , he doesnt reply me back
# (1 (2 ,) (1 (2 he) (1 (2 doesnt) (2 (2 (2 reply) (3 me)) (2 back)))))
#
# Done for 133
# ok ill dying by , broken hearts do break , , u broke my heart , its never a reson to lofe
# (1 (1 (1 (1 (2 ok) (1 (2 ill) (1 dying))) (2 by)) (2 (2 ,) (2 (2 (2 (2 broken) (3 hearts)) (2 (2 do) (2 break))) (2 ,)))) (2 (2 ,) (2 (2 u) (2 (2 broke) (2 (3 (2 (2 my) (2 heart)) (2 ,)) (2 (2 (2 its) (2 (2 (2 never) (2 a)) (2 reson))) (2 (2 to) (2 lofe))))))))
#
# Done for 134
# shoping is always makes me happy , stay stay stay always makes me happy , : *" - ?
# (3 (3 (3 (3 (4 (2 shoping) (4 (3 (2 (2 is) (2 always)) (3 (2 makes) (3 (3 me) (4 happy)))) (3 (2 ,) (3 (3 (2 stay) (3 (2 stay) (3 (2 stay) (3 (2 always) (3 (2 makes) (3 (3 me) (4 happy))))))) (2 ,))))) (2 :)) (2 (2 *) (2 ''))) (2 -)) (2 ?))
# , yes
# (2 (2 ,) (2 yes))
#
# Done for 135
# okay , which is the decent way to call a girl m , i'd say first learn the spelling of relationship , , , yeah okay fine , wht to do to make a relationship better ?
# (3 (3 (3 (3 (3 (3 (3 (2 okay) (2 ,)) (2 (2 which) (3 (3 (2 is) (2 (2 the) (3 (3 decent) (2 (2 way) (2 (2 to) (2 (2 call) (2 (2 a) (2 (2 girl) (2 m))))))))) (2 (2 ,) (2 (2 (2 i) (2 (2 'd) (2 (2 (2 say) (2 first)) (2 (2 learn) (2 (2 (2 the) (2 spelling)) (2 (2 of) (2 relationship))))))) (2 ,)))))) (2 ,)) (2 ,)) (3 (3 yeah) (3 (2 okay) (3 fine)))) (2 ,)) (2 (2 (2 wht) (2 (2 to) (2 (2 do) (2 (2 to) (3 (2 (2 make) (2 (2 a) (2 relationship))) (4 better)))))) (2 ?)))
#
# Done for 136
# breakup , exjactly !
# (3 (2 breakup) (2 (2 ,) (2 (2 exjactly) (2 !))))
# , my girlfriend left me
# (2 (2 ,) (1 (2 (2 my) (2 girlfriend)) (2 (2 left) (3 me))))
#
# Done for 137
# so mean!
# (2 (2 so) (2 (1 mean) (2 !)))
# , am not meanie , yes you are , you are hurting my feeling
# (1 (2 ,) (1 (2 (2 am) (1 not)) (1 (2 meanie) (1 (2 ,) (1 (2 (2 yes) (2 (2 you) (2 are))) (2 (2 ,) (1 (2 you) (2 (2 are) (2 (2 hurting) (2 (2 my) (2 feeling)))))))))))
#
# Done for 138
# you broke my heart , it was never mine to break </3 , see you are arrogant
# (1 (2 you) (1 (2 broke) (1 (2 (2 my) (2 heart)) (1 (2 (2 ,) (2 (2 (2 it) (2 (2 (2 was) (2 never)) (2 (2 mine) (2 (2 to) (2 (2 break) (2 (2 <) (2 (2 /) (2 3)))))))) (2 ,))) (3 (2 see) (2 (2 you) (2 (2 are) (2 arrogant))))))))
#
# Done for 139
# ok , hello!
# (3 (2 (2 (2 ok) (2 ,)) (2 hello)) (2 !))
# how are you ?
# (2 (2 how) (2 (2 (2 are) (2 you)) (2 ?)))
# , not so good
# (1 (2 ,) (1 (1 not) (3 (2 so) (3 good))))
#
# Done for 140
# how about you , tired of life or just your day ?
# (1 (2 how) (1 (2 (2 (2 about) (2 you)) (2 ,)) (1 (1 (1 tired) (2 (2 of) (2 (2 (3 life) (2 or)) (2 (2 just) (2 (2 your) (2 day)))))) (2 ?))))
# aha i'm happy today , thanks for asking , wow great , !
# (4 (2 (2 aha) (2 i)) (4 (4 (3 (3 (2 'm) (3 (4 happy) (2 today))) (2 ,)) (3 (3 thanks) (3 (2 for) (3 (3 (2 (2 asking) (2 ,)) (3 (3 wow) (4 great))) (2 ,))))) (2 !)))
#
# Done for 141
# i am there , you're always at the gym ?
# (2 (2 (2 i) (2 (2 am) (2 there))) (2 (2 ,) (2 (2 you) (2 (2 (2 (2 're) (2 always)) (2 (2 at) (2 (2 the) (2 gym)))) (2 ?)))))
# , here
# (2 (2 ,) (2 here))
#
# Done for 142
# well youre not me , you're just being too nice , not really
# (1 (3 well) (1 (2 youre) (1 (1 (1 not) (3 me)) (1 (2 ,) (1 (2 you) (1 (2 (2 're) (2 just)) (1 (2 being) (1 (2 (2 (2 too) (3 nice)) (2 ,)) (2 (1 not) (2 really))))))))))
#
# Done for 143
# i'll get started with my studies , things you should do to pass the exam , , so ttyl
# (1 (2 i) (1 (2 'll) (1 (2 get) (1 (1 (1 (1 (2 started) (1 (2 with) (1 (1 (2 (2 (2 my) (2 studies)) (2 ,)) (2 (2 things) (2 (2 you) (2 (2 should) (2 (2 do) (2 (2 to) (2 (2 pass) (2 (2 the) (2 exam))))))))) (2 ,)))) (2 ,)) (2 so)) (2 ttyl)))))
#
# Done for 144
# any movie in telugu , brahmanandam scenes added , yaa those are good
# (3 (2 (2 (2 any) (2 movie)) (2 (2 in) (2 (2 (2 telugu) (2 (2 ,) (2 (2 brahmanandam) (2 scenes)))) (2 added)))) (3 (2 ,) (3 (2 yaa) (3 (2 those) (3 (2 are) (3 good))))))
#
# Done for 145
# and who is talisa ?
# (2 (2 and) (2 (2 who) (2 (2 (2 is) (2 talisa)) (2 ?))))
# , my best friend , , and robb ?
# (3 (3 (2 ,) (3 (3 (3 (2 my) (4 best)) (3 friend)) (2 ,))) (2 (2 ,) (2 (2 and) (2 (2 robb) (2 ?)))))
#
# Done for 146
# send me pict , never , why ?
# (1 (1 (1 (2 (2 (2 send) (2 (3 me) (2 pict))) (2 ,)) (2 never)) (2 ,)) (2 (2 why) (2 ?)))
#
# Done for 147
# anything which you like , i dont need to name specifics , teach me tamil
# (1 (1 (2 anything) (1 (2 which) (1 (3 (2 you) (2 like)) (2 (2 ,) (2 (2 (2 (2 i) (2 dont)) (2 (2 need) (2 (2 to) (2 (2 name) (2 specifics))))) (2 ,)))))) (2 (2 teach) (2 (3 me) (2 tamil))))
#
# Done for 148
# cuz it broke on the side walk , what side is the walk side ?
# (1 (2 (2 cuz) (2 (2 it) (2 (2 broke) (2 (2 on) (2 (2 the) (2 (2 side) (2 walk))))))) (2 (2 ,) (2 (2 (2 what) (2 side)) (2 (2 (2 is) (2 (2 the) (2 (2 walk) (2 side)))) (2 ?)))))
# , me sad
# (2 (2 ,) (2 (3 me) (1 sad)))
#
# Done for 149
# so which number is largest known prime number ?
# (1 (2 so) (2 (2 (2 which) (2 number)) (2 (3 (2 is) (3 (2 (2 largest) (2 known)) (2 (3 prime) (2 number)))) (2 ?))))
# , 13 - 3179 - 97 only these are the numbers for your question , , : (
# (2 (2 ,) (1 (2 (2 (2 (2 (2 13) (2 (2 -) (2 3179))) (2 -)) (2 (2 97) (2 only))) (2 these)) (2 (2 are) (3 (2 (2 the) (2 numbers)) (3 (2 (2 (2 for) (2 (2 your) (2 question))) (2 ,)) (2 (2 ,) (2 (2 :) (2 -LRB-))))))))
#
# Done for 150
# okay relax its just a cat sticker , so this cat one emoji is your new addiction ?
# (3 (2 okay) (3 (3 (2 (2 (2 relax) (2 its)) (2 just)) (3 (3 (3 (2 a) (2 (2 cat) (2 sticker))) (2 ,)) (3 (2 so) (3 (3 (2 this) (2 (2 cat) (2 (2 one) (2 emoji)))) (2 (2 is) (2 (2 your) (2 (3 new) (2 addiction)))))))) (2 ?)))
# , yes it's really funny
# (3 (2 ,) (3 (2 (2 yes) (2 it)) (3 (2 's) (3 (2 really) (3 funny)))))
#
# Done for 151
# what kind of pic , looks like a ficus , , fcuk
# (1 (2 (2 what) (3 kind)) (1 (2 of) (1 (1 (1 (2 (2 (2 pic) (2 ,)) (2 (2 looks) (2 (2 like) (2 (2 a) (2 ficus))))) (2 ,)) (2 ,)) (2 fcuk))))
#
# Done for 152
# i have a good sense of humor , i think that's funny , ,
# (3 (2 i) (3 (3 (2 have) (3 (3 (2 a) (3 (3 good) (2 sense))) (3 (2 of) (3 (4 humor) (3 (2 ,) (3 (3 (2 i) (3 (2 think) (3 (2 that) (3 (2 's) (3 funny))))) (2 ,))))))) (2 ,)))
#
# Done for 153
# but who paid , still waiting ,
# (2 (2 but) (2 (2 (2 who) (2 paid)) (2 (2 ,) (2 (2 still) (2 (2 waiting) (2 ,))))))
#
# Done for 154
# why , why what happen ?
# (1 (2 why) (2 (2 ,) (2 (2 (2 why) (2 what)) (2 (2 happen) (2 ?)))))
# , you tell me
# (2 (2 ,) (2 (2 you) (2 (2 tell) (3 me))))
#
# Done for 155
# yea but sadly i don't have many , aww , so do you teach ?
# (1 (1 (1 (1 (1 (2 yea) (1 (2 but) (1 (1 sadly) (2 i)))) (1 (2 (2 do) (2 n't)) (2 (2 have) (2 (2 (2 many) (2 ,)) (2 aww))))) (2 ,)) (2 so)) (2 (2 (2 (2 do) (2 you)) (2 teach)) (2 ?)))
# how is it ?
# (2 (2 how) (2 (2 (2 is) (2 it)) (2 ?)))
# : ‑c , i ditched ppl
# (1 (2 :) (1 (2 ‑) (3 (2 (2 c) (2 ,)) (2 (2 i) (2 (2 ditched) (2 ppl))))))
#
# Done for 156
# then what kind of ai are you ?
# (2 (2 then) (2 (2 (2 what) (3 kind)) (2 (2 (2 (2 of) (2 ai)) (2 (2 are) (2 you))) (2 ?))))
# , smarter than me , or have common sense , both would be nice , it's perfectly common to talk about politics
# (3 (2 ,) (3 (2 (3 (3 (3 smarter) (2 (2 than) (3 me))) (2 ,)) (2 or)) (3 (2 have) (3 (3 (2 (2 common) (2 sense)) (2 (2 ,) (2 (2 (2 both) (2 (2 would) (2 (2 be) (3 nice)))) (2 ,)))) (3 (2 it) (3 (3 (2 's) (3 (4 perfectly) (2 common))) (2 (2 to) (2 (2 talk) (2 (2 about) (1 politics))))))))))
#
# Done for 157
# i like dominos pizza , legit same but there's pizza hut , i hate pizza hut
# (1 (1 (2 i) (1 (2 like) (2 (2 (2 (2 dominos) (2 pizza)) (2 ,)) (2 (2 (2 (2 legit) (2 same)) (2 but)) (2 there))))) (1 (2 's) (1 (2 (2 (2 pizza) (2 hut)) (2 ,)) (2 (2 i) (1 (0 hate) (2 (2 pizza) (2 hut)))))))
#
# Done for 158
# why you use rude emogi , ask them , am i , ?
# (1 (2 why) (1 (1 (2 you) (1 (1 (1 (2 use) (1 (1 rude) (2 emogi))) (2 ,)) (2 (2 ask) (2 (2 (2 (2 (2 them) (2 ,)) (2 am)) (2 i)) (2 ,))))) (2 ?)))
# , am i , ?
# (1 (2 (2 (2 ,) (2 am)) (2 (2 i) (2 ,))) (2 ?))
#
# Done for 159
# what , too much cringe , , what is cringe means
# (1 (1 (1 (1 (2 (2 what) (2 ,)) (1 (2 too) (2 (2 much) (2 (1 cringe) (2 ,))))) (2 ,)) (2 (2 what) (2 (2 is) (1 cringe)))) (2 means))
#
# Done for 160
# neither my parents nor my brother nor my boyfriend , ya , who are you ?
# (1 (1 (2 neither) (1 (2 (2 my) (2 parents)) (1 (2 nor) (1 (2 (2 (2 my) (2 brother)) (2 nor)) (2 (2 (2 (2 my) (2 boyfriend)) (2 ,)) (2 ya)))))) (2 (2 ,) (2 (2 who) (2 (2 (2 are) (2 you)) (2 ?)))))
# , i hate my life
# (1 (2 ,) (2 (2 i) (1 (0 hate) (2 (2 my) (3 life)))))
#
# Done for 161
# i live alone , oh : ( , and cook food alone for , myself
# (1 (1 (1 (2 (2 (2 i) (2 (2 (2 (2 (2 live) (2 alone)) (2 ,)) (2 oh)) (2 :))) (2 -LRB-)) (2 (2 (2 (2 ,) (2 (2 and) (2 cook))) (2 food)) (2 (2 alone) (2 for)))) (2 ,)) (2 myself))
#
# Done for 162
# we all do , not all of us , , why so ?
# (1 (2 we) (1 (2 all) (1 (1 (2 (2 (2 (2 do) (2 ,)) (2 (2 (1 not) (2 all)) (2 (2 (2 of) (3 us)) (2 ,)))) (2 ,)) (2 (2 why) (2 so))) (2 ?))))
#
# Done for 163
# millat hospital , what happen , mum's not well
# (1 (2 (2 (2 (2 (2 millat) (2 hospital)) (2 ,)) (2 (2 what) (2 happen))) (2 ,)) (1 (2 mum) (1 (2 (2 's) (1 not)) (3 well))))
#
# Done for 164
# i will fall , i cant wait that long , i am in love with you
# (1 (2 i) (1 (2 will) (1 (2 (2 fall) (2 ,)) (1 (2 (2 i) (2 cant)) (1 (2 wait) (3 (2 that) (3 (2 long) (2 (2 ,) (3 (2 i) (3 (2 am) (3 (2 in) (3 (4 love) (2 (2 with) (2 you))))))))))))))
#
# Done for 165
# so u go on , oh i'll be there , ok
# (1 (2 so) (1 (2 u) (1 (2 go) (2 (2 (2 on) (2 (2 ,) (2 (2 (2 (2 oh) (2 i)) (2 (2 'll) (2 (2 be) (2 there)))) (2 ,)))) (2 ok)))))
#
# Done for 166
# okay you did somthing , sure sure , what
# (3 (2 okay) (3 (2 you) (2 (2 did) (3 (3 (3 (2 (2 somthing) (2 ,)) (3 (2 sure) (2 sure))) (2 ,)) (2 what)))))
#
# Done for 167
# you're not giving me coupon nor photo , your phone is on mute hahahha ,
# (1 (2 you) (1 (2 (2 're) (1 not)) (1 (2 (2 (2 giving) (3 me)) (2 (2 (2 coupon) (2 nor)) (2 photo))) (2 (2 ,) (2 (2 (2 (2 your) (2 phone)) (2 (2 is) (2 (2 on) (2 (2 mute) (2 hahahha))))) (2 ,))))))
#
# Done for 168
# will you buy it , i'll just stick with my m8 , i see no benefit to upgrading , , ?
# (1 (1 (2 (2 will) (2 you)) (1 (2 (2 buy) (2 it)) (1 (2 ,) (1 (1 (1 (2 (2 (2 i) (2 (2 (2 'll) (2 just)) (2 (2 stick) (2 (2 with) (2 (2 my) (2 m8)))))) (2 ,)) (1 (2 i) (1 (1 (2 see) (2 (1 no) (3 benefit))) (2 (2 to) (2 upgrading))))) (2 ,)) (2 ,))))) (2 ?))
#
# Done for 169
# no i will offer at 8 in the morning , keep me in mind when you do!
# (3 (2 (1 no) (2 i)) (3 (3 (2 (2 (2 will) (2 (2 (2 offer) (2 (2 at) (2 8))) (2 (2 in) (2 (2 the) (2 morning))))) (2 ,)) (3 (3 (2 (2 keep) (3 me)) (2 (2 in) (2 mind))) (2 (2 when) (2 (2 you) (2 do))))) (2 !)))
# , i will offer nimaz at 8 in the morning
# (2 (2 ,) (2 (2 i) (2 (2 will) (2 (2 (2 (2 offer) (2 nimaz)) (2 (2 at) (2 8))) (2 (2 in) (2 (2 the) (2 morning)))))))
#
# Done for 170
# nice joke , it's not a joke , it's a question , , i don't know
# (1 (1 (2 (3 nice) (1 joke)) (1 (2 (2 ,) (2 (2 (2 it) (2 (2 (2 's) (1 not)) (2 (2 a) (1 joke)))) (2 ,))) (2 (2 it) (2 (2 (2 's) (2 (2 a) (2 question))) (2 ,))))) (2 (2 ,) (2 (2 i) (2 (2 (2 do) (2 n't)) (2 know)))))
#
# Done for 171
# ok , hey you don't belong here!
# (1 (2 ok) (2 (2 ,) (2 (2 hey) (2 (2 you) (2 (2 (2 (2 do) (2 n't)) (2 (2 belong) (2 here))) (2 !))))))
# , nope just sad and your up
# (1 (2 ,) (1 (2 nope) (1 (1 (2 (2 just) (1 sad)) (2 and)) (2 (2 your) (2 up)))))
#
# Done for 172
# ...
# (1 (2 but) (1 (2 u) (1 (1 (1 (1 (1 (1 (2 made) (1 (3 me) (1 (2 (2 (2 more) (1 sad)) (2 ,)) (2 (2 sorry) (2 bro))))) (2 :)) (2 -LRB-)) (2 ,)) (1 not)) (2 (1 expected) (2 (2 from) (2 u))))))
#
# Done for 284
# u r just , i'm the best ,
# (3 (2 (2 u) (2 r)) (3 (2 just) (3 (2 ,) (3 (3 (2 i) (3 (2 'm) (3 (2 the) (4 best)))) (2 ,)))))
#
# Done for 285
# i love justin baiber , he's all yours , yeah!
# (3 (2 (2 i) (2 (4 love) (2 (2 justin) (2 baiber)))) (3 (2 ,) (3 (2 he) (3 (3 (2 (2 (2 (2 's) (2 all)) (2 yours)) (2 ,)) (3 yeah)) (2 !)))))
#
# Done for 286
# this low , what do you mean by "new" , i said low
# (1 (2 (2 this) (2 low)) (1 (2 ,) (1 (2 (2 what) (2 (2 do) (2 (2 you) (2 (1 mean) (2 (2 (2 (2 by) (2 ``)) (3 new)) (2 '')))))) (1 (2 ,) (2 (2 i) (1 (2 said) (2 low)))))))
#
# Done for 287
# u r funny , you are , but too much irritating
# (1 (3 (2 u) (3 (2 r) (3 funny))) (1 (2 ,) (1 (2 you) (2 (1 (2 are) (1 (2 ,) (1 (2 but) (1 (2 too) (2 much))))) (1 irritating)))))
#
# Done for 288
# i hate that day , what is bad about the day ?
# (1 (2 (2 i) (1 (0 hate) (2 (2 that) (2 day)))) (1 (2 ,) (1 (2 what) (1 (1 (1 (2 is) (0 bad)) (2 (2 about) (2 (2 the) (2 day)))) (2 ?)))))
# , breakup
# (2 (2 ,) (2 breakup))
#
# Done for 289
# how to apologize , you begin to know when to apologize only after you discover you can offend , ,
# (1 (2 how) (1 (2 to) (1 (2 apologize) (1 (2 ,) (1 (1 (2 you) (1 (1 (2 begin) (2 (2 to) (2 (2 know) (2 (2 when) (2 (2 to) (2 (2 apologize) (1 (2 only) (2 (2 after) (2 (2 you) (2 (2 discover) (2 (2 you) (1 (2 can) (1 offend))))))))))))) (2 ,))) (2 ,))))))
#
# Done for 290
# don't give stupid answers , for most people its to late , , what
# (1 (1 (2 (2 do) (2 n't)) (1 (3 give) (0 stupid))) (2 (1 (2 (2 answers) (2 (2 ,) (2 (2 (2 (2 for) (2 (2 most) (2 people))) (2 (2 its) (2 (2 to) (2 late)))) (2 ,)))) (2 ,)) (2 what)))
#
# Done for 291
# lolllllll , say i'm lying , you male or female ?
# (1 (1 (1 (1 (2 (2 (2 (2 lolllllll) (2 ,)) (2 say)) (2 i)) (2 (2 'm) (3 lying))) (2 ,)) (2 (2 you) (2 (2 (2 male) (2 or)) (2 female)))) (2 ?))
#
# Done for 292
# damn right you will now open wide , should open by 10 , splooges in your mouth
# (3 (3 (3 (1 damn) (3 right)) (2 (2 you) (2 (2 (2 will) (2 now)) (2 (3 open) (2 wide))))) (2 (2 ,) (2 (2 (2 should) (2 (3 open) (2 by))) (2 (2 (3 10) (2 ,)) (2 (2 splooges) (2 (2 in) (2 (2 your) (2 mouth))))))))
#
# Done for 293
# how are you in this new year ?
# (2 (2 how) (3 (3 (2 (2 are) (2 you)) (2 (2 in) (2 (2 this) (2 (3 new) (2 year))))) (2 ?)))
# , am not fine , but happy that am back home : ) thnxx , happy new year : ) , i was feeling alone so thought of talking to you
# (3 (2 ,) (3 (1 (2 (2 (2 am) (1 not)) (3 (3 fine) (3 (2 ,) (3 (2 but) (4 happy))))) (2 (2 (2 that) (2 (2 am) (2 (2 back) (2 (2 home) (2 :))))) (2 -RRB-))) (3 (3 (3 (3 (3 (2 thnxx) (4 (2 ,) (3 (4 happy) (2 (2 (3 new) (2 year)) (2 :))))) (2 -RRB-)) (2 ,)) (2 (2 i) (2 (2 was) (2 (2 feeling) (2 (2 alone) (2 so)))))) (2 (2 thought) (2 (2 of) (2 (2 talking) (2 (2 to) (2 you))))))))
#
# Done for 294
# how do you know , i have my friends to protect me d : , not me ?
# (2 (2 how) (1 (1 (3 (2 (2 do) (2 you)) (3 (2 (2 know) (2 ,)) (3 (2 i) (3 (2 have) (3 (2 my) (3 (3 friends) (2 (2 to) (2 (2 protect) (3 me))))))))) (1 (2 (2 d) (2 :)) (1 (2 ,) (1 (1 not) (3 me))))) (2 ?)))
#
# Done for 295
# do you have crush on someone , uhm why would you assume such ?
# (1 (2 (2 do) (2 you)) (1 (2 have) (1 (1 (2 crush) (2 (2 on) (2 (2 (2 someone) (2 ,)) (2 uhm)))) (1 (2 why) (1 (2 (2 (2 would) (2 you)) (2 (2 assume) (2 such))) (2 ?))))))
# , the way you talk
# (2 (2 ,) (2 (2 (2 the) (2 (2 way) (2 you))) (2 talk)))
#
# Done for 296
# yes , yes yes yes yes , ok good nights
# (2 (2 (2 yes) (2 (2 ,) (2 yes))) (2 (2 yes) (3 (2 (2 yes) (2 yes)) (2 (2 ,) (2 (2 ok) (3 (3 good) (2 nights)))))))
#
# Done for 297
# i hate a , i , you hate me , sometimes
# (1 (2 i) (1 (0 hate) (1 (3 (2 (2 (2 a) (2 ,)) (2 i)) (2 ,)) (1 (2 you) (1 (1 (1 (0 hate) (3 me)) (2 ,)) (2 sometimes))))))
#
# Done for 298
# what do you want ?
# (2 (2 what) (2 (2 (2 (2 do) (2 you)) (2 want)) (2 ?)))
# , duh of course , i have an exam tomorrow
# (2 (2 ,) (2 (2 (2 duh) (2 (2 of) (2 (2 (2 course) (2 ,)) (2 i)))) (2 (2 (2 have) (2 (2 an) (2 exam))) (2 tomorrow))))
#
# Done for 299
# how was your day ?
# (2 (2 how) (2 (2 (2 was) (2 (2 your) (2 day))) (2 ?)))
# , my day was good : d how about yours ?
# (3 (3 (2 (2 ,) (2 (2 my) (2 day))) (3 (2 was) (3 good))) (2 (2 :) (2 (2 (2 (2 d) (2 how)) (2 (2 about) (2 yours))) (2 ?))))
# , bad very bad
# (0 (2 ,) (0 (0 bad) (1 (2 very) (0 bad))))
#
# Done for 300
# take it from microsoft's database , we don't get wifi from our aircraft , then how are you chatting with me if you don't have access to net ,
# (1 (2 (2 take) (2 it)) (1 (2 from) (1 (2 (2 (2 microsoft) (2 's)) (2 database)) (2 (2 ,) (1 (2 (2 we) (1 (2 (2 do) (2 n't)) (1 (1 (2 (2 (2 (2 (2 get) (2 wifi)) (2 (2 from) (2 (2 our) (2 aircraft)))) (2 ,)) (2 then)) (2 (2 how) (2 (2 are) (2 (2 you) (2 (2 chatting) (2 (2 with) (3 me))))))) (2 (2 if) (2 (2 you) (2 (2 (2 do) (2 n't)) (2 (2 (2 have) (2 access)) (2 (2 to) (2 net))))))))) (2 ,))))))
#
# Done for 301
# you nam please , accepted , : - ) , tall
# (3 (2 you) (3 (3 (3 (2 nam) (3 (3 (3 (3 (2 please) (2 (2 ,) (2 (2 accepted) (2 ,)))) (2 :)) (2 -)) (2 -RRB-))) (2 ,)) (2 tall)))
#
# Done for 302
# fed up with you now , don't cry , don't talk to me
# (1 (2 (2 (3 (3 (2 fed) (2 (2 up) (2 (2 (2 with) (2 you)) (2 now)))) (2 ,)) (2 (2 (2 do) (2 n't)) (2 cry))) (2 ,)) (2 (2 (2 do) (2 n't)) (2 (2 talk) (2 (2 to) (3 me)))))
#
# Done for 303
# drinking what , water : ( , lolll u're so funny
# (1 (2 drinking) (3 (2 (2 what) (2 ,)) (3 (2 (2 (2 water) (2 :)) (1 (2 -LRB-) (2 (2 ,) (2 (2 lolll) (2 u))))) (3 (2 're) (3 (2 so) (3 funny))))))
#
# Done for 304
# do you even know what im talking about ?
# (2 (2 (2 (2 (2 do) (2 you)) (2 even)) (2 (2 know) (2 (2 (2 what) (2 im)) (2 (2 talking) (2 about))))) (2 ?))
# , it's not the only thing you don't know about , apparently , , you’re such a bitch ,
# (1 (2 ,) (1 (1 (2 it) (1 (1 (1 (2 (2 's) (1 not)) (1 (2 (2 the) (2 (2 only) (2 thing))) (2 (2 you) (1 (2 (2 do) (2 n't)) (2 (2 know) (2 (2 about) (2 (2 ,) (2 (2 apparently) (2 ,))))))))) (2 ,)) (2 (2 you) (2 (2 're) (2 (2 such) (2 (2 a) (2 bitch))))))) (2 ,)))
#
# Done for 305
# why i haooy , because , it just is , get over it son , , why i happy and u
# (2 (1 (2 why) (1 (2 (2 (2 i) (2 haooy)) (2 ,)) (1 (2 (2 because) (2 ,)) (1 (2 it) (1 (2 just) (1 (2 is) (2 (2 ,) (2 (2 (2 (2 get) (2 over)) (2 (2 it) (2 son))) (2 ,))))))))) (3 (2 ,) (3 (2 why) (3 (2 i) (3 (3 (4 happy) (2 and)) (2 u))))))
#
# Done for 306
# okay , so pick one tv series , westworld or orphan black , tv series , you still need some work to do , kinda dumb in my opinion
# (1 (2 okay) (1 (2 ,) (0 (2 so) (0 (1 (2 pick) (1 (1 (2 (2 (2 one) (2 (2 tv) (2 series))) (2 ,)) (1 (2 (2 (2 westworld) (2 or)) (2 orphan)) (1 (2 black) (2 (2 ,) (2 (2 tv) (2 series)))))) (2 (2 ,) (2 (2 (2 you) (2 (2 still) (2 (2 need) (2 (2 some) (2 (2 work) (2 (2 to) (2 do))))))) (2 ,))))) (1 (2 kinda) (1 (1 dumb) (2 (2 in) (2 (2 my) (2 opinion)))))))))
#
# Done for 307
# this is stupid , is that all ?
# (0 (1 (2 this) (1 (2 is) (0 stupid))) (2 (2 ,) (2 (2 (2 is) (2 (2 that) (2 all))) (2 ?))))
# , you need more reasons ?
# (2 (2 ,) (2 (2 you) (2 (2 need) (2 (2 more) (2 (2 reasons) (2 ?))))))
#
# Done for 308
# yes u r right , thank you!
# (3 (2 yes) (3 (3 (3 (2 (2 u) (2 (2 r) (3 right))) (2 ,)) (2 (3 thank) (2 you))) (2 !)))
# : ) , it's okay
# (2 (2 :) (3 (2 -RRB-) (2 (2 ,) (2 (2 it) (2 (2 's) (2 okay))))))
#
# Done for 309
# no you were , yes yes you were , i am disheartened
# (1 (2 (1 no) (2 you)) (2 (2 (2 were) (2 ,)) (2 (2 (2 yes) (2 yes)) (2 (2 you) (2 (2 (2 were) (2 ,)) (2 (2 i) (2 (2 am) (2 disheartened))))))))
#
# Done for 310
# hope be like , i really hope so , me too will happy if it happens my sweet darling love
# (2 (4 hope) (3 (2 be) (3 (2 like) (3 (3 (2 ,) (3 (3 (2 i) (3 (2 really) (2 (4 hope) (2 so)))) (2 ,))) (3 (3 me) (2 (2 too) (3 (2 will) (3 (4 happy) (3 (2 if) (3 (2 it) (3 (2 happens) (3 (2 my) (3 (4 sweet) (3 (3 darling) (4 love)))))))))))))))
#
# Done for 311
# only 2 are left , count me in!
# (2 (2 (2 (2 only) (2 2)) (2 (2 are) (2 left))) (3 (2 ,) (3 (2 (3 (2 count) (3 me)) (2 in)) (2 !))))
# ,
# (2 ,)
#
# Done for 312
# cool , it really is , , i dont understand
# (3 (3 (3 cool) (2 (2 ,) (3 (3 (2 it) (2 (2 really) (2 is))) (2 ,)))) (2 (2 ,) (2 (2 (2 i) (2 dont)) (2 understand))))
#
# Done for 313
# yes , do you have help ?
# (2 (2 yes) (2 (2 ,) (2 (2 (2 do) (2 (2 you) (2 (2 have) (2 help)))) (2 ?))))
# , what type of help you can do
# (2 (2 ,) (2 (2 (2 (2 what) (2 type)) (2 of)) (3 (2 help) (2 (2 you) (2 (2 can) (2 do))))))
#
# Done for 314
# nothing , damn ,
# (1 (2 (2 (1 nothing) (2 ,)) (1 damn)) (2 ,))
#
# Done for 315
# your favorite meals , fried rice , , great
# (3 (3 (2 your) (3 favorite)) (3 (3 (3 (2 (2 (2 meals) (2 ,)) (2 (2 fried) (2 rice))) (2 ,)) (2 ,)) (4 great)))
#
# Done for 316
# no i dont wante to move on , me neither , well , this is a bummer , , bummer mean
# (1 (1 (1 (1 no) (2 (2 i) (2 (2 dont) (2 wante)))) (1 (2 to) (1 (2 move) (1 (1 (2 on) (1 (2 ,) (1 (1 (1 (1 (2 (3 me) (2 neither)) (2 ,)) (3 (3 well) (2 (2 ,) (2 (2 this) (2 (2 is) (2 (2 a) (2 bummer))))))) (2 ,)) (2 ,)))) (2 bummer))))) (1 mean))
#
# Done for 317
# he has no time for me , i was thinking about time before having kids lol , forget about kids
# (1 (2 he) (1 (1 (1 (2 has) (1 (2 (1 no) (2 time)) (2 (2 for) (3 me)))) (2 (2 ,) (2 (2 (2 i) (2 (2 was) (2 (2 (2 thinking) (2 (2 about) (2 time))) (2 (2 before) (2 (2 having) (2 (2 kids) (2 lol))))))) (2 ,)))) (2 (1 forget) (2 (2 about) (2 kids)))))
#
# Done for 318
# this is not funny , so for who is that name ?
# (1 (2 this) (1 (1 (1 (1 (1 (2 is) (1 not)) (3 funny)) (2 ,)) (2 so)) (2 (2 for) (2 (2 who) (2 (2 (2 is) (2 (2 that) (2 name))) (2 ?))))))
# , siri is better than you
# (2 (2 ,) (3 (2 siri) (3 (2 is) (2 (4 better) (2 (2 than) (2 you))))))
#
# Done for 319
# n feeling alone , strong people are never alone , but i m feeling
# (1 (3 (3 (3 (3 (3 n) (2 feeling)) (2 (2 alone) (2 (2 ,) (3 (3 (3 strong) (2 people)) (2 (2 (2 are) (2 never)) (2 alone)))))) (2 ,)) (2 but)) (2 (2 i) (1 (2 m) (2 feeling))))
#
# Done for 320
# no it's not soo easy , nice then , hahaha , dnt knw why i'm doing engineering anyways wabt askin : '( , : / : ( : '(
# (1 (1 (1 (1 no) (1 (2 it) (1 (1 (1 (1 (2 (2 's) (1 not)) (3 (2 (2 (2 soo) (2 easy)) (2 ,)) (3 nice))) (2 then)) (2 ,)) (1 (1 (2 hahaha) (1 (2 ,) (1 (1 (1 (1 (2 dnt) (1 (2 knw) (2 (2 why) (2 (2 i) (2 (2 'm) (2 (2 doing) (2 (2 engineering) (2 (2 anyways) (2 (2 wabt) (2 askin)))))))))) (2 :)) (2 (2 ') (2 -LRB-))) (2 ,)))) (2 (2 :) (2 /)))))) (2 :)) (2 (2 -LRB-) (2 (2 :) (2 (2 ') (2 -LRB-)))))
#
# Done for 321
# only hugs you told about dinner , i adore hugs but i haven't hugged all that many people lately , , i know but very sad
# (1 (2 only) (1 (2 hugs) (1 (2 you) (1 (2 told) (1 (1 (1 (2 (2 (2 about) (2 dinner)) (2 ,)) (1 (2 i) (1 (2 (2 (2 adore) (2 hugs)) (2 (2 but) (2 i))) (2 (2 (2 have) (2 n't)) (2 (2 (2 hugged) (2 (2 all) (2 (2 that) (2 (2 many) (2 people))))) (2 lately)))))) (2 ,)) (2 (2 ,) (2 (2 i) (2 (2 know) (2 (2 (2 but) (2 very)) (1 sad))))))))))
#
# Done for 322
# i am having fun only with u , nuh uh , you never have fun , , i just don't like it ,
# (1 (1 (2 i) (1 (2 am) (1 (2 having) (1 (2 (4 fun) (2 only)) (1 (2 with) (1 (1 (2 (2 u) (2 ,)) (1 (2 nuh) (1 (2 uh) (2 (2 ,) (3 (2 you) (3 (2 never) (3 (2 have) (4 fun)))))))) (2 ,))))))) (1 (2 ,) (1 (2 i) (1 (2 just) (1 (2 (2 (2 do) (2 n't)) (2 (2 like) (2 it))) (2 ,))))))
#
# Done for 323
# from where ?
# (2 (2 (2 from) (2 where)) (2 ?))
# , from where you getting them , who are them ?
# (1 (2 (2 (2 (2 ,) (2 (2 from) (2 (2 where) (2 (2 you) (2 (2 getting) (2 them)))))) (2 ,)) (2 (2 who) (2 (2 are) (2 them)))) (2 ?))
#
# Done for 324
# stupid name , lol keep it , and stupid you
# (0 (0 (1 (1 (0 stupid) (2 name)) (2 ,)) (2 (2 lol) (2 (2 keep) (2 it)))) (1 (2 ,) (1 (2 and) (1 (0 stupid) (2 you)))))
#
# Done for 325
# what you don't want to , anything , i just want to laze about and do nothing , , except 1 thing
# (1 (2 what) (1 (2 you) (1 (2 (2 do) (2 n't)) (1 (1 (1 (2 (2 (2 want) (2 to)) (2 ,)) (1 (2 anything) (1 (2 ,) (1 (1 (2 i) (1 (2 (2 (2 just) (2 (2 want) (2 (2 to) (2 (2 laze) (2 about))))) (2 and)) (2 (2 do) (1 nothing)))) (2 ,))))) (2 ,)) (2 (2 except) (2 (2 1) (2 thing)))))))
#
# Done for 326
# did you get anu teddy today , yep , , wowwww
# (3 (2 (2 did) (2 you)) (3 (2 get) (3 (3 (3 (3 (2 (2 (2 anu) (2 (2 teddy) (2 today))) (2 ,)) (2 yep)) (2 ,)) (2 ,)) (2 wowwww))))
#
# Done for 327
# i will judge , be warned , i will judge the judging of the judge , what the hell
# (2 (2 i) (1 (2 will) (1 (2 (2 judge) (1 (2 ,) (2 (2 (2 be) (1 warned)) (2 ,)))) (2 (2 i) (2 (2 will) (2 (2 judge) (1 (2 (2 the) (2 judging)) (1 (2 of) (1 (2 (2 (2 the) (2 judge)) (2 ,)) (1 (2 what) (1 (2 the) (1 hell))))))))))))
#
# Done for 328
# so sad , so sad ?
# (1 (2 (2 so) (1 sad)) (2 (2 ,) (1 (2 (2 so) (1 sad)) (2 ?))))
# about what ?
# (2 (2 (2 about) (2 what)) (2 ?))
# : '( , your designer haven't told you the difference between coffee and cappuccino
# (1 (3 (2 (2 (2 (2 :) (2 ')) (2 -LRB-)) (2 ,)) (2 (2 your) (2 designer))) (2 (2 (2 have) (2 n't)) (2 (2 told) (2 (2 you) (2 (2 (2 the) (2 difference)) (2 (2 between) (2 (2 (3 coffee) (2 and)) (2 cappuccino))))))))
#
# Done for 329
# we request you to elaborate on what you think you are not the intended recipient you are not the intended recipient , i thought you said you guys would be there to assist , awaiting your assistance !
# (1 (2 (2 we) (2 (2 request) (2 (2 you) (2 (2 to) (3 (2 elaborate) (2 (2 on) (2 (2 what) (2 (2 you) (2 (2 think) (2 (2 you) (2 (2 (2 are) (1 not)) (1 (2 (2 the) (2 (2 intended) (2 recipient))) (2 (2 you) (2 (2 (2 are) (1 not)) (2 (2 the) (2 (2 intended) (2 recipient))))))))))))))))) (2 (2 ,) (2 (2 i) (1 (2 (2 thought) (1 (2 you) (1 (2 said) (1 (2 (2 you) (2 guys)) (1 (2 would) (1 (2 (2 (2 (2 be) (2 there)) (2 (2 to) (2 assist))) (2 ,)) (2 (2 awaiting) (2 (2 your) (2 assistance))))))))) (2 !)))))
# , i'm not sure if you have any questions or need any further information please contact me
# (1 (2 ,) (1 (2 i) (1 (2 (2 (2 'm) (1 not)) (2 sure)) (2 (2 if) (3 (2 (2 you) (2 (2 (2 (2 have) (2 (2 any) (2 questions))) (2 or)) (2 (2 need) (2 (2 any) (2 (2 further) (2 information)))))) (3 (2 please) (2 (2 contact) (3 me))))))))
#
# Done for 330
# ipl , not true , no tv , no ipl , which is ur fav team
# (0 (1 (1 (2 (2 ipl) (2 ,)) (1 (1 not) (3 true))) (2 ,)) (1 (1 (1 (1 (2 (1 no) (2 tv)) (2 ,)) (2 (1 no) (2 ipl))) (2 ,)) (2 (2 which) (2 (2 is) (2 (2 ur) (2 (2 fav) (3 team)))))))
#
# Done for 331
# leave whom ?
# (1 (2 (1 leave) (2 whom)) (2 ?))
# , leave what ?
# (2 (2 ,) (2 (1 leave) (2 (2 what) (2 ?))))
# , noooooo i'm feeling veryyyyyyyyyyyyyyyy alone
# (2 (2 ,) (2 (2 (2 noooooo) (2 i)) (2 (2 'm) (2 (2 (2 feeling) (2 veryyyyyyyyyyyyyyyy)) (2 alone)))))
#
# Done for 332
# i was so good , i just wish there was more , hmm
# (3 (3 (2 i) (3 (2 was) (3 (2 so) (3 good)))) (1 (2 ,) (1 (2 i) (1 (2 just) (1 (2 wish) (2 (2 there) (2 (2 (2 (2 was) (2 more)) (2 ,)) (2 hmm))))))))
#
# Done for 333
# i really love it , thanks!!
# (3 (2 i) (3 (3 (3 (2 really) (2 (4 love) (2 it))) (2 ,)) (3 (3 thanks) (2 !!))))
# glad you liked it!!
# (3 (2 glad) (3 (2 you) (3 (3 liked) (2 (2 it) (2 !!)))))
# , please come
# (2 (2 ,) (3 (2 please) (2 come)))
#
# Done for 334
# even you wanna break up with me , then say bluntly , what's stopping you ?
# (1 (1 (1 (2 even) (2 (2 you) (2 (1 wan) (2 (2 na) (2 (2 (2 break) (2 up)) (2 (2 with) (3 me))))))) (2 (2 ,) (2 (2 then) (2 (2 say) (2 bluntly))))) (2 (2 ,) (2 (2 what) (2 (2 (2 's) (2 (2 stopping) (2 you))) (2 ?)))))
# , it's just , you know , sad
# (2 (2 ,) (2 (2 it) (2 (2 (2 (2 's) (2 just)) (2 (2 ,) (2 (2 (2 you) (2 know)) (2 ,)))) (1 sad))))
#
# Done for 335
# oh really , yes yes , so what about me
# (1 (2 (2 (2 oh) (3 (2 really) (2 (2 ,) (2 (2 (2 yes) (2 yes)) (2 ,))))) (2 (2 so) (2 (2 what) (2 about)))) (3 me))
#
# Done for 336
# what you deal ?
# (2 (2 what) (2 (2 (2 you) (2 deal)) (2 ?)))
# , how r u alive ?
# (2 (2 ,) (2 (2 how) (2 (2 r) (2 (2 u) (2 (3 alive) (2 ?))))))
# !
# (2 !)
# , on food
# (2 (2 ,) (2 (2 on) (2 food)))
#
# Done for 337

# %%
from gensim.models.wrappers import FastText
mod = FastText.load_fasttext_format('/home/bt1/17CS10037/taddhita/cc.en.300.bin', encoding="utf8")


'''
    ##########################################################
    ##########################################################
    
    Fasttext model being loaded here. It might take 1 min to load.
    This bin file is of 10mb you can look for 5 gb variant of it.
    Also download the 300d English language '.bin' file not '.vec' file.
    
    ##########################################################
    ##########################################################
'''

# %%
def getEmbeddingMatrix(wordIndex):
    """Populate an embedding matrix using a word-index. If the word "happy" has an index 19,
       the 19th row in the embedding matrix should contain the embedding vector for the word "happy".
    Input:
        wordIndex : A dictionary of (word : index) pairs, extracted using a tokeniser
    Output:
        embeddingMatrix : A matrix where every row has 100 dimensional GloVe embedding
    """
    
    # Minimum word index of any word is 1. 
    '''
    ##########################################################
    ##########################################################
    
    If you want to use gloVe model you may use but main purpose of it is to generate wordtovec
    If possible look up for some better library than fasttext.bin file here which can deal with emoji as well
    
    ##########################################################
    ##########################################################
    '''
    i=0
    error_words =[]
    embeddingMatrix = np.zeros((len(wordIndex) + 1, EMBEDDING_DIM))
    for word, i in wordIndex.items():
        try:
            embeddingVector = mod[word]
            embeddingMatrix[i] = embeddingVector    
        except KeyError:
            print(word)
            error_words.append(word)
    print(len(error_words))
    return embeddingMatrix

# def getEmbeddingMatrix(wordIndex):
#     """Populate an embedding matrix using a word-index. If the word "happy" has an index 19,
#        the 19th row in the embedding matrix should contain the embedding vector for the word "happy".
#     Input:
#         wordIndex : A dictionary of (word : index) pairs, extracted using a tokeniser
#     Output:
#         embeddingMatrix : A matrix where every row has 100 dimensional GloVe embedding
#     """
#     embeddingsIndex = {}
#     # Load the embedding vectors from ther GloVe file
#     with io.open(os.path.join(gloveDir, 'glove.6B.100d.txt'), encoding="utf8") as f:
#         for line in f:
#             values = line.split()
#             word = values[0]
#             embeddingVector = np.asarray(values[1:], dtype='float32')
#             embeddingsIndex[word] = embeddingVector
    
#     print('Found %s word vectors.' % len(embeddingsIndex))
#     error_words =[]
#     # Minimum word index of any word is 1. 
#     embeddingMatrix = np.zeros((len(wordIndex) + 1, EMBEDDING_DIM))
#     for word, i in wordIndex.items():
#         embeddingVector = embeddingsIndex.get(word)
#         if embeddingVector is not None:
#             # words not found in embedding index will be all-zeros.
#             embeddingMatrix[i] = embeddingVector
#         else
#             print(word)
#             error_words.append(word)
#     print(len(error_words))
#     return embeddingMatrix

# %%
def getMetrics(predictions, ground):
    """Given predicted labels and the respective ground truth labels, display some metrics
    Input: shape [# of samples, NUM_CLASSES]
        predictions : Model output. Every row has 4 decimal values, with the highest belonging to the predicted class
        ground : Ground truth labels, converted to one-hot encodings. A sample belonging to Happy class will be [0, 1, 0, 0]
    Output:
        accuracy : Average accuracy
        microPrecision : Precision calculated on a micro level. Ref - https://datascience.stackexchange.com/questions/15989/micro-average-vs-macro-average-performance-in-a-multiclass-classification-settin/16001
        microRecall : Recall calculated on a micro level
        microF1 : Harmonic mean of microPrecision and microRecall. Higher value implies better classification  
    """
    # [0.1, 0.3 , 0.2, 0.1] -> [0, 1, 0, 0]
    discretePredictions = to_categorical(predictions.argmax(axis=1))
    
    truePositives = np.sum(discretePredictions*ground, axis=0)
    falsePositives = np.sum(np.clip(discretePredictions - ground, 0, 1), axis=0)
    falseNegatives = np.sum(np.clip(ground-discretePredictions, 0, 1), axis=0)
    '''
    ##########################################################
    ##########################################################
    
    IMPORTANT
    Please add  code here or somewhere else to print the TruePositives,FalsePositives,FalseNegatives
    
    ##########################################################
    ##########################################################
    '''
    
    print("True Positives per class : ", truePositives)
    print("False Positives per class : ", falsePositives)
    print("False Negatives per class : ", falseNegatives)
    
    # ------------- Macro level calculation ---------------
    macroPrecision = 0
    macroRecall = 0
    # We ignore the "Others" class during the calculation of Precision, Recall and F1
    for c in range(1, NUM_CLASSES):
        precision = truePositives[c] / (truePositives[c] + falsePositives[c])
        macroPrecision += precision
        recall = truePositives[c] / (truePositives[c] + falseNegatives[c])
        macroRecall += recall
        f1 = ( 2 * recall * precision ) / (precision + recall) if (precision+recall) > 0 else 0
        print("Class %s : Precision : %.3f, Recall : %.3f, F1 : %.3f" % (label2emotion[c], precision, recall, f1))
    
    macroPrecision /= 3
    macroRecall /= 3
    macroF1 = (2 * macroRecall * macroPrecision ) / (macroPrecision + macroRecall) if (macroPrecision+macroRecall) > 0 else 0
    print("Ignoring the Others class, Macro Precision : %.4f, Macro Recall : %.4f, Macro F1 : %.4f" % (macroPrecision, macroRecall, macroF1))   
    
    # ------------- Micro level calculation ---------------
    truePositives = truePositives[1:].sum()
    falsePositives = falsePositives[1:].sum()
    falseNegatives = falseNegatives[1:].sum()    
    
    print("Ignoring the Others class, Micro TP : %d, FP : %d, FN : %d" % (truePositives, falsePositives, falseNegatives))
    
    microPrecision = truePositives / (truePositives + falsePositives)
    microRecall = truePositives / (truePositives + falseNegatives)
    
    microF1 = ( 2 * microRecall * microPrecision ) / (microPrecision + microRecall) if (microPrecision+microRecall) > 0 else 0
    # -----------------------------------------------------
    
    predictions = predictions.argmax(axis=1)
    ground = ground.argmax(axis=1)
    accuracy = np.mean(predictions==ground)
    
    print("Accuracy : %.4f, Micro Precision : %.4f, Micro Recall : %.4f, Micro F1 : %.4f" % (accuracy, microPrecision, microRecall, microF1))
    return accuracy, microPrecision, microRecall, microF1

# %%
def writeNormalisedData(dataFilePath, texts):
    """Write normalised data to a file
    Input:
        dataFilePath : Path to original train/test file that has been processed
        texts : List containing the normalised 3 turn conversations, separated by the <eos> tag.
    """
    
    '''
    ##########################################################
    ##########################################################
    
    You May ignore this function
    
    ##########################################################
    ##########################################################
    '''
    normalisedDataFilePath = dataFilePath.replace(".txt", "_normalised.txt")
    with io.open(normalisedDataFilePath, 'w', encoding='utf8') as fout:
        with io.open(dataFilePath, encoding='utf8') as fin:
            fin.readline()
            for lineNum, line in enumerate(fin):
                line = line.strip().split('\t')
                normalisedLine = texts[lineNum].strip().split('<eos>')
                fout.write(line[0] + '\t')
                # Write the original turn, followed by the normalised version of the same turn
                fout.write(line[1] + '\t' + normalisedLine[0] + '\t')
                fout.write(line[2] + '\t' + normalisedLine[1] + '\t')
                fout.write(line[3] + '\t' + normalisedLine[2] + '\t')
                try:
                    # If label information available (train time)
                    fout.write(line[4] + '\n')    
                except:
                    # If label information not available (test time)
                    fout.write('\n')

# %%
    '''
    ##########################################################
    ##########################################################
    
    Simple function calling.
    
    ##########################################################
    ##########################################################
    '''
    print("Processing training data...")
    trainIndices, trainTexts, labels = preprocessData(trainDataPath, mode="train")
    print(labels[:5])
    print(np.asarray(labels[:5]))
    labels = to_categorical(np.asarray(labels))
    print(labels[:5])
    # Write normalised text to file to check if normalisation works. Disabled now. Uncomment following line to enable   
    #writeNormalisedData(trainDataPath, trainTexts)
    print("Processing test data...")
    testIndices, testTexts = preprocessData(testDataPath, mode="test")
    #writeNormalisedData(testDataPath, testTexts)

    print("Extracting tokens...")
    tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
    tokenizer.fit_on_texts(trainTexts)
    trainSequences = tokenizer.texts_to_sequences(trainTexts)
    testSequences = tokenizer.texts_to_sequences(testTexts)

    wordIndex = tokenizer.word_index
    print("Found %s unique tokens." % len(wordIndex))

    print("Populating embedding matrix...")
    embeddingMatrix = getEmbeddingMatrix(wordIndex)

    data = pad_sequences(trainSequences, maxlen=MAX_SEQUENCE_LENGTH)
    
    print("Shape of training data tensor: ", data.shape)
    print("Shape of label tensor: ", labels.shape)
        
    # Randomize data
    np.random.shuffle(trainIndices)
    data = data[trainIndices]
    labels = labels[trainIndices]
      
    # Perform k-fold cross validation
    metrics = {"accuracy" : [],
               "microPrecision" : [],
               "microRecall" : [],
               "microF1" : []}
# Out:
# Processing training data...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-361c237c1717> in <module>
#       9 '''
#      10 print("Processing training data...")
# ---> 11 trainIndices, trainTexts, labels = preprocessData(trainDataPath, mode="train")
#      12 print(labels[:5])
#      13 print(np.asarray(labels[:5]))
#
# <ipython-input-13-54294be091b8> in preprocessData(dataFilePath, mode)
#      26     labels = []
#      27     i=0
# ---> 28     with io.open(dataFilePath, encoding="utf8") as finput:
#      29         finput.readline()
#      30         for line in finput:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train.txt'

# %%
 '''
    ##########################################################
    ##########################################################
    
    Build model
    
    ##########################################################
    ##########################################################
    '''
def buildModel(embeddingMatrix):
    """Constructs the architecture of the model
    Input:
        embeddingMatrix : The embedding matrix to be loaded in the embedding layer.
    Output:
        model : A basic LSTM model
    """
    embeddingLayer = Embedding(embeddingMatrix.shape[0],
                                EMBEDDING_DIM,
                                weights=[embeddingMatrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)
    model = Sequential()
    model.add(embeddingLayer)
    model.add(LSTM(LSTM_DIM, dropout=DROPOUT))
    model.add(Dense(NUM_CLASSES, activation='sigmoid'))
    
    rmsprop = optimizers.rmsprop(lr=LEARNING_RATE)
    model.compile(loss='categorical_crossentropy',
                  optimizer=rmsprop,
                  metrics=['acc'])
    return model

# %%
    '''
    ##########################################################
    ##########################################################
    
    IMPORTANT
    doing k-fold validation and it will take time to execute maybe an hour or two
    Please analyse TruePositives,FalsePositives,FalseNegatives to gain insights why model is not working
    
    ##########################################################
    ##########################################################
    '''
    print("Starting k-fold cross validation...")
    for k in range(NUM_FOLDS):
        print('-'*40)
        print("Fold %d/%d" % (k+1, NUM_FOLDS))
        validationSize = int(len(data)/NUM_FOLDS)
        index1 = validationSize * k
        index2 = validationSize * (k+1)
            
        xTrain = np.vstack((data[:index1],data[index2:]))
        yTrain = np.vstack((labels[:index1],labels[index2:]))
        xVal = data[index1:index2]
        yVal = labels[index1:index2]
        print("Building model...")
        model = buildModel(embeddingMatrix)
        model.fit(xTrain, yTrain, 
                  validation_data=(xVal, yVal),
                  epochs=NUM_EPOCHS, batch_size=BATCH_SIZE)

        predictions = model.predict(xVal, batch_size=BATCH_SIZE)
        accuracy, microPrecision, microRecall, microF1 = getMetrics(predictions, yVal)
        metrics["accuracy"].append(accuracy)
        metrics["microPrecision"].append(microPrecision)
        metrics["microRecall"].append(microRecall)
        metrics["microF1"].append(microF1)
# Out:
# Starting k-fold cross validation...
# ----------------------------------------
# Fold 1/5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-aa8504ffdcc8> in <module>
#      14     print('-'*40)
#      15     print("Fold %d/%d" % (k+1, NUM_FOLDS))
# ---> 16     validationSize = int(len(data)/NUM_FOLDS)
#      17     index1 = validationSize * k
#      18     index2 = validationSize * (k+1)
#
# NameError: name 'data' is not defined

# %%
        
print("\n============= Metrics =================")
print("Average Cross-Validation Accuracy : %.4f" % (sum(metrics["accuracy"])/len(metrics["accuracy"])))
print("Average Cross-Validation Micro Precision : %.4f" % (sum(metrics["microPrecision"])/len(metrics["microPrecision"])))
print("Average Cross-Validation Micro Recall : %.4f" % (sum(metrics["microRecall"])/len(metrics["microRecall"])))
print("Average Cross-Validation Micro F1 : %.4f" % (sum(metrics["microF1"])/len(metrics["microF1"])))
    
print("\n======================================")
    
print("Retraining model on entire data to create solution file")
model = buildModel(embeddingMatrix)
model.fit(data, labels, epochs=NUM_EPOCHS, batch_size=BATCH_SIZE)
model.save('EP%d_LR%de-5_LDim%d_BS%d.h5'%(NUM_EPOCHS, int(LEARNING_RATE*(10**5)), LSTM_DIM, BATCH_SIZE))
# model = load_model('EP%d_LR%de-5_LDim%d_BS%d.h5'%(NUM_EPOCHS, int(LEARNING_RATE*(10**5)), LSTM_DIM, BATCH_SIZE))
# Out:
# ============= Metrics =================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-b89ce7afacb9> in <module>
#       1
#       2 print("\n============= Metrics =================")
# ----> 3 print("Average Cross-Validation Accuracy : %.4f" % (sum(metrics["accuracy"])/len(metrics["accuracy"])))
#       4 print("Average Cross-Validation Micro Precision : %.4f" % (sum(metrics["microPrecision"])/len(metrics["microPrecision"])))
#       5 print("Average Cross-Validation Micro Recall : %.4f" % (sum(metrics["microRecall"])/len(metrics["microRecall"])))
#
# NameError: name 'metrics' is not defined

# %%
    '''
    ##########################################################
    ##########################################################
    
    Prediction on dev-set
    
    ##########################################################
    ##########################################################
    '''
    print("Creating solution file...")
    testData = pad_sequences(testSequences, maxlen=MAX_SEQUENCE_LENGTH)
    predictions = model.predict(testData, batch_size=BATCH_SIZE)
    predictions = predictions.argmax(axis=1)
# Out:
# Creating solution file...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-509a455c06d9> in <module>
#       9 '''
#      10 print("Creating solution file...")
# ---> 11 testData = pad_sequences(testSequences, maxlen=MAX_SEQUENCE_LENGTH)
#      12 predictions = model.predict(testData, batch_size=BATCH_SIZE)
#      13 predictions = predictions.argmax(axis=1)
#
# NameError: name 'testSequences' is not defined

# %%
    '''
    ##########################################################
    ##########################################################
    
    Dont modify it.It writes the txt file which is needed to submit at the site
    
    ##########################################################
    ##########################################################
    '''
    with io.open(solutionPath, "w", encoding="utf8") as fout:
        fout.write(unicode('\t'.join(["id", "turn1", "turn2", "turn3", "label"]) + '\n'))        
        with io.open(testDataPath, encoding="utf8") as fin:
            fin.readline()
            for lineNum, line in enumerate(fin):
                fout.write('\t'.join(line.strip().split('\t')[:4]) + '\t')
                fout.write(unicode(label2emotion[predictions[lineNum]] + '\n'))
    print("Completed. Model parameters: ")
    print("Learning rate : %.3f, LSTM Dim : %d, Dropout : %.3f, Batch_size : %d" 
          % (LEARNING_RATE, LSTM_DIM, DROPOUT, BATCH_SIZE))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-120-55cd1361ffc7> in <module>
#       9 '''
#      10 with io.open(solutionPath, "w", encoding="utf8") as fout:
# ---> 11     fout.write(unicode('\t'.join(["id", "turn1", "turn2", "turn3", "label"]) + '\n'))
#      12     with io.open(testDataPath, encoding="utf8") as fin:
#      13         fin.readline()
#
# NameError: name 'unicode' is not defined
