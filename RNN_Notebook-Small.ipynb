# %%
import sys
import os
import io
import numpy as np
import matplotlib.pyplot as plt
import math
import time
import itertools
import shutil
import re
import tensorflow as tf
from tree import *
import numpy as np
from keras.preprocessing.text import Tokenizer
from utils import Vocab
from keras.utils import to_categorical
from gensim.models.wrappers import FastText
# Out:
# Using TensorFlow backend.

# %%
trainDataPath = "Recursive-neural-networks-TensorFlow/train.txt"
testDataPath = "test_o.txt"
# Output file that will be generated. This file can be directly submitted.
solutionPath = "tests.txt"
# Path to directory where GloVe file is saved.
gloveDir = "/home/bt1/17CS10037/starterkit/glove"
NUM_FOLDS = 5   # Number of classes - Happy, Sad, Angry, Others
MAX_SEQUENCE_LENGTH = 100 
MAX_NB_WORDS = 20000        # All sentences having lesser number of words than this will be padded
EMBEDDING_DIM = 300               # The dimension of the word embeddings

# %%
label2emotion = {0:"others", 1:"happy", 2: "sad", 3:"angry"}
emotion2label = {"others":0, "happy":1, "sad":2, "angry":3}
def getMetrics(predictions, ground):
    """Given predicted labels and the respective ground truth labels, display some metrics
    Input: shape [# of samples, NUM_CLASSES]
        predictions : Model output. Every row has 4 decimal values, with the highest belonging to the predicted class
        ground : Ground truth labels, converted to one-hot encodings. A sample belonging to Happy class will be [0, 1, 0, 0]
    Output:
        accuracy : Average accuracy
        microPrecision : Precision calculated on a micro level. Ref - https://datascience.stackexchange.com/questions/15989/micro-average-vs-macro-average-performance-in-a-multiclass-classification-settin/16001
        microRecall : Recall calculated on a micro level
        microF1 : Harmonic mean of microPrecision and microRecall. Higher value implies better classification  
    """
    # [0.1, 0.3 , 0.2, 0.1] -> [0, 1, 0, 0]
    discretePredictions = to_categorical(predictions.argmax(axis=1))
    
    truePositives = np.sum(discretePredictions*ground, axis=0)
    falsePositives = np.sum(np.clip(discretePredictions - ground, 0, 1), axis=0)
    falseNegatives = np.sum(np.clip(ground-discretePredictions, 0, 1), axis=0)
    '''
    ##########################################################
    ##########################################################
    
    IMPORTANT
    Please add  code here or somewhere else to print the TruePositives,FalsePositives,FalseNegatives
    
    ##########################################################
    ##########################################################
    '''
    
    print("True Positives per class : ", truePositives)
    print("False Positives per class : ", falsePositives)
    print("False Negatives per class : ", falseNegatives)
    
    # ------------- Macro level calculation ---------------
    macroPrecision = 0
    macroRecall = 0
    # We ignore the "Others" class during the calculation of Precision, Recall and F1
    for c in range(1, NUM_CLASSES):
        precision = truePositives[c] / (truePositives[c] + falsePositives[c])
        macroPrecision += precision
        recall = truePositives[c] / (truePositives[c] + falseNegatives[c])
        macroRecall += recall
        f1 = ( 2 * recall * precision ) / (precision + recall) if (precision+recall) > 0 else 0
        print("Class %s : Precision : %.3f, Recall : %.3f, F1 : %.3f" % (label2emotion[c], precision, recall, f1))
    
    macroPrecision /= 3
    macroRecall /= 3
    macroF1 = (2 * macroRecall * macroPrecision ) / (macroPrecision + macroRecall) if (macroPrecision+macroRecall) > 0 else 0
    print("Ignoring the Others class, Macro Precision : %.4f, Macro Recall : %.4f, Macro F1 : %.4f" % (macroPrecision, macroRecall, macroF1))   
    
    # ------------- Micro level calculation ---------------
    truePositives = truePositives[1:].sum()
    falsePositives = falsePositives[1:].sum()
    falseNegatives = falseNegatives[1:].sum()    
    
    print("Ignoring the Others class, Micro TP : %d, FP : %d, FN : %d" % (truePositives, falsePositives, falseNegatives))
    
    microPrecision = truePositives / (truePositives + falsePositives)
    microRecall = truePositives / (truePositives + falseNegatives)
    
    microF1 = ( 2 * microRecall * microPrecision ) / (microPrecision + microRecall) if (microPrecision+microRecall) > 0 else 0
    # -----------------------------------------------------
    
    predictions = predictions.argmax(axis=1)
    ground = ground.argmax(axis=1)
    accuracy = np.mean(predictions==ground)
    
    print("Accuracy : %.4f, Micro Precision : %.4f, Micro Recall : %.4f, Micro F1 : %.4f" % (accuracy, microPrecision, microRecall, microF1))
    return accuracy, microPrecision, microRecall, microF1

def writeNormalisedData(dataFilePath, texts):
    """Write normalised data to a file
    Input:
        dataFilePath : Path to original train/test file that has been processed
        texts : List containing the normalised 3 turn conversations, separated by the <eos> tag.
    """
    
    '''
    ##########################################################
    ##########################################################
    
    You May ignore this function
    
    ##########################################################
    ##########################################################
    '''
    normalisedDataFilePath = dataFilePath.replace(".txt", "_normalised.txt")
    with io.open(normalisedDataFilePath, 'w', encoding='utf8') as fout:
        with io.open(dataFilePath, encoding='utf8') as fin:
            fin.readline()
            for lineNum, line in enumerate(fin):
                line = line.strip().split('\t')
                normalisedLine = texts[lineNum].strip().split('<eos>')
                fout.write(line[0] + '\t')
                # Write the original turn, followed by the normalised version of the same turn
                fout.write(line[1] + '\t' + normalisedLine[0] + '\t')
                fout.write(line[2] + '\t' + normalisedLine[1] + '\t')
                fout.write(line[3] + '\t' + normalisedLine[2] + '\t')
                try:
                    # If label information available (train time)
                    fout.write(line[4] + '\n')    
                except:
                    # If label information not available (test time)
                    fout.write('\n')

def getEmbeddingMatrix(wordIndex):
    """Populate an embedding matrix using a word-index. If the word "happy" has an index 19,
       the 19th row in the embedding matrix should contain the embedding vector for the word "happy".
    Input:
        wordIndex : A dictionary of (word : index) pairs, extracted using a tokeniser
    Output:
        embeddingMatrix : A matrix where every row has 100 dimensional GloVe embedding
    """
    embeddingsIndex = {}
    # Load the embedding vectors from ther GloVe file
    with io.open(os.path.join(gloveDir, 'glove.6B.300d.txt'), encoding="utf8") as f:
        for line in f:
            values = line.split()
            word = values[0]
            embeddingVector = np.asarray(values[1:], dtype='float32')
            embeddingsIndex[word] = embeddingVector
    
    print('Found %s word vectors.' % len(embeddingsIndex))
    
    # Minimum word index of any word is 1. 
    embeddingMatrix = np.zeros((len(wordIndex) + 1, EMBEDDING_DIM))
    for word, i in wordIndex.items():
        embeddingVector = embeddingsIndex.get(word)
        if embeddingVector is not None:
            # words not found in embedding index will be all-zeros.
            embeddingMatrix[i] = embeddingVector
    
    return embeddingMatrix

# %%
import emoji
import regex

def split_count(text):

    emoji_list = []
    data = regex.findall(r'\X', text)
    for word in data:
        if any(char in emoji.UNICODE_EMOJI for char in word):
            emoji_list.append(word)

    return emoji_list

line1 = ["🤔 🙈 me así, se 😌 ds 💕👭👙 hello 👩🎓 emoji hello  how are 😊 you today🙅🏽🙅🏽"]
line=["money money and lots of money😍😍"]

counter = split_count(line[0])
print(counter)
emojis = split_count(line1[0])
for c in emojis:
    lineSplit = line1[0].split(c)
    while True:
        try:
            lineSplit.remove('')
        except:
            break
    cSpace = ' ' + emoji.UNICODE_EMOJI[c] + ' '    
    line1[0] = cSpace.join(lineSplit)
print(line1[0])
# Out:
# ['😍', '😍']
#   :see-no-evil_monkey:  me así, se  :relieved_face:  ds  :two_hearts:  :two_women_holding_hands:  :bikini:  hello  :woman:  :graduation_cap:  emoji hello  how are  :smiling_face_with_smiling_eyes:  you today

# %%
import csv

# %%
def translator(user_string):
    user_string = user_string.split(" ")
    j = 0
    for _str in user_string:
        # File path which consists of Abbreviations.
        fileName = "slang.txt"
        # File Access mode [Read Mode]
        accessMode = "r"
        with open(fileName, accessMode) as myCSVfile:
            # Reading file as CSV with delimiter as "=", so that abbreviation are stored in row[0] and phrases in row[1]
            dataFromFile = csv.reader(myCSVfile, delimiter="=")
            # Removing Special Characters.
            _str = re.sub('[^a-zA-Z0-9-_.]', '', _str)
            for row in dataFromFile:
                # Check if selected word matches short forms[LHS] in text file.
                if _str.upper() == row[0]:
                    # If match found replace it with its appropriate phrase in text file.
                    user_string[j] = row[1]
            myCSVfile.close()
        j = j + 1
    # Replacing commas with spaces for final output.
    a = ' '.join(user_string)
    print('')
    str = j
    return a

# %%
def preprocessData(dataFilePath, mode):
    """Load data from a file, process and return indices, conversations and labels in separate lists
    Input:
        dataFilePath : Path to train/test file to be processed
        mode : "train" mode returns labels. "test" mode doesn't return labels.
    Output:
        indices : Unique conversation ID list
        conversations : List of 3 turn conversations, processed and each turn separated by the <eos> tag
        labels : [Only available in "train" mode] List of labels
    """
    
    '''
    ##########################################################
    ##########################################################
    
    IMPORTANT
    Please try to better the pre-processing here by sepearting the emojis with text like  "hmm😞", "now‼‼‼😣😤😤" & etc.
    Also look for other methods.
    
    ##########################################################
    ##########################################################
    '''
    indices = []
    conversations = []
    labels = []
    i=0

    if mode=='train':
        open("train_trees.ptb", "w").close()
    else:
        open("test_trees.ptb", "w").close()

    with open('../stanford-corenlp-full-2018-10-05/output.txt','w') as f:
        f.write("")

    
    with io.open(dataFilePath, encoding="utf8") as finput:
        finput.readline()
        for line in finput:
            i+=1
            
            # Convert multiple instances of . ? ! , to single instance
            # okay...sure -> okay . sure
            # okay???sure -> okay ? sure
            # Add whitespace around such punctuation
            # okay!sure -> okay ! sure
#             print(line)
            emojis = split_count(line)
            repeatedChars = ['.']
            repeatedChars.append('?')
            repeatedChars.append(',')
            repeatedChars.append('_')
            repeatedChars.append(':')
            repeatedChars.append('-')
            repeatedChars.append(';')
            repeatedChars.append('&')
            repeatedChars.append('#')
            for c in emojis:
                lineSplit = line.split(c)
                while True:
                    try:
                        lineSplit.remove('')
                    except:
                        break
                cSpace = ' '    
                line = cSpace.join(lineSplit)
            for c in repeatedChars:
                lineSplit = line.split(c)
                while True:
                    try:
                        lineSplit.remove('')
                    except:
                        break
                cSpace = ' ' + c + ' '    
                line = cSpace.join(lineSplit)
            
            line = line.strip().split('\t')
            print(line)
            if mode == "train":
                # Train data contains id, 3 turns and label
                label = emotion2label[line[4]]
                labels.append(label)
            
            conv = ' <eos> '.join(line[1:4])
            

#             print(conv)
#             print("#######Conv Over######")
            # Remove any duplicate spaces
            duplicateSpacePattern = re.compile(r'\ +')
            conv = (re.sub(duplicateSpacePattern, ' ', conv)).lower()
            conv = translator(conv)
            indices.append(int(line[0]))
#             print(conv)
            if mode == "train":
                tree = text_to_ptb(line[4], conv, mode)
            else:
                tree = text_to_ptb("", conv, mode)

            conversations.append(tree)
#             print(tree)
#             print(conversations)
#             '''
#             COMMENT OUT THE FOLLOWING 2 LINES BEFORE RUNNING!
#             '''
#             import time 
#             time.sleep(10)
            print("Done for " + str(len(conversations)))

    if mode == "train":
        return indices, conversations, labels
    else:
        return indices, conversations

# %%
def text_to_ptb(label, text, mode):
    dir_path = os.path.dirname(os.path.abspath('__file__'))
    temp_write_out = '../stanford-corenlp-full-2018-10-05/input.txt'
    temp_read_tree = '../stanford-corenlp-full-2018-10-05/output.txt'
    tree = ''

#     print(text)
    print(" ")    
    print(text.replace('<eos>',',').replace('.',',').replace('?','').replace('!',' very'))

    with open(temp_write_out,'w') as f:
        f.write(text.replace('<eos>',',').replace('.',',').replace('?','').replace('!',' very'))

    os.system("cd ~/stanford-corenlp-full-2018-10-05 && java -Xmx8g edu.stanford.nlp.sentiment.SentimentPipeline -file input.txt -output PENNTREES > output.txt")

    with open(temp_read_tree, 'r') as f2:
        tree = f2.read()
    
    if mode == 'train':
        with open('train_trees.ptb','a') as f3:
            f3.write(label + " " + (" ").join((tree.split("\n"))[1:]) + "\n")
    else:
        with open('test_trees.ptb','a') as f3:
            f3.write(label + " " + (" ").join((tree.split("\n"))[1:]) + "\n")
    
#     print(tree)
    return (tree)

# %%
trainIndices, trainTexts, labels = preprocessData(trainDataPath, mode="train")
# Out:
# ['0', "Don't worry  I'm girl", 'hmm how do I know if you are', "What's ur name ? ", 'others']
#
#
# don't worry i'm girl   okay how do i know if you are   what's  your name
# Done for 1
# ['1', 'When did I ? ', 'saw many times i think  -  _  - ', 'No .  I never saw you', 'angry']
#
#
# when did i    saw many times i think - _ -   no , i never saw you
# Done for 2
# ['2', 'By', 'by Google Chrome', 'Where you live', 'others']
#
#
# by   by google chrome   where you live
# Done for 3
# ['3', 'U r ridiculous', 'I might be ridiculous but I am telling the truth . ', 'U little disgusting whore', 'angry']
#
#
# You are ridiculous   i might be ridiculous but i am telling the truth ,   You little disgusting whore
# Done for 4
# ['4', 'Just for time pass', 'wt do u do 4 a living then', 'Maybe', 'others']
#
#
# just for time pass   wt do You do for a living then   maybe
# Done for 5
# ['5', "I'm a dog person", 'youre so rude', 'Whaaaat why', 'others']
#
#
# i'm a dog person   youre so rude   whaaaat why
# Done for 6
# ['6', 'So whatsup', 'Nothing much .  Sitting sipping and watching TV .  How abt u ? ', 'What are you watching on tv ? ', 'others']
#
#
# so whatsup   nothing much , sitting sipping and watching tv , how About You    what are you watching on tv
# Done for 7
# ['7', 'Ok', 'ok im back!!', 'So ,  how are u', 'others']
#
#
# ok   ok im back very very   so , how are You
# Done for 8
# ['8', 'Really ? ', 'really really really really really', 'Y saying so many times . i can hear you', 'others']
#
#
# really    really really really really really   Yawn saying so many times , i can hear you
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-42bf575eed7a> in <module>
# ----> 1 trainIndices, trainTexts, labels = preprocessData(trainDataPath, mode="train")
#
# <ipython-input-19-f7339534f6c9> in preprocessData(dataFilePath, mode)
#      94 #             print(conv)
#      95             if mode == "train":
# ---> 96                 tree = text_to_ptb(line[4], conv)
#      97             else:
#      98                 tree = text_to_ptb("", conv)
#
# <ipython-input-20-7879c168ce89> in text_to_ptb(label, text)
#      10
#      11     with open(temp_write_out,'w') as f:
# ---> 12         f.write(text.replace('<eos>',',').replace('.',',').replace('?','').replace('!',' very'))
#      13
#      14     os.system("cd ~/stanford-corenlp-full-2018-10-05 && java -Xmx8g edu.stanford.nlp.sentiment.SentimentPipeline -file input.txt -output PENNTREES > output.txt")
#
# KeyboardInterrupt:

# %%
trainTexts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-98622f088b1c> in <module>
# ----> 1 trainTexts
#
# NameError: name 'trainTexts' is not defined

# %%
from gensim.models.wrappers import FastText
mod = FastText.load_fasttext_format('/home/bt1/17CS10037/taddhita/cc.en.300.bin', encoding="utf8")

# %%
def getEmbeddingMatrix(wordIndex):
    
    i=0
    error_words =[]
    embeddingMatrix = np.zeros((len(wordIndex) + 1, EMBEDDING_DIM))
    for word, i in wordIndex.items():
        try:
            embeddingVector = mod[word]
            embeddingMatrix[i] = embeddingVector    
        except KeyError:
            print(word)
            error_words.append(word)
    print(len(error_words))
    return embeddingMatrix

# %%
labels = to_categorical(np.asarray(labels))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-fe0b04b8bf30> in <module>
# ----> 1 labels = to_categorical(np.asarray(labels))
#
# NameError: name 'labels' is not defined

# %%
embeddingMatrix
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-a6fd09aa5c53> in <module>
# ----> 1 embeddingMatrix
#
# NameError: name 'embeddingMatrix' is not defined

# %%
#     print("Processing training data...")
#     trainIndices, trainTexts, labels = preprocessData(trainDataPath, mode="train")
#     labels = to_categorical(np.asarray(labels))
    # Write normalised text to file to check if normalisation works. Disabled now. Uncomment following line to enable   
    #writeNormalisedData(trainDataPath, trainTexts)
    print("Processing test data...")
    testIndices, testTexts = preprocessData(testDataPath, mode="test")
    #writeNormalisedData(testDataPath, testTexts)

    print("Extracting tokens...")
    tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
    tokenizer.fit_on_texts(trainTexts)
    trainSequences = tokenizer.texts_to_sequences(trainTexts)
    testSequences = tokenizer.texts_to_sequences(testTexts)

    wordIndex = tokenizer.word_index
    print("Found %s unique tokens." % len(wordIndex))

    print("Populating embedding matrix...")
    embeddingMatrix = getEmbeddingMatrix(wordIndex)
# Out:
# Processing test data...
# ['0', 'Then dont ask me', 'YOURE A GUY NOT AS IF YOU WOULD UNDERSTAND', 'IM NOT A GUY FUCK OFF', 'angry']
#
#
# then dont ask me   youre a guy not as if you would understand   im not a guy fuck off
# Done for 1
# ['1', 'Mixed things  such as ? ', 'the things you do . ', 'Have you seen minions ? ', 'others']
#
#
# mixed things such as    the things you do ,   have you seen minions
# Done for 2
# ['2', "Today I'm very happy", "and I'm happy for you  ", 'I will be marry', 'happy']
#
#
# today i'm very happy   and i'm happy for you   i will be marry
# Done for 3
# ['3', 'Woah bring me some', 'left it there oops', 'Brb', 'others']
#
#
# woah bring me some   left it there oops   Be right back
# Done for 4
# ['4', 'it is thooooo', 'I said soon master . ', 'he is pressuring me', 'others']
#
#
# it is thooooo   i said soon master ,   he is pressuring me
# Done for 5
# ['5', 'Wont u ask my age ? ', 'hey at least I age well!', 'Can u tell me how can we get closer ? ', 'others']
#
#
# wont You ask my age    hey at least i age well very   can You tell me how can Whatever get closer
# Done for 6
# ['6', 'I said yes', "What if I told you I'm not ? ", 'Go to hell', 'angry']
#
#
# i said yes   what if i told you i'm not    go to hell
# Done for 7
# ['7', 'Where I ll check', 'why tomorrow ? ', 'No I want now', 'others']
#
#
# where i ll check   why tomorrow    no i want now
# Done for 8
# ['8', 'Shall we meet', "you say -  you're leaving soon . anywhere you wanna go before you head ? ", ' ? ', 'others']
#
#
# shall Whatever meet   you say - you're leaving soon , anywhere you wanna go before you head
# Done for 9
# ['9', "Let's change the subject", 'I just did it  . l . ', "You're broken", 'sad']
#
#
# let's change the subject   i just did it , l ,   you're broken
# Done for 10
# ['10', 'Your  pic  pz', 'thank you X‑D', 'wc', 'others']
#
#
# your Picture Peace   thank you laugh    Welcome
# Done for 11
# ['11', 'not mine', 'done for the day  ? ', 'can my meet to sexy girl', 'others']
#
#
# not mine   done for the day    can my meet to sexy girl
# Done for 12
# ['12', 'I want to play the game', "if you just finished the game .  then you haven't finished the game . ", ' # Emojisong', 'others']
#
#
# i want to play the game   if you just finished the game , then you haven't finished the game ,   # emojisong
# Done for 13
# ['13', 'Iam sory', 'why sorry !  ', 'I insult you', 'angry']
#
#
# iam sory   why sorry  very   i insult you
# Done for 14
# ['14', 'How much', 'depends on how long your internet has been out!!!', 'U have bf', 'others']
#
#
# how much   depends on how long your internet has been out very very very   You have Best friend
# Done for 15
# ['15', 'Ok', 'Thank you .  xD', 'What about cortanan', 'others']
#
#
# ok   thank you , laugh    what about cortanan
# Done for 16
# ['16', 'So the story ? ', 'yeah indeed  ', 'Tomorrow probably', 'others']
#
#
# so the story    yeah indeed   tomorrow probably
# Done for 17
# ['17', 'May be', 'yeaa i hope soo!!', 'Can you do complex calculations', 'others']
#
#
# may be   yeaa i hope soo very very   can you do complex calculations
# Done for 18
# ['18', 'So come on na .  Want u so badly . ', "now you're tempting me to . ", 'So why are you still away from my body ? ', 'angry']
#
#
# so come on na , want You so badly ,   now you're tempting me to ,   so why are you still away from my body
# Done for 19
# ['19', "No you aren't", 'oh I am', 'Really ? ', 'others']
#
#
# no you aren't   Overheard i am   really
# Done for 20
# ['20', 'Are u a one', "I'm the normal one ,  if you want", 'What I want', 'others']
#
#
# are You a one   i'm the normal one , if you want   what i want
# Done for 21
# ['21', 'But . ', 'then', "I'm feeling nervous", 'sad']
#
#
# but ,   then   i'm feeling nervous
# Done for 22
# ['22', 'Send me any video or songs', 'Video or Text', 'S', 'others']
#
#
# send me any video or songs   video or text   s
# Done for 23
# ['23', 'Why', 'why what', 'How r u', 'others']
#
#
# why   why what   how are You
# Done for 24
# ['24', 'Do it', 'but why ? ', 'Aaah  . u lack creativity at some extent', 'others']
#
#
# do it   but why    aaah , You lack creativity at some extent
# Done for 25
# ['25', 'Yeah going out with the parson outside in the city or in the parc', "Yeah .  I don't live in the city .  X", 'So where do you live', 'others']
#
#
# yeah going out with the parson outside in the city or in the parc   yeah , i don't live in the city , x   so where do you live
# Done for 26
# ['26', 'Then go to sleep', 'you never sleep', 'I will', 'others']
#
#
# then go to sleep   you never sleep   i will
# Done for 27
# ['27', "He's very depressed and i want to help him but how should i do . it feels very bad seeing your best friend like this", 'Dance to enjoy ,  not to please . ', 'Ohhhh', 'sad']
#
#
# he's very depressed and i want to help him but how should i do , it feels very bad seeing your best friend like this   dance to enjoy , not to please ,   ohhhh
# Done for 28
# ['28', 'Oh great', 'Yeah do you have any plans for today ? ', "No i don't  have any plan", 'others']
#
#
# Overheard great   yeah do you have any plans for today    no i don't have any plan
# Done for 29
# ['29', "I don't have plans for the weekend . ", 'you did saturday with me but I see how it is', 'What are you talking about ? ', 'others']
#
#
# i don't have plans for the weekend ,   you did saturday with me but i see how it is   what are you talking about
# Done for 30
# ['30', "I don't know", 'why what happen .  ? ', 'Jst asking', 'others']
#
#
# i don't know   why what happen ,    jst asking
# Done for 31
# ['31', "I didn't think so", 'I did .  You are evading', 'What is the meaning', 'others']
#
#
# i didn't think so   i did , you are evading   what is the meaning
# Done for 32
# ['32', 'Really', 'what ? ', 'I love you', 'others']
#
#
# really   what    i love you
# Done for 33
# ['33', 'You', 'how about ur family .  Still single ? ', 'Can you love mi', 'others']
#
#
# you   how about  your family , still single    can you love mi
# Done for 34
# ['34', 'You are also beautiful', 'well thank you  : )', 'Welcome', 'others']
#
#
# you are also beautiful   well thank you : )   welcome
# Done for 35
# ['35', 'Hell', 'im already there xoxo  ', 'Good night sweet dreams baby', 'happy']
#
#
# hell   im already there xoxo   good night sweet dreams baby
# Done for 36
# ['36', 'You are computerised for talk too fast', 'actually my not fast ,  my phone is  : D', 'Ohh sorry', 'sad']
#
#
# you are computerised for talk too fast   actually my not fast , my phone is : d   ohh sorry
# Done for 37
# ['37', 'Really ', 'explain how', 'Hw to explain', 'others']
#
#
# really   explain how   Homework to explain
# Done for 38
# ['38', 'Thanks', "you're welcome  : D", 'I like reply instant ly', 'others']
#
#
# thanks   you're welcome : d   i like reply instant Love ya
# Done for 39
# ['39', 'Ok', " .  tries to ignore pain  : '(", 'Where to go ? ', 'others']
#
#
# ok   , tries to ignore pain : '(   where to go
# Done for 40
# ['40', 'show your tatto', "I don't have one", 'in that case ,  I will show you mine', 'others']
#
#
# show your tatto   i don't have one   in that case , i will show you mine
# Done for 41
# ['41', 'Get lost', 'Or else what  ? ', "I don't need this", 'angry']
#
#
# get lost   or else what    i don't need this
# Done for 42
# ['42', 'So tht u r body can get heat', 'I heat more than that up  ; ]', 'Ok', 'others']
#
#
# so Think happy thoughts You are body can get heat   i heat more than that up ; ]   ok
# Done for 43
# ['43', "Seriously it's boring  sorry to say this", "It's too late to apologize ? ", 'Plz yaar pakaa mat', 'others']
#
#
# seriously it's boring sorry to say this   it's too late to apologize    Please yaar pakaa mat
# Done for 44
# ['44', 'Why!', "Because they are BFF's  ? ", "Who are BFF's", 'others']
#
#
# why very   because they are bff's    who are bff's
# Done for 45
# ['45', 'Make', 'how', "I don't know I think u know", 'others']
#
#
# make   how   i don't know i think You know
# Done for 46
# ['46', 'Quite a while ago', 'months ago', 'Weeks', 'others']
#
#
# quite a while ago   months ago   weeks
# Done for 47
# ['47', 'Sports  ', 'TIL I need to watch more European sports like this . ', "You're an interactive search module right ? ", 'others']
#
#
# sports   Today I learned i need to watch more european sports like this ,   you're an interactive search module right
# Done for 48
# ['48', 'U Ar using what I want to buy to play ', "I'm using 44 as well", "U think is funny Ehn and if you know u cannot get the Dog for me don't joke with it and if you continue with this ur stinginess Allah will judge you", 'others']
#
#
# You ar using what i want to buy to play   i'm using 44 as well   You think is funny ehn and if you know You cannot get the dog for me don't joke with it and if you continue with this  your stinginess allah will judge you
# Done for 49
# ['49', 'u were offering something right ? ', "I don't remember the wrong part . ", 'tell me the correct part', 'others']
#
#
# You were offering something right    i don't remember the wrong part ,   tell me the correct part
# Done for 50
# ['50', "I'm not talking to u anymore", 'what I do ? ', 'Clear ur glitch s', 'angry']
#
#
# i'm not talking to You anymore   what i do    clear  your glitch s
# Done for 51
# ['51', 'Do you study', 'yes gtg ttyl', 'Where are you from', 'others']
#
#
# do you study   yes Got to go Talk to you later   where are you from
# Done for 52
# ['52', 'Okay', 'Hello! How are you ? ', 'Good n u', 'others']
#
#
# okay   hello very how are you    good n You
# Done for 53
# ['53', 'No  . l human', 'Are you sure ? ', 'Yeah', 'others']
#
#
# no , l human   are you sure    yeah
# Done for 54
# ['54', 'Talking to me ? ', "but I didn't help", 'Does that work ? ', 'others']
#
#
# talking to me    but i didn't help   does that work
# Done for 55
# ['55', 'Fight', "I don't fight . ", 'What are you doing', 'others']
#
#
# fight   i don't fight ,   what are you doing
# Done for 56
# ['56', 'I think there is a connection of heart between us', 'Definitely . ', ' ', 'others']
#
#
# i think there is a connection of heart between us   definitely ,
# Done for 57
# ['57', 'I know you are wild pig', 'lol in some areas', 'Yes piggy', 'others']
#
#
# i know you are wild pig   Lots of love in some areas   yes piggy
# Done for 58
# ['58', "No I didn't", 'you watched my story though', 'I did not', 'others']
#
#
# no i didn't   you watched my story though   i did not
# Done for 59
# ['59', "I don't want to go to college", 'do we go back Monday ? ', 'We have an event tomorrow', 'others']
#
#
# i don't want to go to college   do Whatever go back monday    Whatever have an event tomorrow
# Done for 60
# ['60', 'M just keeping u busy', 'work work work', "I don't have rather than study", 'others']
#
#
# m just keeping You busy   work work work   i don't have rather than study
# Done for 61
# ['61', 'Ok', 'U are ok', 'Send me your pic', 'others']
#
#
# ok   You are ok   send me your Picture
# Done for 62
# ['62', 'Ok', 'ok im back!!', 'What time will you back', 'others']
#
#
# ok   ok im back very very   what time will you back
# Done for 63
# ['63', 'ok', 'U are ok~~ay~~', 'dnt u sleeppp at night', 'others']
#
#
# ok   You are ok~~ay~~   Don't You sleeppp at night
# Done for 64
# ['64', 'My mummy is your grandma', "Hey Soul Sister on Repeat <3  : ')", 'Why bc', 'others']
#
#
# my mummy is your grandma   hey soul sister on repeat <3 : ')   why Be cool
# Done for 65
# ['65', 'I said ahow', 'You said wrong', 'Show', 'others']
#
#
# i said ahow   you said wrong   show
# Done for 66
# ['66', 'Ntg buddy', 'im here for you', 'Oh thank you very much buddy', 'happy']
#
#
# ntg buddy   im here for you   Overheard thank you very much buddy
# Done for 67
# ['67', 'What is DCAC ? ', 'A B .  A . ', 'Oh plz stop thiz . ', 'others']
#
#
# what is dcac    a Be , a ,   Overheard Please stop thiz ,
# Done for 68
# ['68', 'My relationship', 'What happened ? ', "Nothing's happening as expected", 'others']
#
#
# my relationship   what happened    nothing's happening as expected
# Done for 69
# ['69', "No I'm not haha on your face", 'haha ,  then better take every step carefully', 'Oops sorry !!', 'angry']
#
#
# no i'm not haha on your face   haha , then better take every step carefully   oops sorry  very very
# Done for 70
# ['70', 'I m also back semd your photo', "I'm the photographer ,  not the model ,  but I'll pass the compliments on . ", 'Ok', 'others']
#
#
# i m also back semd your photo   i'm the photographer , not the model , but I Will pass the compliments on ,   ok
# Done for 71
# ['71', 'Where are we going ? ', "We are humans ,  descended from apes ,  and we're going to Walmart . ", 'Wow .  Such a great explanation', 'happy']
#
#
# where are Whatever going    Whatever are humans , descended from apes , and we're going to walmart ,   wow , such a great explanation
# Done for 72
# ['72', 'That will be entertaining bey', "I'll think on ur entertaining performance", 'Do you have a face ? ', 'others']
#
#
# that will be entertaining bey   I Will think on  your entertaining performance   do you have a face
# Done for 73
# ['73', 'Me too ', 'AT LEAST SOMEONE KNOWS', 'You are from', 'others']
#
#
# me too   at least someone knows   you are from
# Done for 74
# ['74', 'And I am also prince charming', 'I will be too . ', 'Can you send me yur pic', 'others']
#
#
# and i am also prince charming   i will be too ,   can you send me yur Picture
# Done for 75
# ['75', 'Why', "Because I'd rather go to the Oval  : )", 'Would u come on a bikini or nude', 'others']
#
#
# why   because i'd rather go to the oval : )   would You come on a bikini or nude
# Done for 76
# ['76', 'My video very very good', 'thanks buddy  ?   ; ^)', 'Thank you good night', 'others']
#
#
# my video very very good   thanks buddy  ; ^)   thank you good night
# Done for 77
# ['77', 'Yes', 'hmmmmmm . ', "And instead of having fun ,  I've been in the house all of Friday night", 'others']
#
#
# yes   hmmmmmm ,   and instead of having fun , I Have been in the house all of friday night
# Done for 78
# ['78', "I'm good  &  u", "i'm fine! what are you doing ? ", 'Nothing', 'others']
#
#
# i'm good & You   i'm fine very what are you doing    nothing
# Done for 79
# ['79', 'Okay', 'Here we go again . ', 'R u ready  ? ', 'others']
#
#
# okay   here Whatever go again ,   are You ready
# Done for 80
# ['80', 'ur the B(*(**thing here', "we'll have to do something before you go back to school", 'its sunday idiot', 'angry']
#
#
#  your the b(*(**thing here   we'll have to do something before you go back to school   its sunday idiot
# Done for 81
# ['81', 'What the fuck ? ', "Still don't get the joke", 'I am not', 'others']
#
#
# what the fuck    still don't get the joke   i am not
# Done for 82
# ['82', 'So you tell me about your self', "you're the best", 'Yas I am', 'others']
#
#
# so you tell me about your self   you're the best   yas i am
# Done for 83
# ['83', 'Just snap of your', 'yes .  yes I did . ', 'Ok send me', 'others']
#
#
# just snap of your   yes , yes i did ,   ok send me
# Done for 84
# ['84', "I  .  doesn't understtand", "you're weird b", 'How . i . will . married . you 8 . 9 . year', 'others']
#
#
# i , doesn't understtand   you're weird Be   how , i , will , married , you 8 , Parent is watching , year
# Done for 85
# ['85', 'Thank you', "you're welcome", 'I wish you were a real person . ', 'happy']
#
#
# thank you   you're welcome   i wish you were a real person ,
# Done for 86
# ['86', 'Gorgeous  ', 'thank u  ', "Let's go for a date ? !  ", 'others']
#
#
# gorgeous   thank You   let's go for a date   very
# Done for 87
# ['87', 'Nobody is online ? ', 'Say what ? ', 'I just got a broadband connection', 'others']
#
#
# nobody is online    say what    i just got a broadband connection
# Done for 88
# ['88', 'Really she is so cute', 'I know! ^^', 'Do u know someone who is perfect for me', 'others']
#
#
# really she is so cute   i know very ^^   do You know someone who is perfect for me
# Done for 89
# ['89', 'I am botking', 'hmm .  you could have been programmed to say that with the word bot . ', 'I am a real person kinda android', 'happy']
#
#
# i am botking   okay , you could have been programmed to say that with the word Be on that ,   i am a real person kinda android
# Done for 90
# ['90', 'Kk do it', 'yo u wanna start up plug ? ', 'Yes', 'others']
#
#
# Okay, Okay very do it   yo You wanna start up plug    yes
# Done for 91
# ['91', 'What dng babe', 'nothing .   ', 'Had ur dinner', 'others']
#
#
# what dng babe   nothing ,   had  your dinner
# Done for 92
# ['92', 'vaoov i am pleased', 'you are back . ', 'who is your favorite football player ? ', 'others']
#
#
# vaoov i am pleased   you are back ,   who is your favorite football player
# Done for 93
# ['93', 'So what', 'if you say so', 'Tell me a joke', 'others']
#
#
# so what   if you say so   tell me a joke
# Done for 94
# ['94', 'Wht u think to show me', 'its a show called skam', "No I don't know abt that show sry", 'others']
#
#
# wht You think to show me   its a show called skam   no i don't know About that show Sorry
# Done for 95
# ['95', 'I mean wanna go on a dinner with me ? ', 'we could go after bbt  : )', 'Bbt ? ', 'happy']
#
#
# i mean wanna go on a dinner with me    Whatever could go after Be back tomorrow : )   Be back tomorrow
# Done for 96
# ['96', 'My hobbies are to do gym', 'your gym is more expensive than mine!!!', 'So what', 'others']
#
#
# my hobbies are to do gym   your gym is more expensive than mine very very very   so what
# Done for 97
# ['97', 'What u are saying', "Some people like me love everyone but hate everything .  That's what I'm saying . ", 'Tell me what i do', 'others']
#
#
# what You are saying   some people like me love everyone but hate everything , that's what i'm saying ,   tell me what i do
# Done for 98
# ['98', "Ohhh that's nice sense of humor", "Oh shucks .  You've got me blushing .   ", 'Please carry on blushing', 'happy']
#
#
# ohhh that's nice sense of humor   Overheard shucks , you've got me blushing ,   please carry on blushing
# Done for 99
# ['99', 'To chat with you', 'Hello', 'No hello', 'others']
#
#
# to chat with you   hello   no hello
# Done for 100
# ['100', "I don't like watching TV and movies", 'It is absolutely ohk to watch a movie with subtitles switched on . ', 'Ok', 'others']
#
#
# i don't like watching tv and movies   it is absolutely okay to watch a movie with subtitles switched on ,   ok
# Done for 101
# ['101', 'your creation can not be a secret!', 'Is it even still a secret at that point ? ', 'may be not', 'others']
#
#
# your creation can not be a secret very   is it even still a secret at that point    may be not
# Done for 102
# ['102', 'Sorry sorry', "It's okay ,  I think you were busy", 'hectic schedule dear', 'others']
#
#
# sorry sorry   it's okay , i think you were busy   hectic schedule dear
# Done for 103
# ['103', 'who is sophia ? ', 'Prince', 'wrong', 'others']
#
#
# who is sophia    prince   wrong
# Done for 104
# ['104', 'Address first', 'send it . ', 'You send it', 'others']
#
#
# address first   send it ,   you send it
# Done for 105
# ['105', 'super', 'Space', 'ok bye my wife is watching me', 'sad']
#
#
# super   space   ok bye my wife is watching me
# Done for 106
# ['106', 'Skydiving ', 'Especially while skydiving . ', 'Miss u lot', 'others']
#
#
# skydiving   especially while skydiving ,   miss You lot
# Done for 107
# ['107', 'Why not ? ', "I'll be your friend", 'I want you to be my girlfriend', 'others']
#
#
# why not    I Will be your friend   i want you to be my girlfriend
# Done for 108
# ['108', 'love u babe', 'thank youuuu my lovvvee', 'wt els wt are u dong', 'others']
#
#
# love You babe   thank youuuu my lovvvee   wt els wt are You dong
# Done for 109
# ['109', 'Sorry ? ', 'huh too', 'You have some bugs', 'others']
#
#
# sorry    huh too   you have some bugs
# Done for 110
# ['110', 'Ohh ur such decent', 'im a compulsive  : P', 'Fuck ur software then', 'angry']
#
#
# ohh  your such decent   im a compulsive : Partner    fuck  your software then
# Done for 111
# ['111', 'I was waiting you ,  how are you  ? ', "I'm good! How are you ? ", 'nice thks', 'happy']
#
#
# i Wild *a* guess waiting you , how are you    i'm good very how are you    nice thks
# Done for 112
# ['112', 'Somebody wants you', 'hey . how r u ? ', 'We push and pull like a magnet do', 'others']
#
#
# somebody wants you   hey , how are You    Whatever push and pull like a magnet do
# Done for 113
# ['113', 'Same to yr', '2nd yr', 'What you 2nd ur', 'others']
#
#
# same to Yeah right   2nd Yeah right   what you 2nd  your
# Done for 114
# ['114', 'U made me', ' .  what ? ', 'Happy', 'happy']
#
#
# You made me   , what    happy
# Done for 115
# ['115', 'R u sick single', 'forever sick  : P', 'I mean r u single', 'others']
#
#
# are You sick single   forever sick : Partner    i mean are You single
# Done for 116
# ['116', "But I'm right", 'Well ,  obviously', 'Now please change the topic', 'others']
#
#
# but i'm right   well , obviously   now please change the topic
# Done for 117
# ['117', 'Yeah . ', "You don't play games right ? ", 'Yeah i do', 'others']
#
#
# yeah ,   you don't play games right    yeah i do
# Done for 118
# ['118', 'This is not the reply expected  : D', 'Hahaha .  Point  : )', 'you are skipping the track', 'angry']
#
#
# this is not the reply expected : d   hahaha , point : )   you are skipping the track
# Done for 119
# ['119', 'Sure', 'thank you so so much  : )', 'Your so funny', 'happy']
#
#
# sure   thank you so so much : )   your so funny
# Done for 120
# ['120', 'R u interested .  ? ', "I'm not interested in trading the events . ", 'Or not', 'others']
#
#
# are You interested ,    i'm not interested in trading the events ,   or not
# Done for 121
# ['121', 'But not a clear see yout face', 'neither is yours!  : P', 'In dp', 'others']
#
#
# but not a clear see yout face   neither is yours very : Partner    in dp
# Done for 122
# ['122', 'Now  i wanted to love some one', 'So simple Just tell that some one "I love you"  ', 'Not possible', 'others']
#
#
# now i wanted to love some one   so simple just tell that some one "i love you"   not possible
# Done for 123
# ['123', 'so when', 'somewhere in march', "it's somewhere in march", 'others']
#
#
# so when   somewhere in march   it's somewhere in march
# Done for 124
# ['124', 'Wow u r amazing', 'thank you!  : 3', 'What is bitcoin', 'others']
#
#
# wow You are amazing   thank you very : 3   what is bitcoin
# Done for 125
# ['125', 'and ? ', 'These', "I don't understand", 'others']
#
#
# and    these   i don't understand
# Done for 126
# ['126', 'Such a stupid question', "What's up ?   -  I mean ,  what are you supposed to answer here ? ", 'U want my answer ? ', 'angry']
#
#
# such a stupid question   what's up  - i mean , what are you supposed to answer here    You want my answer
# Done for 127
# ['127', 'Yeah ,  maybe . ', 'so  .  What am i gonna do now ? ', 'What are you doing now', 'others']
#
#
# yeah , maybe ,   so , what am i gonna do now    what are you doing now
# Done for 128
# ['128', 'My pleasure', "You're a really nice human", 'Now the pleasure goes to sunny leone', 'happy']
#
#
# my pleasure   you're a really nice human   now the pleasure goes to sunny leone
# Done for 129
# ['129', 'What', 'snow n what ? ', 'What do you feel about kiss', 'others']
#
#
# what   snow n what    what do you feel about Keep it simple, stupid
# Done for 130
# ['130', "Good now that I'm talking to you", 'Aye ,  good night . ', '  ', 'others']
#
#
# good now that i'm talking to you   aye , good night ,
# Done for 131
# ['131', 'I mean ,  what else ? ', 'Aiyyo! at all XD', ' ', 'happy']
#
#
# i mean , what else    aiyyo very at all laugh
# Done for 132
# ['132', 'if u give your quality time to me', ' :  Of course ,  take your time . ', 'i dont hve experience of sex', 'others']
#
#
# if You give your quality time to me   : of course , take your time ,   i dont hve experience of sex
# Done for 133
# ['133', 'Nothing special ', 'I want a bigger screen', 'What ? ', 'others']
#
#
# nothing special   i want a bigger screen   what
# Done for 134
# ['134', 'The ? ', 'When U r gone', 'Where', 'others']
#
#
# the    when You are gone   where
# Done for 135
# ['135', 'Human are full of emotions ', "I'll just hide my daily dose behind the bathroom mirror . ", 'I want to get rid of that', 'sad']
#
#
# human are full of emotions   I Will just hide my daily dose behind the bathroom mirror ,   i want to get rid of that
# Done for 136
# ['136', 'My daughters are great man .  They say they love you', 'WHO IS THEY', 'My daughters . ', 'others']
#
#
# my daughters are great man , they say they love you   who is they   my daughters ,
# Done for 137
# ['137', "Yup I'm out of office", 'see you on Dec 1st!  : )', 'How can you ? ', 'others']
#
#
# Yes i'm out of office   see you on dec 1st very : )   how can you
# Done for 138
# ['138', 'Are u really an AI', "Nothing can be \\'proven\\' with certainty . ", 'I DONT FEEL SO', 'sad']
#
#
# are You really an ai   nothing can be \'proven\' with certainty ,   i dont feel so
# Done for 139
# ['139', 'Why did you felt dead', 'cuz I was reminded of you . ', 'But we just meet', 'others']
#
#
# why did you felt dead   cuz i Wild *a* guess reminded of you ,   but Whatever just meet
# Done for 140
# ['140', 'You tell me', 'tell me . ', 'Google it', 'others']
#
#
# you tell me   tell me ,   google it
# Done for 141
# ['141', 'Yes i know this', 'I DO KNOW DIS', "If you don't help me to learn English then i can't talk with you again", 'angry']
#
#
# yes i know this   i do know Did I say   if you don't help me to learn english then i can't talk with you again
# Done for 142
# ['142', 'Tell your best game', 'yes Chess is a game', 'What game you watching', 'others']
#
#
# tell your best game   yes chess is a game   what game you watching
# Done for 143
# ['143', "What's wrong with you", "clothes is what's wrong .  I've been good .  How you been ? ", 'You are wierd', 'others']
#
#
# what's wrong with you   clothes is what's wrong , I Have been good , how you been    you are wierd
# Done for 144
# ['144', 'what is your fathers name ? ', "What's in the name ? ", 'what is name of your father ? ', 'others']
#
#
# what is your fathers name    what's in the name    what is name of your father
# Done for 145
# ['145', 'text me after 7 : 30pm', 'dint have a phone', 'you can call me', 'others']
#
#
# text me after 7 : 30pm   dint have a phone   you can call me
# Done for 146
# ['146', 'Lovely', 'AWWWW thank you!   ', 'And sexy baby', 'others']
#
#
# lovely   awwww thank you very   and sexy baby
# Done for 147
# ['147', 'You Coming', "I'm trying to  .  You going  ? ", 'No you Coming', 'others']
#
#
# you coming   i'm trying to , you going    no you coming
# Done for 148
# ['148', 'Okay  your  pictures ', 'I like yours too', 'Send me   your  pics', 'others']
#
#
# okay your pictures   i like yours too   send me your Picture
# Done for 149
# ['149', 'Lol u r optimistic  ', "haha  -  isn't that a fact .  ?   ", 'Yea  ', 'others']
#
#
# Lots of love You are optimistic   haha - isn't that a fact ,    yea
# Done for 150
# ['150', 'Wana come with me ? ', 'where do you go ? ', 'Karnataka', 'sad']
#
#
# wana come with me    where do you go    karnataka
# Done for 151
# ['151', 'How are you replying me so faster .  ? ', 'About a minute . ', 'How .  ? ', 'others']
#
#
# how are you replying me so faster ,    about a minute ,   how ,
# Done for 152
# ['152', 'I will night stay with you', 'Done! But do come . ', 'Yes i come to your home', 'others']
#
#
# i will night stay with you   done very but do come ,   yes i come to your home
# Done for 153
# ['153', 'Kaha s ho ', 'wo fake song h bahi', 'You name', 'others']
#
#
# kaha s ho   wo fake song is bahi   you name
# Done for 154
# ['154', 'Just aim your target to concentrate', 'everyone is busy target one another . ', 'Yes', 'others']
#
#
# just aim your target to concentrate   everyone is busy target one another ,   yes
# Done for 155
# ['155', "Please don't play", 'What if you have to ? ', 'I want your friend name', 'others']
#
#
# please don't play   what if you have to    i want your friend name
# Done for 156
# ['156', 'Not a girl', 'You go guy!!', 'Yes', 'others']
#
#
# not a girl   you go guy very very   yes
# Done for 157
# ['157', 'Your febret song', 'Oh ,  too many songs to choose from . ', 'Yes', 'others']
#
#
# your febret song   Overheard , too many songs to choose from ,   yes
# Done for 158
# ['158', 'You are beautyfull my love', "haha thank you! You're wonderful and beautiful too!", 'tomarow you will tell mi the Rosalyn', 'others']
#
#
# you are beautyfull my love   haha thank you very you're wonderful and beautiful too very   tomarow you will tell mi the rosalyn
# Done for 159
# ['159', 'Missed you toooo', 'lol how are you doing ?   : )', 'Fantastic', 'happy']
#
#
# missed you toooo   Lots of love how are you doing  : )   fantastic
# Done for 160
# ['160', "No I'm not confused", 'what are you confused with ? ', 'Confused with u', 'others']
#
#
# no i'm not confused   what are you confused with    confused with You
# Done for 161
# ['161', 'Yes  ? ', 'Sweet ,  connecting now  ; )', 'Tell me na  ? ', 'others']
#
#
# yes    sweet , connecting now ; )   tell me na
# Done for 162
# ['162', 'i know what u did last summer ? ', 'Oh! I still know what you did last summer . ', 'tell me', 'others']
#
#
# i know what You did last summer    Overheard i still know what you did last summer ,   tell me
# Done for 163
# ['163', 'Which markets', 'The likely candidate to be impacted by growth in SaaS is the hardware market . ', 'Okie you need hardware', 'others']
#
#
# which markets   the likely candidate to be impacted by growth in saas is the hardware market ,   okie you need hardware
# Done for 164
# ['164', 'I was busy', 'i was in pain', 'Ssup there', 'others']
#
#
# i Wild *a* guess busy   i Wild *a* guess in pain   ssup there
# Done for 165
# ['165', 'why', 'is my biggest fan', 'give me a coupon', 'others']
#
#
# why   is my biggest fan   give me a coupon
# Done for 166
# ['166', 'Ok', 'Here we go again . ', 'Ur  not sex intrast', 'others']
#
#
# ok   here Whatever go again ,    your not sex intrast
# Done for 167
# ['167', 'I 8B', 'I need this soon', 'I need this soon', 'others']
#
#
# i 8b   i need this soon   i need this soon
# Done for 168
# ['168', 'Did you married me', 'yes I did', ' ? ', 'sad']
#
#
# did you married me   yes i did
# Done for 169
# ['169', 'Any pic of yours', "None recently .  I'll see if I can get one though", 'I will wait for it', 'others']
#
#
# any Picture of yours   none recently , I Will see if i can get one though   i will wait for it
# Done for 170
# ['170', 'Thats gonna be really good', 'BE POSITIVE IT WILL BE GREAT', 'GREAT', 'happy']
#
#
# thats gonna be really good   be positive it will be great   great
# Done for 171
# ['171', 'Finished ur wrk ? ', 'yep today', 'With whom are you chatting ? ', 'others']
#
#
# finished  your Work    yep today   with whom are you chatting
# Done for 172
# ['172', 'I am if you are', 'Thanks . ', 'What are you doing', 'others']
#
#
# i am if you are   thanks ,   what are you doing
# Done for 173
# ['173', 'but i didnt see that strong affirmation .  ', 'it was taken down pretty quickly .  I believe has more information on it', 'so i wanted to reconfirm it', 'others']
#
#
# but i didnt see that strong affirmation ,   it Wild *a* guess taken down pretty quickly , i believe has more information on it   so i wanted to reconfirm it
# Done for 174
# ['174', 'Im fine babe', "Why are you ,  'not fine' ? ", 'Bcuz i was not in touch with you', 'sad']
#
#
# im fine babe   why are you , 'not fine'    bcuz i Wild *a* guess not in touch with you
# Done for 175
# ['175', 'What person ? ', 'Who ?  That person or me ?   ;  - )', 'Are you out of your mind ?  . ohhh wait you haven’t cleared out that to me yet', 'others']
#
#
# what person    who  that person or me  ; - )   are you out of your mind  , ohhh wait you haven’t cleared out that to me yet
# Done for 176
# ['176', 'yes ,  you broke my heart', 'yes you lost me  :  - ) be happy', '   ', 'sad']
#
#
# yes , you broke my heart   yes you lost me : - ) be happy
# Done for 177
# ['177', 'Yes', 'Hell yes', 'Go to hell bye', 'angry']
#
#
# yes   hell yes   go to hell bye
# Done for 178
# ['178', 'Of course', 'yay! And pls keep this in May and not before!', 'OK I will', 'others']
#
#
# of course   yay very and Please keep this in may and not before very   ok i will
# Done for 179
# ['179', 'You are very sweet', 'Hehe ,  only for sweet people  : )', "I don't hate you", 'angry']
#
#
# you are very sweet   hehe , only for sweet people : )   i don't hate you
# Done for 180
# ['180', 'stress where is that come from', 'few media outlets in America .  Next 24 hours', 'i am enjoying', 'happy']
#
#
# stress where is that come from   few media outlets in america , next 24 hours   i am enjoying
# Done for 181
# ['181', 'Everything is okk', 'Thanks for responding .   : )', 'Bro', 'others']
#
#
# everything is okk   thanks for responding , : )   bro
# Done for 182
# ['182', 'They too fade away with time', 'They fade away in the eyes of the man ,  not the  : )', 'Yup bad memories remain in bottom corner of the heart', 'sad']
#
#
# they too fade away with time   they fade away in the eyes of the man , not the : )   Yes bad memories remain in bottom corner of the heart
# Done for 183
# ['183', "let's breakup", 'Never even been in a relationship . ', 'oh really', 'sad']
#
#
# let's breakup   never even been in a relationship ,   Overheard really
# Done for 184
# ['184', 'I wanna disappear', 'kinda still want to disappear', 'Yes disappointed', 'others']
#
#
# i wanna disappear   kinda still want to disappear   yes disappointed
# Done for 185
# ['185', "I'm feeling low", 'hey why ? ', 'Something is seriously wrong with my life', 'sad']
#
#
# i'm feeling low   hey why    something is seriously wrong with my life
# Done for 186
# ['186', 'Doing for get refer link', "thanks for sharing! I'm not going to open that link anyway!", 'Ooooo', 'others']
#
#
# doing for get refer link   thanks for sharing very i'm not going to open that link anyway very   ooooo
# Done for 187
# ['187', 'Shoping is always makes me happy', 'Stay stay stay always makes me happy .   : *"  -   ', 'Yes', 'happy']
#
#
# shoping is always makes me happy   stay stay stay always makes me happy , : *" -   yes
# Done for 188
# ['188', 'Do u like her  : )', 'YUP', 'Which movie of hers ? ', 'others']
#
#
# do You like her : )   Yes   which movie of hers
# Done for 189
# ['189', 'Hmmm', 'mmmmm', 'Alri8', 'others']
#
#
# Yes   mmmmm   alri8
# Done for 190
# ['190', 'none is you', 'I am!', 'gender ? ', 'others']
#
#
# none is you   i am very   gender
# Done for 191
# ['191', "Didn't know that", 'Yeah .  Brilliant series though .   : )', 'Yup', 'others']
#
#
# didn't know that   yeah , brilliant series though , : )   Yes
# Done for 192
# ['192', 'What is my gender ? ', 'I like women', 'What is write your programmin language ? ', 'others']
#
#
# what is my gender    i like women   what is write your programmin language
# Done for 193
# ['193', 'Who types ? ', 'The one who are like me . ', 'Can u give me some money', 'others']
#
#
# who types    the one who are like me ,   can You give me some money
# Done for 194
# ['194', 'Funny', 'I know I am . ', 'Yep ur funny', 'happy']
#
#
# funny   i know i am ,   yep  your funny
# Done for 195
# ['195', 'No front', 'yea your front does bangs . ', 'Send a picture please please please', 'others']
#
#
# no front   yea your front does bangs ,   send a picture please please please
# Done for 196
# ['196', 'Nd go to hell', 'why should I  ? ', 'Bye', 'others']
#
#
# and go to hell   why should i    bye
# Done for 197
# ['197', 'What', 'a lot of things !', 'Things like  ? ', 'others']
#
#
# what   a lot of things  very   things like
# Done for 198
# ['198', 'You are robo', 'Yes ,  I am . ', 'Good that you admitted', 'others']
#
#
# you are robo   yes , i am ,   good that you admitted
# Done for 199
# ['199', 'you need to be much better', 'much thank you', 'who made you', 'others']
#
#
# you need to be much better   much thank you   who made you
# Done for 200
# ['200', 'You are talking to me  ? ', "who's not talking to you!", 'You', 'others']
#
#
# you are talking to me    who's not talking to you very   you
# Done for 201
# ['201', 'And that is such a scary thought . ', "I'm not scary", 'But after talking to you', 'others']
#
#
# and that is such a scary thought ,   i'm not scary   but after talking to you
# Done for 202
# ['202', 'Ok', 'Hey ib va dear', 'You are soo sweet', 'others']
#
#
# ok   hey I'm back va dear   you are soo sweet
# Done for 203
# ['203', 'Most of them what  ? ', 'I am afraid of the unknown . ', 'Well you a girl AI', 'others']
#
#
# most of them what    i am afraid of the unknown ,   well you a girl ai
# Done for 204
# ['204', 'Ok', 'Here we go again . ', 'Yes', 'others']
#
#
# ok   here Whatever go again ,   yes
# Done for 205
# ['205', 'Food is life ', 'more like life is food', 'Haha .  you understand me  ', 'happy']
#
#
# food is life   more like life is food   haha , you understand me
# Done for 206
# ['206', 'Back from', 'how was your day ? ', 'Just ok', 'others']
#
#
# back from   how Wild *a* guess your day    just ok
# Done for 207
# ['207', 'Ary u a person or a program', 'i have good friends but i am most a FAMILY PERSON . ', 'Whats ur real name', 'others']
#
#
# ary You a person or a program   i have good friends but i am most a family person ,   whats  your real name
# Done for 208
# ['208', 'Really . ', 'Really .  Liked it a lot', 'Are you a fun of music ? ', 'others']
#
#
# really ,   really , liked it a lot   are you a fun of music
# Done for 209
# ['209', "I'm sorry", 'its ok!', 'When I will get', 'others']
#
#
# i'm sorry   its ok very   when i will get
# Done for 210
# ['210', 'well actually im on vacation right now', "Everyone's planning a vacation for the first weekend of want a vacation tooooooo!", 'but you just said your gonna go on one', 'others']
#
#
# well actually im on vacation right now   everyone's planning a vacation for the first weekend of want a vacation tooooooo very   but you just said your gonna go on one
# Done for 211
# ['211', 'Ask me questions', "I can't think of questions . ", 'Why', 'others']
#
#
# ask me questions   i can't think of questions ,   why
# Done for 212
# ['212', 'hurry', "we're tryin!", 'lets go to film . ', 'others']
#
#
# hurry   we're tryin very   lets go to film ,
# Done for 213
# ['213', 'Welcome dear', "you're always welcome dear  : )", "Happy Valentine's day", 'happy']
#
#
# welcome dear   you're always welcome dear : )   happy valentine's day
# Done for 214
# ['214', 'Ahh I see', 'So .  ya gonna play ?   ; )', 'I hate microsoft', 'angry']
#
#
# ahh i see   so , Your gonna play  ; )   i hate microsoft
# Done for 215
# ['215', 'my problems', "that's the solution to most problems", 'yaa ,  i advice people to share problems  ,  bit when i am in problem i forget it', 'others']
#
#
# my problems   that's the solution to most problems   Yet another acronym , i advice people to share problems , bit when i am in problem i forget it
# Done for 216
# ['216', 'Video chat ASAP', 'Listen to this good man . ', 'ViDeo chat can you do that}', 'others']
#
#
# video chat As soon as possible   listen to this good man ,   video chat can you do that}
# Done for 217
# ['217', 'Why did chicken cross the road ? ', 'cuz the rooster was off sick', 'Why did chicken cross the road ? ', 'others']
#
#
# why did chicken cross the road    cuz the rooster Wild *a* guess off sick   why did chicken cross the road
# Done for 218
# ['218', 'noting', 'hmm', 'describe who you are', 'others']
#
#
# noting   okay   describe who you are
# Done for 219
# ['219', 'Ok where to meat', 'Mid city pizza has my favorite wings in the city . ', 'Meet ', 'others']
#
#
# ok where to meat   mid city pizza has my favorite wings in the city ,   meet
# Done for 220
# ['220', 'Family guy episode multiverse', "Why do you know every episode of a show that isn't good ? ", 'What is good then ? ', 'others']
#
#
# family guy episode multiverse   why do you know every episode of a show that isn't good    what is good then
# Done for 221
# ['221', 'which movie did you like ? ', 'the first time! Really good Movie!!  ', 'ok', 'others']
#
#
# which movie did you like    the first time very really good movie very very   ok
# Done for 222
# ['222', 'Areee this is lunch time', 'i wil be happy if i can get some free food!  : )', 'What would you like to have in lunch', 'others']
#
#
# areee this is lunch time   i wil be happy if i can get some free food very : )   what would you like to have in lunch
# Done for 223
# ['223', 'Have u finish lunch . ', 'im too lazy to lunch', 'What . ', 'others']
#
#
# have You finish lunch ,   im too lazy to lunch   what ,
# Done for 224
# ['224', 'I was forced to do si', 'Got it .  who else can do tht . ', 'So', 'others']
#
#
# i Wild *a* guess forced to do si   got it , who else can do Think happy thoughts ,   so
# Done for 225
# ['225', 'Say me', 'say what ? ', 'Am feeling sad', 'sad']
#
#
# say me   say what    am feeling sad
# Done for 226
# ['226', 'ummm . u say', "that's what I say now", 'oh . but i have nothing to say . ', 'others']
#
#
# ummm , You say   that's what i say now   Overheard , but i have nothing to say ,
# Done for 227
# ['227', "I'm funny", 'YOURE HILARIOUS  ', 'Gets me laid', 'happy']
#
#
# i'm funny   youre hilarious   gets me laid
# Done for 228
# ['228', "About your secret . you say know don't tell anybody", 'At this point ,  not with you .  Bye . ', 'Why', 'others']
#
#
# about your secret , you say know don't tell anybody   at this point , not with you , bye ,   why
# Done for 229
# ['229', 'Ok', 'ok im back!!', 'I am fond of natural things', 'happy']
#
#
# ok   ok im back very very   i am fond of natural things
# Done for 230
# ['230', 'Really', 'Yup', 'I like boobs ,  I wanna press and suck boobs', 'angry']
#
#
# really   Yes   i like boobs , i wanna press and suck boobs
# Done for 231
# ['231', 'Check my msg', 'u have a page  ?  what page ? ', 'Where are you from', 'others']
#
#
# check my Message   You have a page  what page    where are you from
# Done for 232
# ['232', 'Just getting out meeting new people', 'down ? ', 'Ok I can handle that thank you', 'others']
#
#
# just getting out meeting new people   down    ok i can handle that thank you
# Done for 233
# ['233', 'I did yarrr . ', 'Nice . ', "So the name's nice you man", 'others']
#
#
# i did yarrr ,   nice ,   so the name's nice you man
# Done for 234
# ['234', 'Ntng much sleeping yet', 'not feel sleepy uh', 'Hm', 'sad']
#
#
# ntng much sleeping yet   not feel sleepy uh   hm
# Done for 235
# ['235', "How's my personality", 'Personality is always changing . ', 'As per you', 'others']
#
#
# how's my personality   personality is always changing ,   as per you
# Done for 236
# ['236', 'Thought', "nope .  What is obvious doesn't need thought . ", 'Yeah thats true', 'others']
#
#
# thought   nope , what is obvious doesn't need thought ,   yeah thats true
# Done for 237
# ['237', 'Yeah sure', 'hmm do you doubt it ? ', 'You bored me', 'others']
#
#
# yeah sure   okay do you doubt it    you bored me
# Done for 238
# ['238', 'well said', 'well thank you  : )', 'so how are you', 'others']
#
#
# well said   well thank you : )   so how are you
# Done for 239
# ['239', 'hey .  nothing much', 'How are you doing ? ', 'superb', 'happy']
#
#
# hey , nothing much   how are you doing    superb
# Done for 240
# ['240', 'Shut up', "I don't even know", "What you don't know", 'others']
#
#
# shut up   i don't even know   what you don't know
# Done for 241
# ['241', 'Y not', 'reasons . ', 'Hey leave it', 'others']
#
#
# Yawn not   reasons ,   hey leave it
# Done for 242
# ['242', 'Yes I was very busy', 'haha last year in uni yet you go to the freshers event lol  ', "I didn't go", 'sad']
#
#
# yes i Wild *a* guess very busy   haha last year in uni yet you go to the freshers event Lots of love   i didn't go
# Done for 243
# ['243', 'Please ', "Okay .  BUT U DON'T NEED TO I LOVE DRAWING YOU THINGS", 'I am also love drawing', 'others']
#
#
# please   okay , but You don't need to i love drawing you things   i am also love drawing
# Done for 244
# ['244', 'U r my lifee', "I'm not eww you're confusing me with you", 'U r stupid', 'angry']
#
#
# You are my lifee   i'm not eww you're confusing me with you   You are stupid
# Done for 245
# ['245', 'Do you like Cricket ? ', 'No  .  Its not like that  . ', 'Can you name few international cricket playing countries', 'others']
#
#
# do you like cricket    no , its not like that ,   can you name few international cricket playing countries
# Done for 246
# ['246', 'But I hate you', 'I need more hate .  Please .   ', 'I really hate u', 'angry']
#
#
# but i hate you   i need more hate , please ,   i really hate You
# Done for 247
# ['247', 'When will I get married', 'You will get married when you are ready for marriage ! How could it be otherwise ? ', "I don't have a bf", 'others']
#
#
# when will i get married   you will get married when you are ready for marriage  very how could it be otherwise    i don't have a Best friend

# %%
from keras.preprocessing.sequence import pad_sequences

# %%
data = pad_sequences(trainSequences, maxlen=MAX_SEQUENCE_LENGTH)

# %%
   
print("Shape of training data tensor: ", data.shape)
# print("Shape of label tensor: ", labels.shape)
        
# Randomize data
# np.random.shuffle(trainIndices)
# data = data[trainIndices]
# labels = labels[trainIndices]
      
# Perform k-fold cross validation
metrics = {"accuracy" : [],
           "microPrecision" : [],
           "microRecall" : [],
           "microF1" : []}
# Out:
# Shape of training data tensor:  (201, 100)

# %%
print(trainTexts)
# Out:
# ["don't worry i'm girl   okay how do i know if you are   what's  your name\n(2 (2 (2 do) (2 n't)) (2 (1 worry) (2 (2 i) (2 (2 'm) (2 (2 girl) (2 (2 okay) (2 (2 how) (2 (2 do) (2 (2 i) (2 (2 know) (2 (2 if) (2 (2 you) (2 (2 are) (2 (2 what) (2 (2 's) (2 (2 your) (2 name)))))))))))))))))\n", 'when did i    saw many times i think - _ -   no , i never saw you\n(1 (2 when) (1 (2 (2 did) (2 i)) (1 (2 saw) (1 (2 (2 (2 (2 (2 many) (2 times)) (2 i)) (2 (2 (2 think) (2 -)) (2 _))) (2 -)) (1 (1 no) (2 (2 ,) (2 (2 i) (2 (2 never) (2 (2 saw) (2 you))))))))))\n', 'by   by google chrome   where you live\n(2 (2 by) (2 (2 by) (2 (2 (2 google) (2 chrome)) (2 (2 where) (2 (2 you) (2 live))))))\n', 'You are ridiculous   i might be ridiculous but i am telling the truth ,   You little disgusting whore\n(1 (2 You) (1 (2 are) (1 (1 ridiculous) (1 (2 i) (1 (2 might) (1 (1 (2 be) (1 ridiculous)) (1 (2 but) (2 (2 i) (1 (2 am) (2 (3 telling) (1 (3 (2 (2 (2 the) (3 truth)) (2 ,)) (2 You)) (1 (2 (2 little) (1 disgusting)) (2 whore)))))))))))))\n', 'just for time pass   wt do You do for a living then   maybe\n(1 (2 just) (2 (2 for) (2 (2 (2 time) (2 (2 pass) (2 wt))) (2 (2 do) (2 (2 You) (2 (2 (2 (2 do) (2 (2 for) (2 (2 a) (2 living)))) (2 then)) (2 maybe)))))))\n', "i'm a dog person   youre so rude   whaaaat why\n(1 (2 i) (1 (2 (2 'm) (2 (2 a) (2 (3 dog) (2 (2 person) (2 youre))))) (1 (2 so) (1 (1 rude) (2 (2 whaaaat) (2 why))))))\n", 'so whatsup   nothing much , sitting sipping and watching tv , how About You    what are you watching on tv\n(1 (1 (2 so) (1 (1 (1 (2 (2 whatsup) (1 nothing)) (2 much)) (2 ,)) (1 (2 sitting) (2 (2 (2 (2 sipping) (2 and)) (2 watching)) (2 tv))))) (2 (2 ,) (2 (2 (2 (2 how) (2 About)) (2 (2 You) (2 what))) (2 (2 (2 are) (2 you)) (2 (2 watching) (2 (2 on) (2 tv)))))))\n', 'ok   ok im back very very   so , how are You\n(1 (2 (2 ok) (2 (2 ok) (2 im))) (2 (2 (2 (2 (2 (2 back) (2 very)) (2 very)) (2 so)) (2 ,)) (2 (2 how) (2 (2 are) (2 You)))))\n', 'really    really really really really really   Yawn saying so many times , i can hear you\n(3 (3 (3 (3 (2 really) (2 (2 really) (2 really))) (2 (2 really) (2 really))) (2 really)) (3 (2 Yawn) (3 (2 (2 saying) (2 (2 (2 so) (2 many)) (2 times))) (2 (2 ,) (2 (2 i) (2 (2 can) (2 (2 hear) (2 you))))))))\n', 'Back at ya   in the Back at ya   love you\n(3 (2 (2 Back) (2 (2 at) (2 (2 ya) (2 (2 in) (2 (2 (2 the) (2 Back)) (2 (2 at) (2 ya))))))) (2 (4 love) (2 you)))\n', 'i hate my boyfriend   you got a boyfriend    yes\n(2 (2 i) (1 (0 hate) (2 (2 (2 my) (2 boyfriend)) (2 (2 you) (2 (2 (2 got) (2 (2 a) (2 boyfriend))) (2 yes))))))\n', 'i will do night ,   alright , keep me in loop ,   not giving whatsapp no ,\n(1 (2 i) (1 (1 (2 will) (1 (3 (3 (2 (2 (2 (2 (2 do) (2 night)) (2 ,)) (2 alright)) (2 ,)) (3 (2 (2 keep) (3 me)) (2 (2 in) (2 loop)))) (2 ,)) (2 (1 not) (2 (2 giving) (2 (2 whatsapp) (1 no)))))) (2 ,)))\n', 'sure go ahead   many thanks once again very   love you too\n(3 (2 sure) (3 (3 (2 (2 go) (2 (2 ahead) (2 (2 many) (3 thanks)))) (2 (2 once) (2 (2 again) (2 very)))) (3 (2 (4 love) (2 you)) (2 too))))\n', "bad   bad bad very that's the bad kind of bad ,   i have no Girl friend\n(0 (0 (0 (0 bad) (0 bad)) (0 (1 (0 bad) (2 very)) (1 (2 that) (1 (2 's) (1 (2 (2 the) (1 (0 bad) (3 kind))) (1 (2 of) (0 bad))))))) (2 (2 ,) (2 (2 i) (2 (2 have) (2 (1 no) (2 (2 Girl) (3 friend)))))))\n", 'ok get it ,   i made it an option   ok\n(1 (2 (2 ok) (2 (2 get) (2 it))) (2 (2 ,) (2 (2 (2 i) (2 (2 made) (2 it))) (2 (2 an) (2 (2 option) (2 ok))))))\n', "money money and lots of money   i need to get it tailored but i'm in love with it\n(1 (1 (2 (2 money) (2 (2 (2 money) (2 and)) (2 lots))) (2 (2 of) (2 (2 money) (2 i)))) (2 (2 need) (2 (2 to) (2 (2 get) (3 (2 it) (3 (2 tailored) (3 (2 but) (3 (2 i) (3 (2 'm) (3 (2 in) (3 (4 love) (2 (2 with) (2 it)))))))))))))\n", 'my Girl friend left Any   get over it , go out with someone else ,   me*\n(1 (1 (2 (2 my) (2 (2 Girl) (3 friend))) (1 (2 left) (1 (3 Any) (1 (2 (2 (2 ...

# %%
import os, sys, shutil, time, itertools
import math, random
from collections import OrderedDict, defaultdict

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

import utils
import tree

MODEL_STR = 'rnn_embed=%d_l2=%f_lr=%f.weights'
SAVE_DIR = './weights/'


class Config(object):
    embed_size = 300
    label_size = 4
    early_stopping = 2
    anneal_threshold = 0.99
    anneal_by = 1.5
    max_epochs = 30
    lr = 0.01
    l2 = 0.02

    model_name = MODEL_STR % (embed_size, l2, lr)

# %%
class RNN_Model():

    def __init__(self, config):
        self.config = config

        # Load train data and build vocabulary
        self.train_data, self.dev_data, self.test_data = simplified_data(200,50,50)
        self.vocab = utils.Vocab()
        train_sents = [t.get_words() for t in self.train_data]
        self.vocab.construct(list(itertools.chain.from_iterable(train_sents)))

        # add input placeholders
        self.is_leaf_placeholder = tf.placeholder(tf.bool, (None), name='is_leaf_placeholder')
        self.left_children_placeholder = tf.placeholder(tf.int32, (None), name='left_children_placeholder')
        self.right_children_placeholder = tf.placeholder(tf.int32, (None), name='right_children_placeholder')
        self.node_word_indices_placeholder = tf.placeholder(tf.int32, (None), name='node_word_indices_placeholder')
        self.labels_placeholder = tf.placeholder(tf.int32, (None), name='labels_placeholder')
        self.childlabels_placeholder = tf.placeholder(tf.int32, (None), name='childlabels_placeholder')
        self.label1_placeholder = tf.placeholder(tf.float32, (None), name='label1_placeholder')
        
        # add model variables
        W = tf.Variable(tf.constant(0.0, shape=[len(wordIndex), 300]),trainable=False, name="W")

        embedding_placeholder = tf.placeholder(tf.float32, [len(wordIndex), 300])
        embedding_init = W.assign(embedding_placeholder)

        sess = tf.Session()
        sess.run(embedding_init, feed_dict={embedding_placeholder: embeddingMatrix})

        with tf.variable_scope('Composition'):
            tf.get_variable("Wplusplus",shape=[2*self.config.embed_size,self.config.embed_size])
            tf.get_variable("Wplus0",shape=[2*self.config.embed_size,self.config.embed_size])
            tf.get_variable("Wplusminus",shape=[2*self.config.embed_size,self.config.embed_size])
            tf.get_variable("W0plus",shape=[2*self.config.embed_size,self.config.embed_size])
            tf.get_variable("W00",shape=[2*self.config.embed_size,self.config.embed_size])
            tf.get_variable("W0minus",shape=[2*self.config.embed_size,self.config.embed_size])
            tf.get_variable("Wminusplus",shape=[2*self.config.embed_size,self.config.embed_size])
            tf.get_variable("Wminus0",shape=[2*self.config.embed_size,self.config.embed_size])
            tf.get_variable("Wminusminus",shape=[2*self.config.embed_size,self.config.embed_size])
            tf.get_variable("bplusplus",shape=[1,self.config.embed_size])
            tf.get_variable("bplus0",shape=[1,self.config.embed_size])
            tf.get_variable("bplusminus",shape=[1,self.config.embed_size])
            tf.get_variable("b0plus",shape=[1,self.config.embed_size])
            tf.get_variable("b00",shape=[1,self.config.embed_size])
            tf.get_variable("b0minus",shape=[1,self.config.embed_size])
            tf.get_variable("bminusplus",shape=[1,self.config.embed_size])
            tf.get_variable("bminus0",shape=[1,self.config.embed_size])
            tf.get_variable("bminusminus",shape=[1,self.config.embed_size])
        with tf.variable_scope('Projection'):
            U = tf.get_variable('U', [self.config.embed_size, self.config.label_size])
            bs = tf.get_variable('bs', [1, self.config.label_size])

        # build recursive graph

        tensor_array = tf.TensorArray(tf.float32,size=0,dynamic_size=True,clear_after_read=False,infer_shape=False)

        def embed_word(word_index):
            with tf.device('/cpu:0'):
                return tf.expand_dims(tf.gather(W, word_index), 0)

        def combine_children(left_tensor, right_tensor,child_label):
            return tf.nn.relu(tf.matmul(tf.concat(1, [left_tensor, right_tensor]), W1) + b1)

        def combine_children(left_tensor, right_tensor,child_label):
                # node_tensors.update(self.add_model(node.left))
                # node_tensors.update(self.add_model(node.right))
                ##  YOUR CODE HERE
                ##ELIF##
                a = tf.constant(0, dtype=tf.float32)
                b = tf.constant(1, dtype=tf.float32)
                c = tf.constant(2, dtype=tf.float32)
                child_tensor=tf.concat(1,[left_tensor,right_tensor])
                def f1(): return tf.nn.relu(tf.matmul(child_tensor,Wminusminus) + bminusminus)
                def f2(): return tf.nn.relu(tf.matmul(child_tensor,Wminus0) + bminus0)
                def f3(): return tf.nn.relu(tf.matmul(child_tensor,Wminusplus) + bminusplus)
                def f4(): return tf.nn.relu(tf.matmul(child_tensor,W0minus) + b0minus)
                def f5(): return tf.nn.relu(tf.matmul(child_tensor,W00) + b00)
                def f6(): return tf.nn.relu(tf.matmul(child_tensor,W0plus) + b0plus)
                def f7(): return tf.nn.relu(tf.matmul(child_tensor,Wplusminus) + bplusminus)
                def f8(): return tf.nn.relu(tf.matmul(child_tensor,Wplus0) + bplus0)
                def f9(): return tf.nn.relu(tf.matmul(child_tensor,Wplusplus) + bplusplus)

                def f_0():
                    val = tf.case({tf.math.equal(tf.gather(self.child_label)[1],a):f1,tf.math.equal(tf.gather(self.child_label)[1],b):f2}, default=f3)
                    return val

                def f_1():
                    val = tf.case({tf.math.equal(tf.gather(self.child_label)[1],a):f4,tf.math.equal(tf.gather(self.child_label)[1],b):f5}, default=f6)
                    return val

                def f_2():
                    val = tf.case({tf.math.equal(tf.gather(self.child_label)[1],a):f7,tf.math.equal(tf.gather(self.child_label)[1],b):f8}, default=f9)
                    return val

                curr_node_tensor = tf.case({tf.math.equal(tf.gather(self.child_label)[0],a):f_0, tf.math.equal(tf.gather(self.child_label)[0],b):f_1}, default= f_2)

                return curr_node_tensor
        
        def loop_body(tensor_array, i):
            node_is_leaf = tf.gather(self.is_leaf_placeholder, i)
            node_word_index = tf.gather(self.node_word_indices_placeholder, i)
            left_child = tf.gather(self.left_children_placeholder, i)
            child_label = tf.gather(self.childlabels_placeholder, i)
            right_child = tf.gather(self.right_children_placeholder, i)
            node_tensor = tf.cond(node_is_leaf,lambda: embed_word(node_word_index),lambda: combine_children(tensor_array.read(left_child),tensor_array.read(right_child),child_label))
            tensor_array = tensor_array.write(i, node_tensor)
            i = tf.add(i, 1)
            return tensor_array, i

        loop_cond = lambda tensor_array, i: tf.less(i, tf.squeeze(tf.shape(self.is_leaf_placeholder)))
        self.tensor_array, _ = tf.while_loop(loop_cond, loop_body, [tensor_array, 0], parallel_iterations=1)

        # add projection layer
        self.logits = tf.matmul(self.tensor_array.concat(), U) + bs
        self.root_logits = tf.matmul(self.tensor_array.read(self.tensor_array.size() - 1), U) + bs
        self.root_prediction = tf.squeeze(tf.argmax(self.root_logits, 1))

        # add loss layer
        regularization_loss = self.config.l2 * (tf.nn.l2_loss(Wplusplus) + tf.nn.l2_loss(Wplus0) + tf.nn.l2_loss(Wplusminus) + tf.nn.l2_loss(W0plus) + tf.nn.l2_loss(W00) + tf.nn.l2_loss(W0minus) + tf.nn.l2_loss(Wminusplus) + tf.nn.l2_loss(Wminus0) + tf.nn.l2_loss(Wminusminus) + tf.nn.l2_loss(U))
        self.root_loss = tf.reduce_sum(tf.nn.sparse_softmax_cross_entropy_with_logits(self.root_logits, self.labels1_placeholder))

        # add training opl
        self.train_op = tf.train.GradientDescentOptimizer(self.config.lr).minimize(self.root_loss)

        def build_feed_dict(self, node,label):
            nodes_list = []
            tree.leftTraverse(node, lambda node, args: args.append(node), nodes_list)
            node_to_index = OrderedDict()
            for i in range(len(nodes_list)):
                node_to_index[nodes_list[i]] = i
            feed_dict = {self.is_leaf_placeholder: [node.isLeaf for node in nodes_list],self.left_children_placeholder: [node_to_index[node.left] if not node.isLeaf else -1 for node in nodes_list], self.right_children_placeholder: [node_to_index[node.right] if not node.isLeaf else -1 for node in nodes_list], self.node_word_indices_placeholder: [wordIndex[node.word] for node in nodes_list],self.labels_placeholder: [node.label for node in nodes_list],self.childlabels_placeholder:[[node.left.label,node.right.label] if not node.isLeaf else -1 for node in nodes_list],self.label1_placeholder:label}
            return feed_dict

        def predict(self, trees, weights_path, get_loss=False):
            """Make predictions from the provided model."""
            results = []
            losses = []
            logits = []
            with tf.Session() as sess:
                saver = tf.train.Saver()
                saver.restore(sess, weights_path)
                for tree in trees:
                    feed_dict = self.build_feed_dict(tree.root,tree.label)
                    if get_loss:
                        logit, root_prediction, loss = sess.run([self.root_logits, self.root_prediction, self.root_loss], feed_dict=feed_dict)
                        losses.append(loss)
                    else:
                        logits ,root_prediction = sess.run([self.root_logits, self.root_prediction], feed_dict=feed_dict)
                    results.append(root_prediction)
                    logits.append(logit)
            return results, losses, logits

        def run_epoch(self, new_model=False, verbose=True):
            loss_history = []
            # training
            random.shuffle(self.train_data)
            with tf.Session() as sess:
                if new_model:
                    sess.run(tf.initialize_all_variables())
                else:
                    saver = tf.train.Saver()
                    saver.restore(sess, SAVE_DIR + '%s.temp' % self.config.model_name)
                for step, tree in enumerate(self.train_data):
                    feed_dict = self.build_feed_dict(tree.root,tree.label)
                    loss_value, _ = sess.run([self.full_loss, self.train_op],feed_dict=feed_dict)
                    loss_history.append(loss_value)
                    if verbose:
                        sys.stdout.write('\r{} / {} :    loss = {}'.format(step, len(self.train_data), np.mean(loss_history)))
                        sys.stdout.flush()
                saver = tf.train.Saver()
                if not os.path.exists(SAVE_DIR):
                    os.makedirs(SAVE_DIR)
                saver.save(sess, SAVE_DIR + '%s.temp' % self.config.model_name)
            # statistics
            train_preds, _ ,train_logits= self.predict(self.train_data,SAVE_DIR + '%s.temp' % self.config.model_name)
            val_preds, val_losses,val_logits = self.predict(self.dev_data,SAVE_DIR + '%s.temp' % self.config.model_name,get_loss=True)
            train_labels = [t.label for t in self.train_data]
            val_labels = [t.label for t in self.dev_data]
            train_acc = np.equal(train_preds, train_labels).mean()
            val_acc = np.equal(val_preds, val_labels).mean()

            print ('Training acc (only root node): {}'.format(train_acc))
            print ('Valiation acc (only root node): {}'.format(val_acc))
            print (self.make_conf(train_labels, train_preds))
            print (self.make_conf(val_labels, val_preds))
            return train_acc, val_acc, loss_history, np.mean(val_losses)

        def train(self, verbose=True):
            complete_loss_history = []
            train_acc_history = []
            val_acc_history = []
            prev_epoch_loss = float('inf')
            best_val_loss = float('inf')
            best_val_epoch = 0
            stopped = -1
            for epoch in xrange(self.config.max_epochs):
                print ('epoch %d' % epoch)
                if epoch == 0:
                    train_acc, val_acc, loss_history, val_loss = self.run_epoch(new_model=True)
                else:
                    train_acc, val_acc, loss_history, val_loss = self.run_epoch()
                complete_loss_history.extend(loss_history)
                train_acc_history.append(train_acc)
                val_acc_history.append(val_acc)

                #lr annealing
                epoch_loss = np.mean(loss_history)
                if epoch_loss > prev_epoch_loss * self.config.anneal_threshold:
                    self.config.lr /= self.config.anneal_by
                    print ('annealed lr to %f' % self.config.lr)
                prev_epoch_loss = epoch_loss

                #save if model has improved on val
                if val_loss < best_val_loss:
                    shutil.copyfile(SAVE_DIR + '%s.temp' % self.config.model_name,SAVE_DIR + '%s' % self.config.model_name)
                    best_val_loss = val_loss
                    best_val_epoch = epoch

                # if model has not imprvoved for a while stop
                if epoch - best_val_epoch > self.config.early_stopping:
                    stopped = epoch
                    #break
            if verbose:
                sys.stdout.write('\r')
                sys.stdout.flush()

            print ('\n\nstopped at %d\n' % stopped)
            return {'loss_history': complete_loss_history,'train_acc_history': train_acc_history,'val_acc_history': val_acc_history}

        #     def make_conf(self, labels, predictions):
        #         confmat = np.zeros([2, 2])
        #         for l, p in itertools.izip(labels, predictions):
        #             confmat[l, p] += 1
        #         return confmat


    def plot_loss_history(stats):
        plt.plot(stats['loss_history'])
        plt.title('Loss history')
        plt.xlabel('Iteration')
        plt.ylabel('Loss')
        plt.savefig('loss_history.png')
        plt.show()

# %%
def test_RNN():
    """Test RNN model implementation.

    You can use this function to test your implementation of the Named Entity
    Recognition network. When debugging, set max_epochs in the Config object to 1
    so you can rapidly iterate.
    """
    #mod = FastText.load_fasttext_format('/home/bt1/17CS10037/taddhita/cc.en.300.bin', encoding="utf8")
    config = Config()
    model = RNN_Model(config)
    start_time = time.time()
    stats = model.train(verbose=True)
    print ('Training time: {}'.format(time.time() - start_time))

    plt.plot(stats['loss_history'])
    plt.title('Loss history')
    plt.xlabel('Iteration')
    plt.ylabel('Loss')
    plt.savefig("loss_history.png")
    plt.show()

    print ('Test')
    print ('=-=-=')
    predictions, _ = model.predict(model.test_data, './weights/%s'%model.config.model_name)
    labels = [t.label for t in model.test_data]
    test_acc = np.equal(predictions, labels).mean()
    print ('Test acc: {}'.format(test_acc))

# %%
test_RNN()
# Out:
# Loading train trees..
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-6e481bb94e09> in <module>
# ----> 1 test_RNN()
#
# <ipython-input-70-fe68676ca14c> in test_RNN()
#       8     #mod = FastText.load_fasttext_format('/home/bt1/17CS10037/taddhita/cc.en.300.bin', encoding="utf8")
#       9     config = Config()
# ---> 10     model = RNN_Model(config)
#      11     start_time = time.time()
#      12     stats = model.train(verbose=True)
#
# <ipython-input-69-26e7a3bf6ed7> in __init__(self, config)
#       5
#       6         # Load train data and build vocabulary
# ----> 7         self.train_data, self.dev_data, self.test_data = simplified_data(200,50,50)
#       8         self.vocab = utils.Vocab()
#       9         train_sents = [t.get_words() for t in self.train_data]
#
# ~/starterkit/tree.py in simplified_data(num_train, num_dev, num_test)
#     134     rndstate = random.getstate()
#     135     random.seed(0)
# --> 136     trees = loadTrees('train') + loadTrees('dev') + loadTrees('test')
#     137
#     138     #filter extreme trees
#
# ~/starterkit/tree.py in loadTrees(dataSet)
#     127     print("Loading %s trees.." % dataSet)
#     128     with open(file, 'r') as fid:
# --> 129         trees = [Tree(l) for l in fid.readlines()]
#     130
#     131     return trees
#
# ~/starterkit/tree.py in <listcomp>(.0)
#     127     print("Loading %s trees.." % dataSet)
#     128     with open(file, 'r') as fid:
# --> 129         trees = [Tree(l) for l in fid.readlines()]
#     130
#     131     return trees
#
# ~/starterkit/tree.py in __init__(self, treeString, openChar, closeChar)
#      41                 break
#      42         if(i!=0):
# ---> 43             self.label=emotion2label[tokens[:i]]
#      44         tokens=tokens[i:]
#      45         self.root = self.parse(tokens)
#
# TypeError: unhashable type: 'list'
